# %% [markdown]
# # Intro to Natural Language Processing with Python
#
# ## Info
# - Scott Bailey (CIDR), *scottbailey@stanford.edu*
# - Javier de la Rosa (CIDR), *versae@stanford.edu*
#
#
# ## What are we covering today?
# - What is NLP?
# - Options for NLP in Python
# - Tokenization
# - Part of Speech Tagging
# - Named Entity Recognition
# - Word transformations
# - Readability indices

# %% [markdown]
# ## Goals
#
# By the end of the workshop, we hope you'll have a basic understanding of natural language processing, and enough familiarity with one NLP package, SpaCy, to perform basic NLP tasks like tokenization and part of speech tagging. Through analyzing presidential speeches, we also hope you'll understand how these basic tasks open up a number of possibilities for textual analysis, such as readability indices.

# %% [markdown]
# ## What is NLP
#
# NLP stands for Natual Language Processing and it involves a huge variety of tasks such as:
# - Automatic summarization.
# - Coreference resolution.
# - Discourse analysis.
# - Machine translation.
# - Morphological segmentation.
# - Named entity recognition.
# - Natural language understanding.
# - Part-of-speech tagging.
# - Parsing.
# - Question answering.
# - Relationship extraction.
# - Sentiment analysis.
# - Speech recognition.
# - Topic segmentation.
# - Word segmentation.
# - Word sense disambiguation.
# - Information retrieval.
# - Information extraction.
# - Speech processing.
#
# One of the key ideas is to be able to process text without reading it.

# %% [markdown]
# ## NLP in Python
#
# Python is builtin with a very mature regular expression library, which is the building block of natural language processing. However, more advanced tasks need different libraries. Traditionally, in the Python ecosystem the Natural Language Processing Toolkit, abbreviated as `NLTK`, has been until recently the only working choice. Now, though, there are a number of choices based on different technologies and approaches
#
# We'll a solution that appeared relatively recently, called `spaCy`, and it is much faster than NLTK since is written in a pseudo-C Python language optimized for speed called Cython.
#
# Both these libraries are complex and there exist wrappers around them to simplify their APIs. The two more popular are `Textblob` for NLTK and CLiPS Parser, and `textacy` for spaCy. In this workshop we will be using spaCy with a touch of textacy thrown in at the very end.

# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in /Users/lisa/anaconda3/lib/python3.7/site-packages (2.1.6)
# Requirement already satisfied: thinc<7.1.0,>=7.0.8 in /Users/lisa/anaconda3/lib/python3.7/site-packages (from spacy) (7.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/lisa/anaconda3/lib/python3.7/site-packages (from spacy) (2.0.2)
# Requirement already satisfied: numpy>=1.15.0 in /Users/lisa/anaconda3/lib/python3.7/site-packages (from spacy) (1.17.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/lisa/anaconda3/lib/python3.7/site-packages (from spacy) (2.22.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/lisa/anaconda3/lib/python3.7/site-packages (from spacy) (1.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.2.0 in /Users/lisa/anaconda3/lib/python3.7/site-packages (from spacy) (0.2.2)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /Users/lisa/anaconda3/lib/python3.7/site-packages (from spacy) (0.9.6)
# Requirement already satisfied: srsly<1.1.0,>=0.0.6 in /Users/lisa/anaconda3/lib/python3.7/site-packages (from spacy) (0.0.7)
# Requirement already satisfied: preshed<2.1.0,>=2.0.1 in /Users/lisa/anaconda3/lib/python3.7/site-packages (from spacy) (2.0.1)
# Requirement already satisfied: blis<0.3.0,>=0.2.2 in /Users/lisa/anaconda3/lib/python3.7/site-packages (from spacy) (0.2.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /Users/lisa/anaconda3/lib/python3.7/site-packages (from thinc<7.1.0,>=7.0.8->spacy) (4.36.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/lisa/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/lisa/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2019.9.11)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/lisa/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/lisa/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.8)

# %%
import spacy

# %%
# !python -m spacy download en
# Out:
# Requirement already satisfied: en_core_web_sm==2.1.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.1.0/en_core_web_sm-2.1.0.tar.gz#egg=en_core_web_sm==2.1.0 in /Users/lisa/anaconda3/lib/python3.7/site-packages (2.1.0)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /Users/lisa/anaconda3/lib/python3.7/site-packages/en_core_web_sm -->
# /Users/lisa/anaconda3/lib/python3.7/site-packages/spacy/data/en
# You can now load the model via spacy.load('en')

# %%
nlp = spacy.load('en')

# %%
# helper functions
import requests

def get_text(url):
    return requests.get(url).text

def get_speech(url):
    page = get_text(url)
    full_text = page.split('\n')
    return " ".join(full_text[2:])

# %%
clinton_url = "https://raw.githubusercontent.com/sul-cidr/python_workshops/master/data/clinton2000.txt"
clinton_speech = get_speech(clinton_url)
clinton_speech
# Out:
# 'Mr. Speaker, Mr. Vice President, members of Congress, honored guests, my fellow Americans:  We are fortunate to be alive at this moment in history. Never before has our nation enjoyed, at once, so much prosperity and social progress with so little internal crisis and so few external threats. Never before have we had such a blessed opportunity and, therefore, such a profound obligation to build the more perfect Union of our Founders’ dreams.  We begin the new century with over 20 million new jobs; the fastest economic growth in more than 30 years; the lowest unemployment rates in 30 years; the lowest poverty rates in 20 years; the lowest African-American and Hispanic unemployment rates on record; the first back-to-back surpluses in 42 years; and next month, America will achieve the longest period of economic growth in our entire history. We have built a new economy.  And our economic revolution has been matched by a revival of the American spirit: crime down by 20 percent, to its lowest level in 25 years; teen births down seven years in a row; adoptions up by 30 percent; welfare rolls cut in half, to their lowest levels in 30 years.  My fellow Americans, the state of our Union is the strongest it has ever been.  As always, the real credit belongs to the American people. My gratitude also goes to those of you in this chamber who have worked with us to put progress over partisanship.  Eight years ago, it was not so clear to most Americans there would be much to celebrate in the year 2000. Then our nation was gripped by economic distress, social decline, political gridlock. The title of a best-selling book asked: "America: What Went Wrong?"  In the best traditions of our nation, Americans determined to set things right. We restored the vital center, replacing outmoded ideologies with a new vision anchored in basic, enduring values: opportunity for all, responsibility from all, a community of all Americans. We reinvented government, transforming it into a catalyst for new ideas that stress both opportunity and responsibility and give our people the tools they need to solve their own problems.  With the smallest federal work force in 40 years, we turned record deficits into record surpluses and doubled our investment in education. We cut crime with 100,000 community police and the Brady law, which has kept guns out of the hands of half a million criminals.  We ended welfare as we knew it, requiring work while protecting health care and nutrition for children and investing more in child care, transportation, and housing to help their parents go to work. We’ve helped parents to succeed at home and at work with family leave, which 20 million Americans have now used to care for a newborn child or a sick loved one. We’ve engaged 150,000 young Americans in citizen service through AmeriCorps, while helping them earn money for college.  In 1992, we just had a roadmap. Today, we have results.  Even more important, America again has the confidence to dream big dreams. But we must not let this confidence drift into complacency. For we, all of us, will be judged by the dreams and deeds we pass on to our children. And on that score, we will be held to a high standard, indeed, because our chance to do good is so great.  My fellow Americans, we have crossed the bridge we built to the 21st century. Now, we must shape a 21st century American revolution of opportunity, responsibility, and community. We must be now, as we were in the beginning, a new nation.  At the dawn of the last century, Theodore Roosevelt said, "The one characteristic more essential than any other is foresight . . . it should be the growing nation with a future that takes the long look ahead." So tonight let us take our long look ahead and set great goals for our Nation.  To 21st century America, let us pledge these things: Every child will begin school ready to learn and graduate ready to succeed. Every family will be able to succeed at home and at work, and no child will be ra ...

# %%
doc = nlp(clinton_speech)

# %% [markdown]
# ## Tokenization
#
# In NLP, the act of splitting text is called tokenization, and each of the individual chunks is called a token. Therefore, we can talk about word tokenization or sentence tokenization depending on what it is that we need to divide the text into.

# %%
# word level
for token in doc:
    print(token.text)

# %%
# sentence level
for sent in doc.sents:
    print(sent)

# %%
# noun phrases
for phrase in doc.noun_chunks:
    print(phrase)

# %% [markdown]
# ## Part of Speech Tagging
#
# SpaCy also allows you to perform Part-Of-Speech tagging, a kind of grammatical chunking, out of the box.

# %%
# simple part of speech tag
for token in doc:
    print(token.text, token.pos_)
# Out:
# Mr. PROPN
# Speaker PROPN
# , PUNCT
# Mr. PROPN
# Vice PROPN
# President PROPN
# , PUNCT
# members NOUN
# of ADP
# Congress PROPN
# , PUNCT
# honored VERB
# guests NOUN
# , PUNCT
# my DET
# fellow ADJ
# Americans PROPN
# : PUNCT
#   SPACE
# We PRON
# are VERB
# fortunate ADJ
# to PART
# be VERB
# alive ADJ
# at ADP
# this DET
# moment NOUN
# in ADP
# history NOUN
# . PUNCT
# Never ADV
# before ADV
# has VERB
# our DET
# nation NOUN
# enjoyed VERB
# , PUNCT
# at ADP
# once ADV
# , PUNCT
# so ADV
# much ADJ
# prosperity NOUN
# and CCONJ
# social ADJ
# progress NOUN
# with ADP
# so ADV
# little ADJ
# internal ADJ
# crisis NOUN
# and CCONJ
# so ADV
# few ADJ
# external ADJ
# threats NOUN
# . PUNCT
# Never ADV
# before ADV
# have VERB
# we PRON
# had VERB
# such DET
# a DET
# blessed ADJ
# opportunity NOUN
# and CCONJ
# , PUNCT
# therefore ADV
# , PUNCT
# such DET
# a DET
# profound ADJ
# obligation NOUN
# to PART
# build VERB
# the DET
# more ADV
# perfect ADJ
# Union PROPN
# of ADP
# our DET
# Founders NOUN
# ’ PART
# dreams NOUN
# . PUNCT
#   SPACE
# We PRON
# begin VERB
# the DET
# new ADJ
# century NOUN
# with ADP
# over ADP
# 20 NUM
# million NUM
# new ADJ
# jobs NOUN
# ; PUNCT
# the DET
# fastest ADJ
# economic ADJ
# growth NOUN
# in ADP
# more ADJ
# than ADP
# 30 NUM
# years NOUN
# ; PUNCT
# the DET
# lowest ADJ
# unemployment NOUN
# rates NOUN
# in ADP
# 30 NUM
# years NOUN
# ; PUNCT
# the DET
# lowest ADJ
# poverty NOUN
# rates NOUN
# in ADP
# 20 NUM
# years NOUN
# ; PUNCT
# the DET
# lowest ADJ
# African ADJ
# - PUNCT
# American ADJ
# and CCONJ
# Hispanic ADJ
# unemployment NOUN
# rates NOUN
# on ADP
# record NOUN
# ; PUNCT
# the DET
# first ADJ
# back NOUN
# - PUNCT
# to ADP
# - PUNCT
# back NOUN
# surpluses NOUN
# in ADP
# 42 NUM
# years NOUN
# ; PUNCT
# and CCONJ
# next ADJ
# month NOUN
# , PUNCT
# America PROPN
# will VERB
# achieve VERB
# the DET
# longest ADJ
# period NOUN
# of ADP
# economic ADJ
# growth NOUN
# in ADP
# our DET
# entire ADJ
# history NOUN
# . PUNCT
# We PRON
# have VERB
# built VERB
# a DET
# new ADJ
# economy NOUN
# . PUNCT
#   SPACE
# And CCONJ
# our DET
# economic ADJ
# revolution NOUN
# has VERB
# been VERB
# matched VERB
# by ADP
# a DET
# revival NOUN
# of ADP
# the DET
# American ADJ
# spirit NOUN
# : PUNCT
# crime NOUN
# down PART
# by ADP
# 20 NUM
# percent NOUN
# , PUNCT
# to ADP
# its DET
# lowest ADJ
# level NOUN
# in ADP
# 25 NUM
# years NOUN
# ; PUNCT
# teen NOUN
# births NOUN
# down ADV
# seven NUM
# years NOUN
# in ADP
# a DET
# row NOUN
# ; PUNCT
# adoptions NOUN
# up PART
# by ADP
# 30 NUM
# percent NOUN
# ; PUNCT
# welfare NOUN
# rolls NOUN
# cut VERB
# in ADP
# half NOUN
# , PUNCT
# to ADP
# their DET
# lowest ADJ
# levels NOUN
# in ADP
# 30 NUM
# years NOUN
# . PUNCT
#   SPACE
# My DET
# fellow ADJ
# Americans PROPN
# , PUNCT
# the DET
# state NOUN
# of ADP
# our DET
# Union PROPN
# is VERB
# the DET
# strongest ADJ
# it PRON
# has VERB
# ever ADV
# been VERB
# . PUNCT
#   SPACE
# As ADP
# always ADV
# , PUNCT
# the DET
# real ADJ
# credit NOUN
# belongs VERB
# to ADP
# the DET
# American ADJ
# people NOUN
# . PUNCT
# My DET
# gratitude NOUN
# also ADV
# goes VERB
# to ADP
# those DET
# of ADP
# you PRON
# in ADP
# this DET
# chamber NOUN
# who PRON
# have VERB
# worked VERB
# with ADP
# us PRON
# to PART
# put VERB
# progress NOUN
# over ADP
# partisanship NOUN
# . PUNCT
#   SPACE
# Eight NUM
# years NOUN
# ago ADV
# , PUNCT
# it PRON
# was VERB
# not ADV
# so ADV
# clear ADJ
# to ADP
# most ADJ
# Americans PROPN
# there ADV
# would VERB
# be VERB
# much ADJ
# to PART
# celebrate VERB
# in ADP
# the DET
# year NOUN
# 2000 NUM
# . PUNCT
# Then ADV
# our DET
# nation NOUN
# was VERB
# gripped VERB
# by ADP
# economic ADJ
# distress NOUN
# , PUNCT
# social ADJ
# decline NOUN
# , PUNCT
# political ADJ
# gridlock NOUN
# . PUNCT
# The DET
# title NOUN
# of ADP
# a DET
# best ADV
# - PUNCT
# selling VERB
# book NOUN
# asked VERB
# : PUNCT
# " PUNCT
# America PROPN
# : PUNCT
# What PRON
# Went VERB
# Wrong ADJ
# ? PUNCT
# " PUNCT
#   SPACE
# In ADP
# the DET
# best ADJ
# traditions NOUN
# of ADP
# our DET
# nation NOUN
# , PUNCT
# Americans PROPN
# determined VERB
# to PART
# set VERB
# things NOUN
# right ADJ
# . PUNCT
# We PRON
# restored VERB
# the DET
# vital ADJ
# center NOUN
# , PUNCT
# replacing VERB
# outmoded ADJ
# ideologies NOUN
# with ADP
# a DET
# new ADJ
# vision NOUN
# anchored VERB
# in ADP
# basic ADJ
# , PUNCT
# enduring VERB
# values NOUN
# : PUNCT
# opportunity NOUN
# for ADP
# all DET
# , PUNCT
# responsibility NOUN
# from ADP
# all DET
# , PUNCT
# a DET
# community NOUN
# of ADP
# all DET
# Americans PROPN
# . PUNCT
# We PRON
# reinvented VERB
# government NOUN
# , PUNCT
# transforming VERB
# it PRON
# into ADP
# a DET
# catalyst NOUN
# for ADP
# new ADJ
# ideas NOUN
# that DET
# stress VERB
# both DET
# opportunity NOUN
# and CCONJ
# responsibility NOUN
# and CCONJ
# give VERB
# our DET
# people NOUN
# the DET
# tools NOUN
# they PRON
# need VERB
# to PART
# solve VERB
# their DET
# own ADJ
# problems NOUN
# . PUNCT
#   SPACE
# With ADP
# the DET
# smallest ADJ
# federal ADJ
# work NOUN
# force NOUN
# in ADP
# 40 NUM
# years NOUN
# , PUNCT
# we PRON
# turned VERB
# record ADJ
# deficits NOUN
# into ADP
# record NOUN
# surpluses NOUN
# and CCONJ
# doubled VERB
# our DET
# investment NOUN
# in ADP
# education NOUN
# . PUNCT
# We PRON
# cut VERB
# crime NOUN
# with ADP
# 100,000 NUM
# community NOUN
# police NOUN
# and CCONJ
# the DET
# Brady PROPN
# law NOUN
# , PUNCT
# which DET
# has VERB
# kept VERB
# guns NOUN
# out ADP
# of ADP
# the DET
# hands NOUN
# of ADP
# half DET
# a DET
# million NUM
# criminals NOUN
# . PUNCT
#   SPACE
# We PRON
# ended VERB
# welfare NOUN
# as ADP
# we PRON
# knew VERB
# it PRON
# , PUNCT
# requiring VERB
# work NOUN
# while ADP
# protecting VERB
# health NOUN
# care NOUN
# and CCONJ
# nutrition NOUN
# for ADP
# children NOUN
# and CCONJ
# investing VERB
# more ADV
# in ADP
# child NOUN
# care NOUN
# , PUNCT
# transportation NOUN
# , PUNCT
# and CCONJ
# housing NOUN
# to PART
# help VERB
# their DET
# parents NOUN
# go VERB
# to ADP
# work NOUN
# . PUNCT
# We PRON
# ’ve VERB
# helped VERB
# parents NOUN
# to PART
# succeed VERB
# at ADP
# home NOUN
# and CCONJ
# at ADP
# work NOUN
# with ADP
# family NOUN
# leave NOUN
# , PUNCT
# which DET
# 20 NUM
# million NUM
# Americans PROPN
# have VERB
# now ADV
# used VERB
# to PART
# care VERB
# for ADP
# a DET
# newborn ADJ
# child NOUN
# or CCONJ
# a DET
# sick ADJ
# loved VERB
# one NUM
# . PUNCT
# We PRON
# ’ve VERB
# engaged VERB
# 150,000 NUM
# young ADJ
# Americans PROPN
# in ADP
# citizen NOUN
# service NOUN
# through ADP
# AmeriCorps PROPN
# , PUNCT
# while ADP
# helping VERB
# them PRON
# earn VERB
# money NOUN
# for ADP
# college NOUN
# . PUNCT
#   SPACE
# In ADP
# 1992 NUM
# , PUNCT
# we PRON
# just ADV
# had VERB
# a DET
# roadmap NOUN
# . PUNCT
# Today NOUN
# , PUNCT
# we PRON
# have VERB
# results NOUN
# . PUNCT
#   SPACE
# Even ADV
# more ADV
# important ADJ
# , PUNCT
# America PROPN
# again ADV
# has VERB
# the DET
# confidence NOUN
# to PART
# dream VERB
# big ADJ
# dreams NOUN
# . PUNCT
# But CCONJ
# we PRON
# must VERB
# not ADV
# let VERB
# this DET
# confidence NOUN
# drift NOUN
# into ADP
# complacency NOUN
# . PUNCT
# For ADP
# we PRON
# , PUNCT
# all DET
# of ADP
# us PRON
# , PUNCT
# will VERB
# be VERB
# judged VERB
# by ADP
# the DET
# dreams NOUN
# and CCONJ
# deeds NOUN
# we PRON
# pass VERB
# on PART
# to ADP
# our DET
# children NOUN
# . PUNCT
# And CCONJ
# on ADP
# that DET
# score NOUN
# , PUNCT
# we PRON
# will VERB
# be VERB
# held VERB
# to ADP
# a DET
# high ADJ
# standard NOUN
# , PUNCT
# indeed ADV
# , PUNCT
# because ADP
# our DET
# chance NOUN
# to PART
# do VERB
# good NOUN
# is VERB
# so ADV
# great ADJ
# . PUNCT
#   SPACE
# My DET
# fellow ADJ
# Americans PROPN
# , PUNCT
# we PRON
# have VERB
# crossed VERB
# the DET
# bridge NOUN
# we PRON
# built VERB
# to ADP
# the DET
# 21st ADJ
# century NOUN
# . PUNCT
# Now ADV
# , PUNCT
# we PRON
# must VERB
# shape VERB
# a DET
# 21st ADJ
# century NOUN
# American ADJ
# revolution NOUN
# of ADP
# opportunity NOUN
# , PUNCT
# responsibility NOUN
# , PUNCT
# and CCONJ
# community NOUN
# . PUNCT
# We PRON
# must VERB
# be VERB
# now ADV
# , PUNCT
# as ADP
# we PRON
# were VERB
# in ADP
# the DET
# beginning NOUN
# , PUNCT
# a DET
# new ADJ
# nation NOUN
# . PUNCT
#   SPACE
# At ADP
# the DET
# dawn NOUN
# of ADP
# the DET
# last ADJ
# century NOUN
# , PUNCT
# Theodore PROPN
# Roosevelt PROPN
# said VERB
# , PUNCT
# " PUNCT
# The DET
# one NUM
# characteristic ADJ
# more ADV
# essential ADJ
# than ADP
# any DET
# other ADJ
# is VERB
# foresight ADJ
# . PUNCT
# . PUNCT
# . PUNCT
# it PRON
# should VERB
# be VERB
# the DET
# growing VERB
# nation NOUN
# with ADP
# a DET
# future NOUN
# that DET
# takes VERB
# the DET
# long ADJ
# look NOUN
# ahead ADV
# . PUNCT
# " PUNCT
# So ADV
# tonight NOUN
# let VERB
# us PRON
# take VERB
# our DET
# long ADJ
# look NOUN
# ahead ADV
# and CCONJ
# set VERB
# great ADJ
# goals NOUN
# for ADP
# our DET
# Nation PROPN
# . PUNCT
#   SPACE
# To ADP
# 21st ADJ
# century NOUN
# America PROPN
# , PUNCT
# let VERB
# us PRON
# pledge VERB
# these DET
# things NOUN
# : PUNCT
# Every DET
# child NOUN
# will VERB
# begin VERB
# school NOUN
# ready ADJ
# to PART
# learn VERB
# and CCONJ
# graduate VERB
# ready ADJ
# to PART
# succeed VERB
# . PUNCT
# Every DET
# family NOUN
# will VERB
# be VERB
# able ADJ
# to PART
# succeed VERB
# at ADP
# home NOUN
# and CCONJ
# at ADP
# work NOUN
# , PUNCT
# and CCONJ
# no DET
# child NOUN
# will VERB
# be VERB
# raised VERB
# in ADP
# poverty NOUN
# . PUNCT
# We PRON
# will VERB
# meet VERB
# the DET
# challenge NOUN
# of ADP
# the DET
# aging NOUN
# of ADP
# America PROPN
# . PUNCT
# We PRON
# will VERB
# assure VERB
# quality NOUN
# , PUNCT
# affordable ADJ
# health NOUN
# care NOUN
# , PUNCT
# at ADP
# last ADJ
# , PUNCT
# for ADP
# all DET
# Americans PROPN
# . PUNCT
# We PRON
# will VERB
# make VERB
# America PROPN
# the DET
# safest ADJ
# big ADJ
# country NOUN
# on ADP
# Earth PROPN
# . PUNCT
# We PRON
# will VERB
# pay VERB
# off PART
# our DET
# national ADJ
# debt NOUN
# for ADP
# the DET
# first ADJ
# time NOUN
# since ADP
# 1835 NUM
# . PUNCT
# * PUNCT
# We PRON
# will VERB
# bring VERB
# prosperity NOUN
# to ADP
# every DET
# American ADJ
# community NOUN
# . PUNCT
# We PRON
# will VERB
# reverse VERB
# the DET
# course NOUN
# of ADP
# climate NOUN
# change NOUN
# and CCONJ
# leave VERB
# a DET
# safer ADJ
# , PUNCT
# cleaner ADJ
# planet NOUN
# . PUNCT
# America PROPN
# will VERB
# lead VERB
# the DET
# world NOUN
# toward ADP
# shared VERB
# peace NOUN
# and CCONJ
# prosperity NOUN
# and CCONJ
# the DET
# far ADJ
# frontiers NOUN
# of ADP
# science NOUN
# and CCONJ
# technology NOUN
# . PUNCT
# And CCONJ
# we PRON
# will VERB
# become VERB
# at ADP
# last ADJ
# what PRON
# our DET
# Founders NOUN
# pledged VERB
# us PRON
# to PART
# be VERB
# so ADV
# long ADV
# ago ADV
# : PUNCT
#   SPACE
# * PUNCT
# White PROPN
# House PROPN
# correction NOUN
# . PUNCT
#   SPACE
# One NUM
# nation NOUN
# , PUNCT
# under ADP
# God PROPN
# , PUNCT
# indivisible ADJ
# , PUNCT
# with ADP
# liberty NOUN
# and CCONJ
# justice NOUN
# for ADP
# all DET
# . PUNCT
#   SPACE
# These DET
# are VERB
# great ADJ
# goals NOUN
# , PUNCT
# worthy ADJ
# of ADP
# a DET
# great ADJ
# nation NOUN
# . PUNCT
# We PRON
# will VERB
# not ADV
# reach VERB
# them PRON
# all DET
# this DET
# year NOUN
# , PUNCT
# not ADV
# even ADV
# in ADP
# this DET
# decade NOUN
# . PUNCT
# But CCONJ
# we PRON
# will VERB
# reach VERB
# them PRON
# . PUNCT
# Let VERB
# us PRON
# remember VERB
# that ADP
# the DET
# first ADJ
# American PROPN
# Revolution PROPN
# was VERB
# not ADV
# won VERB
# with ADP
# a DET
# single ADJ
# shot NOUN
# ; PUNCT
# the DET
# continent NOUN
# was VERB
# not ADV
# settled VERB
# in ADP
# a DET
# single ADJ
# year NOUN
# . PUNCT
# The DET
# lesson NOUN
# of ADP
# our DET
# history NOUN
# and CCONJ
# the DET
# lesson NOUN
# of ADP
# the DET
# last ADJ
# seven NUM
# years NOUN
# is VERB
# that ADP
# great ADJ
# goals NOUN
# are VERB
# reached VERB
# step NOUN
# by ADP
# step NOUN
# , PUNCT
# always ADV
# building VERB
# on ADP
# our DET
# progress NOUN
# , PUNCT
# always ADV
# gaining VERB
# ground NOUN
# . PUNCT
#   SPACE
# Of ADV
# course ADV
# , PUNCT
# you PRON
# ca AUX
# n’t ADV
# gain VERB
# ground NOUN
# if ADP
# you PRON
# ’re VERB
# standing VERB
# still ADV
# . PUNCT
# And CCONJ
# for ADP
# too ADV
# long ADV
# this DET
# Congress PROPN
# has VERB
# been VERB
# standing VERB
# still ADV
# on ADP
# some DET
# of ADP
# our DET
# most ADV
# pressing VERB
# national ADJ
# priorities NOUN
# . PUNCT
# So ADV
# let VERB
# ’s PROPN
# begin VERB
# tonight NOUN
# with ADP
# them PRON
# . PUNCT
#   SPACE
# Again ADV
# , PUNCT
# I PRON
# ask VERB
# you PRON
# to PART
# pass VERB
# a DET
# real ADJ
# Patients PROPN
# ’ PART
# Bill PROPN
# of ADP
# Rights PROPN
# . PUNCT
# I PRON
# ask VERB
# you PRON
# to PART
# pass VERB
# common ADJ
# - PUNCT
# sense NOUN
# gun NOUN
# safety NOUN
# legislation NOUN
# . PUNCT
# I PRON
# ask VERB
# you PRON
# to PART
# pass VERB
# campaign NOUN
# finance NOUN
# reform NOUN
# . PUNCT
# I PRON
# ask VERB
# you PRON
# to PART
# vote VERB
# up PART
# or CCONJ
# down ADV
# on ADP
# judicial ADJ
# nominations NOUN
# and CCONJ
# other ADJ
# important ADJ
# appointees NOUN
# . PUNCT
# And CCONJ
# again ADV
# , PUNCT
# I PRON
# ask VERB
# you PRON
# — PUNCT
# I PRON
# implore VERB
# you PRON
# to PART
# raise VERB
# the DET
# minimum ADJ
# wage NOUN
# . PUNCT
#   SPACE
# Now ADV
# , PUNCT
# two NUM
# years NOUN
# ago ADV
# — INTJ
# let VERB
# me PRON
# try VERB
# to PART
# balance VERB
# the DET
# seesaw NOUN
# here—[laughter]—two NOUN
# years NOUN
# ago ADV
# , PUNCT
# as ADP
# we PRON
# reached VERB
# across ADP
# party NOUN
# lines NOUN
# to PART
# reach VERB
# our DET
# first ADJ
# balanced ADJ
# budget NOUN
# , PUNCT
# I PRON
# asked VERB
# that ADP
# we PRON
# meet VERB
# our DET
# responsibility NOUN
# to ADP
# the DET
# next ADJ
# generation NOUN
# by ADP
# maintaining VERB
# our DET
# fiscal ADJ
# discipline NOUN
# . PUNCT
# Because ADP
# we PRON
# refused VERB
# to PART
# stray VERB
# from ADP
# that DET
# path NOUN
# , PUNCT
# we PRON
# are VERB
# doing VERB
# something NOUN
# that DET
# would VERB
# have VERB
# seemed VERB
# unimaginable ADJ
# seven NUM
# years NOUN
# ago ADV
# . PUNCT
# We PRON
# are VERB
# actually ADV
# paying VERB
# down PART
# the DET
# national ADJ
# debt NOUN
# . PUNCT
# Now ADV
# , PUNCT
# if ADP
# we PRON
# stay VERB
# on ADP
# this DET
# path NOUN
# , PUNCT
# we PRON
# can VERB
# pay VERB
# down PART
# the DET
# debt NOUN
# entirely ADV
# in ADP
# just ADV
# 13 NUM
# years NOUN
# now ADV
# and CCONJ
# make VERB
# America PROPN
# debt NOUN
# - PUNCT
# free ADJ
# for ADP
# the DET
# first ADJ
# time NOUN
# since ADP
# Andrew PROPN
# Jackson PROPN
# was VERB
# President PROPN
# in ADP
# 1835 NUM
# . PUNCT
#   SPACE
# In ADP
# 1993 NUM
# we PRON
# began VERB
# to PART
# put VERB
# our DET
# fiscal ADJ
# house NOUN
# in ADP
# order NOUN
# with ADP
# the DET
# Deficit PROPN
# Reduction PROPN
# Act PROPN
# , PUNCT
# which DET
# you PRON
# ’ll AUX
# all DET
# remember VERB
# won VERB
# passages NOUN
# in ADP
# both DET
# Houses NOUN
# by ADP
# just ADV
# a DET
# single ADJ
# vote NOUN
# . PUNCT
# Your DET
# former ADJ
# colleague NOUN
# , PUNCT
# my DET
# first ADJ
# Secretary PROPN
# of ADP
# the DET
# Treasury PROPN
# , PUNCT
# led VERB
# that DET
# effort NOUN
# and CCONJ
# sparked VERB
# our DET
# long ADJ
# boom NOUN
# . PUNCT
# He PRON
# ’s PROPN
# here ADV
# with ADP
# us PRON
# tonight NOUN
# . PUNCT
# Lloyd PROPN
# Bentsen PROPN
# , PUNCT
# you PRON
# have VERB
# served VERB
# America PROPN
# well INTJ
# , PUNCT
# and CCONJ
# we PRON
# thank VERB
# you PRON
# . PUNCT
#   SPACE
# Beyond ADP
# paying VERB
# off PART
# the DET
# debt NOUN
# , PUNCT
# we PRON
# must VERB
# ensure VERB
# that ADP
# the DET
# benefits NOUN
# of ADP
# debt NOUN
# reduction NOUN
# go VERB
# to ADP
# preserving VERB
# two NUM
# of ADP
# the DET
# most ADV
# important ADJ
# guarantees NOUN
# we PRON
# make VERB
# to ADP
# every DET
# American PROPN
# , PUNCT
# Social PROPN
# Security PROPN
# and CCONJ
# Medicare PROPN
# . PUNCT
# Tonight NOUN
# I PRON
# ask VERB
# you PRON
# to PART
# work VERB
# with ADP
# me PRON
# to PART
# make VERB
# a DET
# bipartisan ADJ
# downpayment NOUN
# on ADP
# Social PROPN
# Security PROPN
# reform NOUN
# by ADP
# crediting VERB
# the DET
# interest NOUN
# savings NOUN
# from ADP
# debt NOUN
# reduction NOUN
# to ADP
# the DET
# Social PROPN
# Security PROPN
# Trust PROPN
#   SPACE
# Fund PROPN
# so ADP
# that ADP
# it PRON
# will VERB
# be VERB
# strong ADJ
# and CCONJ
# sound ADJ
# for ADP
# the DET
# next ADJ
# 50 NUM
# years NOUN
# . PUNCT
#   SPACE
# But CCONJ
# this DET
# is VERB
# just ADV
# the DET
# start NOUN
# of ADP
# our DET
# journey NOUN
# . PUNCT
# We PRON
# must VERB
# also ADV
# take VERB
# the DET
# right ADJ
# steps NOUN
# toward ADP
# reaching VERB
# our DET
# great ADJ
# goals NOUN
# . PUNCT
# First ADV
# and CCONJ
# foremost ADV
# , PUNCT
# we PRON
# need VERB
# a DET
# 21st ADJ
# century NOUN
# revolution NOUN
# in ADP
# education NOUN
# , PUNCT
# guided VERB
# by ADP
# our DET
# faith NOUN
# that DET
# every DET
# single ADJ
# child NOUN
# can VERB
# learn VERB
# . PUNCT
# Because ADP
# education NOUN
# is VERB
# more ADV
# important ADJ
# than ADP
# ever ADV
# , PUNCT
# more ADJ
# than ADP
# ever ADV
# the DET
# key NOUN
# to ADP
# our DET
# children NOUN
# ’s PROPN
# future NOUN
# , PUNCT
# we PRON
# must VERB
# make VERB
# sure ADJ
# all DET
# our DET
# children NOUN
# have VERB
# that DET
# key NOUN
# . PUNCT
# That DET
# means VERB
# quality NOUN
# preschool NOUN
# and CCONJ
# after ADP
# - PUNCT
# school NOUN
# , PUNCT
# the DET
# best ADV
# trained VERB
# teachers NOUN
# in ADP
# the DET
# classroom NOUN
# , PUNCT
# and CCONJ
# college NOUN
# opportunities NOUN
# for ADP
# all DET
# our DET
# children NOUN
# . PUNCT
#   SPACE
# For ADP
# seven NUM
# years NOUN
# now ADV
# , PUNCT
# we PRON
# ’ve VERB
# worked VERB
# hard ADV
# to PART
# improve VERB
# our DET
# schools NOUN
# , PUNCT
# with ADP
# opportunity NOUN
# and CCONJ
# responsibility NOUN
# , PUNCT
# investing VERB
# more ADV
# but CCONJ
# demanding VERB
# more ADV
# in ADP
# turn NOUN
# . PUNCT
# Reading NOUN
# , PUNCT
# math NOUN
# , PUNCT
# college NOUN
# entrance NOUN
# scores NOUN
# are VERB
# up ADV
# . PUNCT
# Some DET
# of ADP
# the DET
# most ADV
# impressive ADJ
# gains NOUN
# are VERB
# in ADP
# schools NOUN
# in ADP
# very ADV
# poor ADJ
# neighborhoods NOUN
# . PUNCT
#   SPACE
# But CCONJ
# all DET
# successful ADJ
# schools NOUN
# have VERB
# followed VERB
# the DET
# same ADJ
# proven VERB
# formula NOUN
# : PUNCT
# higher ADJ
# standards NOUN
# , PUNCT
# more ADJ
# accountability NOUN
# , PUNCT
# and CCONJ
# extra ADJ
# help NOUN
# so ADP
# children NOUN
# who PRON
# need VERB
# it PRON
# can VERB
# get VERB
# it PRON
# to PART
# reach VERB
# those DET
# standards NOUN
# . PUNCT
# I PRON
# have VERB
# sent VERB
# Congress PROPN
# a DET
# reform NOUN
# plan NOUN
# based VERB
# on ADP
# that DET
# formula NOUN
# . PUNCT
# It PRON
# holds VERB
# states NOUN
# and CCONJ
# school NOUN
# districts NOUN
# accountable ADJ
# for ADP
# progress NOUN
# and CCONJ
# rewards VERB
# them PRON
# for ADP
# results NOUN
# . PUNCT
# Each DET
# year NOUN
# , PUNCT
# our DET
# national ADJ
# government NOUN
# invests VERB
# more ADJ
# than ADP
# $ SYM
# 15 NUM
# billion NUM
# in ADP
# our DET
# schools NOUN
# . PUNCT
# It PRON
# is VERB
# time NOUN
# to PART
# support VERB
# what PRON
# works VERB
# and CCONJ
# stop VERB
# supporting VERB
# what PRON
# does VERB
# n’t ADV
# . PUNCT
#   SPACE
# Now ADV
# , PUNCT
# as ADP
# we PRON
# demand VERB
# more ADJ
# from ADP
# our DET
# schools NOUN
# , PUNCT
# we PRON
# should VERB
# also ADV
# invest VERB
# more ADJ
# in ADP
# our DET
# schools NOUN
# . PUNCT
# Let VERB
# ’s PROPN
# double VERB
# our DET
# investment NOUN
# to PART
# help VERB
# states NOUN
# and CCONJ
# districts NOUN
# turn VERB
# around PART
# their DET
# worst ADJ
# performing VERB
# schools NOUN
# or CCONJ
# shut VERB
# them PRON
# down PART
# . PUNCT
# Let VERB
# ’s PROPN
# double VERB
# our DET
# investments NOUN
# in ADP
# after ADP
# - PUNCT
# school NOUN
# and CCONJ
# summer NOUN
# school NOUN
# programs NOUN
# , PUNCT
# which DET
# boost VERB
# achievement NOUN
# and CCONJ
# keep VERB
# people NOUN
# off ADP
# the DET
# streets NOUN
# and CCONJ
# out ADP
# of ADP
# trouble NOUN
# . PUNCT
# If ADP
# we PRON
# do VERB
# this DET
# , PUNCT
# we PRON
# can VERB
# give VERB
# every DET
# single ADJ
# child NOUN
# in ADP
# every DET
# failing VERB
# school NOUN
# in ADP
# America PROPN
# — PROPN
# everyone NOUN
# — PUNCT
# the DET
# chance NOUN
# to PART
# meet VERB
# high ADJ
# standards NOUN
# . PUNCT
#   SPACE
# Since ADP
# 1993 NUM
# , PUNCT
# we PRON
# ’ve VERB
# nearly ADV
# doubled VERB
# our DET
# investment NOUN
# in ADP
# Head PROPN
# Start PROPN
# and CCONJ
# improved VERB
# its DET
# quality NOUN
# . PUNCT
# Tonight NOUN
# I PRON
# ask VERB
# you PRON
# for ADP
# another DET
# $ SYM
# 1 NUM
# billion NUM
# for ADP
# Head PROPN
# Start PROPN
# , PUNCT
# the DET
# largest ADJ
# increase NOUN
# in ADP
# the DET
# history NOUN
# of ADP
# the DET
# program NOUN
# . PUNCT
#   SPACE
# We PRON
# know VERB
# that ADP
# children NOUN
# learn VERB
# best ADJ
# in ADP
# smaller ADJ
# classes NOUN
# with ADP
# good ADJ
# teachers NOUN
# . PUNCT
# For ADP
# two NUM
# years NOUN
# in ADP
# a DET
# row NOUN
# , PUNCT
# Congress PROPN
# has VERB
# supported VERB
# my DET
# plan NOUN
# to PART
# hire VERB
# 100,000 NUM
# new ADJ
# qualified ADJ
# teachers NOUN
# to PART
# lower VERB
# class NOUN
# size NOUN
# in ADP
# the DET
# early ADJ
# grades NOUN
# . PUNCT
# I PRON
# thank VERB
# you PRON
# for ADP
# that DET
# , PUNCT
# and CCONJ
# I PRON
# ask VERB
# you PRON
# to PART
# make VERB
# it PRON
# three NUM
# in ADP
# a DET
# row NOUN
# . PUNCT
# And CCONJ
# to PART
# make VERB
# sure ADJ
# all DET
# teachers NOUN
# know VERB
# the DET
# subjects NOUN
# they PRON
# teach VERB
# , PUNCT
# tonight NOUN
# I PRON
# propose VERB
# a DET
# new ADJ
# teacher NOUN
# quality NOUN
# initiative NOUN
# , PUNCT
# to PART
# recruit VERB
# more ADV
# talented ADJ
# people NOUN
# into ADP
# the DET
# classroom NOUN
# , PUNCT
# reward VERB
# good ADJ
# teachers NOUN
# for ADP
# staying VERB
# there ADV
# , PUNCT
# and CCONJ
# give VERB
# all DET
# teachers NOUN
# the DET
# training NOUN
# they PRON
# need VERB
# . PUNCT
#   SPACE
# We PRON
# know VERB
# charter NOUN
# schools NOUN
# provide VERB
# real ADJ
# public ADJ
# school NOUN
# choice NOUN
# . PUNCT
# When ADV
# I PRON
# became VERB
# President PROPN
# , PUNCT
# there ADV
# was VERB
# just ADV
# one NUM
# independent ADJ
# public ADJ
# charter NOUN
# school NOUN
# in ADP
# all DET
# America PROPN
# . PUNCT
# Today NOUN
# , PUNCT
# thanks NOUN
# to ADP
# you PRON
# , PUNCT
# there ADV
# are VERB
# 1,700 NUM
# . PUNCT
# I PRON
# ask VERB
# you PRON
# now ADV
# to PART
# help VERB
# us PRON
# meet VERB
# our DET
# goal NOUN
# of ADP
# 3,000 NUM
# charter NOUN
# schools NOUN
# by ADP
# next ADJ
# year NOUN
# . PUNCT
#   SPACE
# We PRON
# know VERB
# we PRON
# must VERB
# connect VERB
# all DET
# our DET
# classrooms NOUN
# to ADP
# the DET
# Internet NOUN
# , PUNCT
# and CCONJ
# we PRON
# ’re VERB
# getting VERB
# there ADV
# . PUNCT
# In ADP
# 1994 NUM
# , PUNCT
# only ADV
# 3 NUM
# percent NOUN
# of ADP
# our DET
# classrooms NOUN
# were VERB
# connected VERB
# . PUNCT
# Today NOUN
# , PUNCT
# with ADP
# the DET
# help NOUN
# of ADP
# the DET
# Vice PROPN
# President PROPN
# ’s PROPN
# E PROPN
# - NOUN
# rate NOUN
# program NOUN
# , PUNCT
# more ADJ
# than ADP
# half NOUN
# of ADP
# them PRON
# are VERB
# , PUNCT
# and CCONJ
# 90 NUM
# percent NOUN
# of ADP
# our DET
# schools NOUN
# have VERB
# at ADV
# least ADV
# one NUM
# Internet NOUN
# connection NOUN
# . PUNCT
# But CCONJ
# we PRON
# can AUX
# not ADV
# finish VERB
# the DET
# job NOUN
# when ADV
# a DET
# third NOUN
# of ADP
# all DET
# our DET
# schools NOUN
# are VERB
# in ADP
# serious ADJ
# disrepair NOUN
# . PUNCT
# Many ADJ
# of ADP
# them PRON
# have VERB
# walls NOUN
# and CCONJ
# wires NOUN
# so ADV
# old ADJ
# , PUNCT
# they PRON
# ’re ADV
# too ADV
# old ADJ
# for ADP
# the DET
# Internet NOUN
# . PUNCT
# So ADV
# tonight NOUN
# I PRON
# propose VERB
# to PART
# help VERB
# 5,000 NUM
# schools NOUN
# a DET
# year NOUN
# make VERB
# immediate ADJ
# and CCONJ
# urgent ADJ
# repairs NOUN
# and CCONJ
# , PUNCT
# again ADV
# , PUNCT
# to PART
# help VERB
# build VERB
# or CCONJ
# modernize VERB
# 6,000 NUM
# more ADJ
# , PUNCT
# to PART
# get VERB
# students NOUN
# out ADP
# of ADP
# trailers NOUN
# and CCONJ
# into ADP
# high ADJ
# - PUNCT
# tech NOUN
# classrooms NOUN
# . PUNCT
#   SPACE
# I PRON
# ask VERB
# all DET
# of ADP
# you PRON
# to PART
# help VERB
# me PRON
# double VERB
# our DET
# bipartisan ADJ
# GEAR PROPN
# UP PROPN
# program NOUN
# , PUNCT
# which DET
# provides VERB
# mentors NOUN
# for ADP
# disadvantaged ADJ
# young ADJ
# people NOUN
# . PUNCT
# If ADP
# we PRON
# double VERB
# it PRON
# , PUNCT
# we PRON
# can VERB
# provide VERB
# mentors NOUN
# for ADP
# 1.4 NUM
# million NUM
# of ADP
# them PRON
# . PUNCT
# Let VERB
# ’s PROPN
# also ADV
# offer VERB
# these DET
# kids NOUN
# from ADP
# disadvantaged ADJ
# backgrounds NOUN
# the DET
# same ADJ
# chance NOUN
# to PART
# take VERB
# the DET
# same ADJ
# college NOUN
# test NOUN
# - PUNCT
# prep ADJ
# courses NOUN
# wealthier ADJ
# students NOUN
# use VERB
# to PART
# boost VERB
# their DET
# test NOUN
# scores NOUN
# . PUNCT
#   SPACE
# To PART
# make VERB
# the DET
# American ADJ
# dream NOUN
# achievable ADJ
# for ADP
# all DET
# , PUNCT
# we PRON
# must VERB
# make VERB
# college NOUN
# affordable ADJ
# for ADP
# all DET
# . PUNCT
# For ADP
# seven NUM
# years NOUN
# , PUNCT
# on ADP
# a DET
# bipartisan ADJ
# basis NOUN
# , PUNCT
# we PRON
# have VERB
# taken VERB
# action NOUN
# toward ADP
# that DET
# goal NOUN
# : PUNCT
# larger ADJ
# Pell PROPN
# Grants PROPN
# , PUNCT
# more ADV
# affordable ADJ
# student NOUN
# loans NOUN
# , PUNCT
# education NOUN
# IRAs NOUN
# , PUNCT
# and CCONJ
# our DET
# HOPE PROPN
# scholarships NOUN
# , PUNCT
# which DET
# have VERB
# already ADV
# benefited VERB
# five NUM
# million NUM
# young ADJ
# people NOUN
# . PUNCT
#   SPACE
# Now ADV
# , PUNCT
# 67 NUM
# percent NOUN
# of ADP
# high ADJ
# school NOUN
# graduates NOUN
# are VERB
# going VERB
# on PART
# to ADP
# college NOUN
# . PUNCT
# That DET
# ’s PROPN
# up ADV
# 10 NUM
# percent NOUN
# since ADP
# 1993 NUM
# . PUNCT
# Yet ADV
# millions NOUN
# of ADP
# families NOUN
# still ADV
# strain VERB
# to PART
# pay VERB
# college NOUN
# tuition NOUN
# . PUNCT
# They PRON
# need VERB
# help NOUN
# . PUNCT
# So ADV
# I PRON
# propose VERB
# a DET
# landmark NOUN
# $ SYM
# 30 NUM
# billion NUM
# college NOUN
# opportunity NOUN
# tax NOUN
# cut NOUN
# , PUNCT
# a DET
# middle ADJ
# class NOUN
# tax NOUN
# deduction NOUN
# for ADP
# up ADP
# to PART
# $ SYM
# 10,000 NUM
# in ADP
# college NOUN
# tuition NOUN
# costs NOUN
# . PUNCT
# The DET
# previous ADJ
# actions NOUN
# of ADP
# this DET
# Congress PROPN
# have VERB
# already ADV
# made VERB
# two NUM
# years NOUN
# of ADP
# college NOUN
# affordable ADJ
# for ADP
# all DET
# . PUNCT
# It PRON
# ’s PROPN
# time NOUN
# make VERB
# four NUM
# years NOUN
# of ADP
# college NOUN
# affordable ADJ
# for ADP
# all DET
# . PUNCT
# If ADP
# we PRON
# take VERB
# all DET
# these DET
# steps NOUN
# , PUNCT
# we PRON
# ’ll AUX
# move VERB
# a DET
# long ADJ
# way NOUN
# toward ADP
# making VERB
# sure ADJ
# every DET
# child NOUN
# starts VERB
# school NOUN
# ready ADJ
# to PART
# learn VERB
# and CCONJ
# graduates NOUN
# ready ADJ
# to PART
# succeed VERB
# . PUNCT
#   SPACE
# We PRON
# also ADV
# need VERB
# a DET
# 21st ADJ
# century NOUN
# revolution NOUN
# to PART
# reward VERB
# work NOUN
# and CCONJ
# strengthen VERB
# families NOUN
# by ADP
# giving VERB
# every DET
# parent NOUN
# the DET
# tools NOUN
# to PART
# succeed VERB
# at ADP
# work NOUN
# and CCONJ
# at ADP
# the DET
# most ADV
# important ADJ
# work NOUN
# of ADP
# all DET
# , PUNCT
# raising VERB
# children NOUN
# . PUNCT
# That DET
# means VERB
# making VERB
# sure ADJ
# every DET
# family NOUN
# has VERB
# health NOUN
# care NOUN
# and CCONJ
# the DET
# support NOUN
# to PART
# care VERB
# for ADP
# aging VERB
# parents NOUN
# , PUNCT
# the DET
# tools NOUN
# to PART
# bring VERB
# their DET
# children NOUN
# up ADV
# right ADV
# , PUNCT
# and CCONJ
# that ADP
# no DET
# child NOUN
# grows VERB
# up PART
# in ADP
# poverty NOUN
# . PUNCT
#   SPACE
# From ADP
# my DET
# first ADJ
# days NOUN
# as ADP
# President PROPN
# , PUNCT
# we PRON
# ’ve VERB
# worked VERB
# to PART
# give VERB
# families NOUN
# better ADJ
# access NOUN
# to ADP
# better ADJ
# health NOUN
# care NOUN
# . PUNCT
# In ADP
# 1997 NUM
# , PUNCT
# we PRON
# passed VERB
# the DET
# Children PROPN
# ’s PROPN
# Health PROPN
# Insurance PROPN
# Program PROPN
# — PROPN
# CHIP PROPN
# — PUNCT
# so ADP
# that ADP
# workers NOUN
# who PRON
# do VERB
# n’t ADV
# have VERB
# coverage NOUN
# through ADP
# their DET
# employers NOUN
# at ADP
# least ADV
# can VERB
# get VERB
# it PRON
# for ADP
# their DET
# children NOUN
# . PUNCT
# So ADV
# far ADV
# , PUNCT
# we PRON
# ’ve VERB
# enrolled VERB
# two NUM
# million NUM
# children NOUN
# . PUNCT
# We PRON
# ’re VERB
# well ADV
# on ADP
# our DET
# way NOUN
# to ADP
# our DET
# goal NOUN
# of ADP
# five NUM
# million NUM
# . PUNCT
#   SPACE
# But CCONJ
# there ADV
# are VERB
# still ADV
# more ADJ
# than ADP
# 40 NUM
# million NUM
# of ADP
# our DET
# fellow ADJ
# Americans PROPN
# without ADP
# health NOUN
# insurance NOUN
# , PUNCT
# more ADJ
# than ADP
# there ADV
# were VERB
# in ADP
# 1993 NUM
# . PUNCT
# Tonight NOUN
# I PRON
# propose VERB
# that ADP
# we PRON
# follow VERB
# Vice PROPN
# President PROPN
# Gore PROPN
# ’s PROPN
# suggestion NOUN
# to PART
# make VERB
# low ADJ
# income NOUN
# parents NOUN
# eligible ADJ
# for ADP
# the DET
# insurance NOUN
# that DET
# covers VERB
# their DET
# children NOUN
# . PUNCT
# Together ADV
# with ADP
# our DET
# children NOUN
# ’s PROPN
# initiative NOUN
# — PUNCT
# think VERB
# of ADP
# this DET
# — NOUN
# together ADV
# with ADP
# our DET
# children NOUN
# ’s PROPN
# initiative NOUN
# , PUNCT
# this DET
# action NOUN
# would VERB
# enable VERB
# us PRON
# to PART
# cover VERB
# nearly ADV
# a DET
# quarter NOUN
# of ADP
# all DET
# the DET
# uninsured ADJ
# people NOUN
# in ADP
# America PROPN
# . PUNCT
#   SPACE
# Again ADV
# , PUNCT
# I PRON
# want VERB
# to PART
# ask VERB
# you PRON
# to PART
# let VERB
# people NOUN
# between ADP
# the DET
# ages NOUN
# of ADP
# 55 NUM
# and CCONJ
# 65 NUM
# , PUNCT
# the DET
# fastest ADJ
# growing VERB
# group NOUN
# of ADP
# uninsured ADJ
# , PUNCT
# buy VERB
# into ADP
# Medicare PROPN
# . PUNCT
# And CCONJ
# this DET
# year NOUN
# I PRON
# propose VERB
# to PART
# give VERB
# them PRON
# a DET
# tax NOUN
# credit NOUN
# to PART
# make VERB
# that DET
# choice NOUN
# an DET
# affordable ADJ
# one NOUN
# . PUNCT
# I PRON
# hope VERB
# you PRON
# will VERB
# support VERB
# that DET
# , PUNCT
# as ADV
# well ADV
# . PUNCT
#   SPACE
# When ADV
# the DET
# baby NOUN
# boomers NOUN
# retire VERB
# , PUNCT
# Medicare PROPN
# will VERB
# be VERB
# faced VERB
# with ADP
# caring VERB
# for ADP
# twice DET
# as ADV
# many ADJ
# of ADP
# our DET
# citizens NOUN
# ; PUNCT
# yet ADV
# , PUNCT
# it PRON
# is VERB
# far ADV
# from ADP
# ready ADJ
# to PART
# do VERB
# so ADV
# . PUNCT
# My DET
# generation NOUN
# must VERB
# not ADV
# ask VERB
# our DET
# children NOUN
# ’s PROPN
# generation NOUN
# to PART
# shoulder VERB
# our DET
# burden NOUN
# . PUNCT
# We PRON
# simply ADV
# must VERB
# act VERB
# now ADV
# to PART
# strengthen VERB
# and CCONJ
# modernize VERB
# Medicare PROPN
# . PUNCT
#   SPACE
# My DET
# budget NOUN
# includes VERB
# a DET
# comprehensive ADJ
# plan NOUN
# to PART
# reform VERB
# Medicare PROPN
# , PUNCT
# to PART
# make VERB
# it PRON
# more ADV
# efficient ADJ
# and CCONJ
# more ADV
# competitive ADJ
# . PUNCT
# And CCONJ
# it PRON
# dedicates VERB
# nearly ADV
# $ SYM
# 400 NUM
# billion NUM
# of ADP
# our DET
# budget NOUN
# surplus NOUN
# to PART
# keep VERB
# Medicare PROPN
# solvent NOUN
# past ADP
# 2025 NUM
# . PUNCT
# And CCONJ
# at ADP
# long ADV
# last ADV
# , PUNCT
# it PRON
# also ADV
# provides VERB
# funds NOUN
# to PART
# give VERB
# every DET
# senior ADJ
# a DET
# voluntary ADJ
# choice NOUN
# of ADP
# affordable ADJ
# coverage NOUN
# for ADP
# prescription NOUN
# drugs NOUN
# . PUNCT
#   SPACE
# Lifesaving VERB
# drugs NOUN
# are VERB
# an DET
# indispensable ADJ
# part NOUN
# of ADP
# modern ADJ
# medicine NOUN
# . PUNCT
# No DET
# one NOUN
# creating VERB
# a DET
# Medicare PROPN
# program NOUN
# today NOUN
# would VERB
# even ADV
# think VERB
# of ADP
# excluding VERB
# coverage NOUN
# for ADP
# prescription NOUN
# drugs NOUN
# . PUNCT
# Yet ADV
# more ADJ
# than ADP
# three NUM
# in ADP
# five NUM
# of ADP
# our DET
# seniors NOUN
# now ADV
# lack VERB
# dependable ADJ
# drug NOUN
# coverage NOUN
# which DET
# can VERB
# lengthen VERB
# and CCONJ
# enrich VERB
# their DET
# lives NOUN
# . PUNCT
# Millions NOUN
# of ADP
# older ADJ
# Americans PROPN
# , PUNCT
# who PRON
# need VERB
# prescription NOUN
# drugs VERB
# the DET
# most ADV
# , PUNCT
# pay VERB
# the DET
# highest ADJ
# prices NOUN
# for ADP
# them PRON
# . PUNCT
# In ADP
# good ADJ
# conscience NOUN
# , PUNCT
# we PRON
# can AUX
# not ADV
# let VERB
# another DET
# year NOUN
# pass VERB
# without ADP
# extending VERB
# to ADP
# all DET
# our DET
# seniors NOUN
# this DET
# lifeline NOUN
# of ADP
# affordable ADJ
# prescription NOUN
# drugs NOUN
# . PUNCT
#   SPACE
# Record PROPN
# numbers NOUN
# of ADP
# Americans PROPN
# are VERB
# providing VERB
# for ADP
# aging VERB
# or CCONJ
# ailing VERB
# loved ADJ
# ones NOUN
# at ADP
# home NOUN
# . PUNCT
# It PRON
# ’s VERB
# a DET
# loving NOUN
# but CCONJ
# a DET
# difficult ADJ
# and CCONJ
# often ADV
# very ADV
# expensive ADJ
# choice NOUN
# . PUNCT
# Last ADJ
# year NOUN
# , PUNCT
# I PRON
# proposed VERB
# a DET
# $ SYM
# 1,000 NUM
# tax NOUN
# credit NOUN
# for ADP
# long ADJ
# - PUNCT
# term NOUN
# care NOUN
# . PUNCT
# Frankly ADV
# , PUNCT
# it PRON
# was VERB
# n’t ADV
# enough ADV
# . PUNCT
# This DET
# year NOUN
# , PUNCT
# let VERB
# ’s PROPN
# triple VERB
# it PRON
# to ADP
# $ SYM
# 3,000 NUM
# . PUNCT
# But CCONJ
# this DET
# year NOUN
# , PUNCT
# let VERB
# ’s PROPN
# pass VERB
# it PRON
# . PUNCT
#   SPACE
# We PRON
# also ADV
# have VERB
# to PART
# make VERB
# needed VERB
# investments NOUN
# to PART
# expand VERB
# access NOUN
# to ADP
# mental ADJ
# health NOUN
# care NOUN
# . PUNCT
# I PRON
# want VERB
# to PART
# take VERB
# a DET
# moment NOUN
# to PART
# thank VERB
# the DET
# person NOUN
# who PRON
# led VERB
# our DET
# first ADJ
# White PROPN
# House PROPN
# Conference PROPN
# on ADP
# Mental PROPN
# Health PROPN
# last ADJ
# year NOUN
# and CCONJ
# who PRON
# for ADP
# seven NUM
# years NOUN
# has VERB
# led VERB
# all DET
# our DET
# efforts NOUN
# to PART
# break VERB
# down PART
# the DET
# barriers NOUN
# to ADP
# decent ADJ
# treatment NOUN
# of ADP
# people NOUN
# with ADP
# mental ADJ
# illness NOUN
# . PUNCT
# Thank VERB
# you PRON
# , PUNCT
# Tipper PROPN
# Gore PROPN
# . PUNCT
#   SPACE
# Taken VERB
# together ADV
# , PUNCT
# these DET
# proposals NOUN
# would VERB
# mark VERB
# the DET
# largest ADJ
# investment NOUN
# in ADP
# health NOUN
# care NOUN
# in ADP
# the DET
# 35 NUM
# years NOUN
# since ADP
# Medicare PROPN
# was VERB
# created VERB
# — PUNCT
# the DET
# largest ADJ
# investment NOUN
# in ADP
# 35 NUM
# years NOUN
# . PUNCT
# That DET
# would VERB
# be VERB
# a DET
# big ADJ
# step NOUN
# toward ADP
# assuring VERB
# quality NOUN
# health NOUN
# care NOUN
# for ADP
# all DET
# Americans PROPN
# , PUNCT
# young ADJ
# and CCONJ
# old ADJ
# . PUNCT
# And CCONJ
# I PRON
# ask VERB
# you PRON
# to PART
# embrace VERB
# them PRON
# and CCONJ
# pass VERB
# them PRON
# . PUNCT
#   SPACE
# We PRON
# must VERB
# also ADV
# make VERB
# investments NOUN
# that DET
# reward VERB
# work NOUN
# and CCONJ
# support NOUN
# families NOUN
# . PUNCT
# Nothing NOUN
# does VERB
# that DET
# better ADJ
# than ADP
# the DET
# earned VERB
# - PUNCT
# income NOUN
# tax NOUN
# credit NOUN
# , PUNCT
# the DET
# EITC PROPN
# . PUNCT
# The DET
# " PUNCT
# E NOUN
# " PUNCT
# in ADP
# the DET
# EITC PROPN
# is VERB
# about ADP
# earning VERB
# , PUNCT
# working VERB
# , PUNCT
# taking VERB
# responsibility NOUN
# , PUNCT
# and CCONJ
# being VERB
# rewarded VERB
# for ADP
# it PRON
# . PUNCT
# In ADP
# my DET
# very ADV
# first ADJ
# address NOUN
# to ADP
# you PRON
# , PUNCT
# I PRON
# asked VERB
# Congress PROPN
# to PART
# greatly ADV
# expand VERB
# this DET
# credit NOUN
# , PUNCT
# and CCONJ
# you PRON
# did VERB
# . PUNCT
# As ADP
# a DET
# result NOUN
# , PUNCT
# in ADP
# 1998 NUM
# alone ADV
# , PUNCT
# the DET
# EITC PROPN
# helped VERB
# more ADJ
# than ADP
# 4.3 NUM
# million NUM
# Americans PROPN
# work VERB
# their DET
# way NOUN
# out ADP
# of ADP
# poverty NOUN
# toward ADP
# the DET
# middle ADJ
# class NOUN
# . PUNCT
# That DET
# ’s PROPN
# double DET
# the DET
# number NOUN
# in ADP
# 1993 NUM
# . PUNCT
#   SPACE
# Tonight NOUN
# I PRON
# propose VERB
# another DET
# major ADJ
# expansion NOUN
# of ADP
# the DET
# EITC NOUN
# : PUNCT
# to PART
# reduce VERB
# the DET
# marriage NOUN
# penalty NOUN
# , PUNCT
# to PART
# make VERB
# sure ADJ
# it PRON
# rewards VERB
# marriage NOUN
# as ADP
# it PRON
# rewards VERB
# work VERB
# , PUNCT
# and CCONJ
# also ADV
# to PART
# expand VERB
# the DET
# tax NOUN
# credit NOUN
# for ADP
# families NOUN
# that DET
# have VERB
# more ADJ
# than ADP
# two NUM
# children NOUN
# . PUNCT
# It PRON
# punishes VERB
# people NOUN
# with ADP
# more ADJ
# than ADP
# two NUM
# children NOUN
# today NOUN
# . PUNCT
# Our DET
# proposal NOUN
# would VERB
# allow VERB
# families NOUN
# with ADP
# three NUM
# or CCONJ
# more ADJ
# children NOUN
# to PART
# get VERB
# up ADP
# to PART
# $ SYM
# 1,100 NUM
# more ADJ
# in ADP
# tax NOUN
# relief NOUN
# . PUNCT
# These DET
# are VERB
# working VERB
# families NOUN
# ; PUNCT
# their DET
# children NOUN
# should VERB
# not ADV
# be VERB
# in ADP
# poverty NOUN
# . PUNCT
#   SPACE
# We PRON
# also ADV
# ca AUX
# n’t ADV
# reward VERB
# work NOUN
# and CCONJ
# family NOUN
# unless ADP
# men NOUN
# and CCONJ
# women NOUN
# get VERB
# equal ADJ
# pay NOUN
# for ADP
# equal ADJ
# work NOUN
# . PUNCT
# Today NOUN
# the DET
# female ADJ
# unemployment NOUN
# rate NOUN
# is VERB
# the DET
# lowest ADJ
# it PRON
# has VERB
# been VERB
# in ADP
# 46 NUM
# years NOUN
# . PUNCT
# Yet ADV
# , PUNCT
# women NOUN
# still ADV
# only ADV
# earn VERB
# about ADV
# 75 NUM
# cents NOUN
# for ADP
# every DET
# dollar NOUN
# men NOUN
# earn VERB
# . PUNCT
# We PRON
# must VERB
# do VERB
# better ADV
# , PUNCT
# by ADP
# providing VERB
# the DET
# resources NOUN
# to PART
# enforce VERB
# present ADJ
# equal ADJ
# pay NOUN
# laws NOUN
# , PUNCT
# training VERB
# more ADJ
# women NOUN
# for ADP
# high ADV
# - PUNCT
# paying VERB
# , PUNCT
# high ADJ
# - PUNCT
# tech NOUN
# jobs NOUN
# , PUNCT
# and CCONJ
# passing VERB
# the DET
# " PUNCT
# Paycheck PROPN
# Fairness PROPN
# Act PROPN
# . PUNCT
# " PUNCT
#   SPACE
# Many ADJ
# working VERB
# parents NOUN
# spend VERB
# up PART
# to ADP
# a DET
# quarter NOUN
# — PUNCT
# a DET
# quarter NOUN
# — X
# of ADP
# their DET
# income NOUN
# on ADP
# child NOUN
# care NOUN
# . PUNCT
# Last ADJ
# year NOUN
# , PUNCT
# we PRON
# helped VERB
# parents NOUN
# provide VERB
# child NOUN
# care NOUN
# for ADP
# about ADV
# two NUM
# million NUM
# children NOUN
# . PUNCT
# My DET
# child NOUN
# care VERB
# initiative NOUN
# before ADP
# you PRON
# now ADV
# , PUNCT
# along ADP
# with ADP
# funds NOUN
# already ADV
# secured VERB
# in ADP
# welfare NOUN
# reform NOUN
# , PUNCT
# would VERB
# make VERB
# child NOUN
# care NOUN
# better ADV
# , PUNCT
# safer ADJ
# , PUNCT
# and CCONJ
# more ADV
# affordable ADJ
# for ADP
# another DET
# 400,000 NUM
# children NOUN
# . PUNCT
# I PRON
# ask VERB
# you PRON
# to PART
# pass VERB
# that DET
# . PUNCT
# They PRON
# need VERB
# it PRON
# out ADV
# there ADV
# . PUNCT
#   SPACE
# For ADP
# hard ADV
# - PUNCT
# pressed VERB
# middle ADJ
# income NOUN
# families NOUN
# , PUNCT
# we PRON
# should VERB
# also ADV
# expand VERB
# the DET
# child NOUN
# care NOUN
# tax NOUN
# credit NOUN
# . PUNCT
# And CCONJ
# I PRON
# believe VERB
# strongly ADV
# we PRON
# should VERB
# take VERB
# the DET
# next ADJ
# big ADJ
# step NOUN
# and CCONJ
# make VERB
# that DET
# tax NOUN
# credit NOUN
# refundable ADJ
# for ADP
# low ADJ
# income NOUN
# families NOUN
# . PUNCT
# For ADP
# people NOUN
# making VERB
# under ADP
# $ SYM
# 30,000 NUM
# a DET
# year NOUN
# , PUNCT
# that DET
# could VERB
# mean VERB
# up ADP
# to PART
# $ SYM
# 2,400 NUM
# for ADP
# child NOUN
# care NOUN
# costs NOUN
# . PUNCT
# You PRON
# know VERB
# , PUNCT
# we PRON
# all DET
# say VERB
# we PRON
# ’re VERB
# pro ADJ
# - ADJ
# work ADJ
# and CCONJ
# pro ADJ
# - ADJ
# family NOUN
# . PUNCT
# Passing VERB
# this DET
# proposal NOUN
# would VERB
# prove VERB
# it PRON
# . PUNCT
#   SPACE
# Ten NUM
# of ADP
# millions NOUN
# of ADP
# Americans PROPN
# live VERB
# from ADP
# paycheck NOUN
# to ADP
# paycheck NOUN
# . PUNCT
# As ADV
# hard ADV
# as ADP
# they PRON
# work VERB
# , PUNCT
# they PRON
# still ADV
# do VERB
# n’t ADV
# have VERB
# the DET
# opportunity NOUN
# to PART
# save VERB
# . PUNCT
# Too ADV
# few ADJ
# can VERB
# make VERB
# use NOUN
# of ADP
# IRAs NOUN
# and CCONJ
# 401k NOUN
# plans NOUN
# . PUNCT
# We PRON
# should VERB
# do VERB
# more ADJ
# to PART
# help VERB
# all DET
# working VERB
# families NOUN
# save VERB
# and CCONJ
# accumulate VERB
# wealth NOUN
# . PUNCT
# That DET
# ’s PROPN
# the DET
# idea NOUN
# behind ADP
# the DET
# Individual PROPN
# Development PROPN
# Accounts PROPN
# , PUNCT
# the DET
# IDAs NOUN
# . PUNCT
# I PRON
# ask VERB
# you PRON
# to PART
# take VERB
# that DET
# idea NOUN
# to ADP
# a DET
# new ADJ
# level NOUN
# , PUNCT
# with ADP
# new ADJ
# retirement NOUN
# savings NOUN
# accounts NOUN
# that DET
# enable VERB
# every DET
# low ADJ
# and CCONJ
# moderate ADJ
# income NOUN
# family NOUN
# in ADP
# America PROPN
# to PART
# save VERB
# for ADP
# retirement NOUN
# , PUNCT
# a DET
# first ADJ
# home NOUN
# , PUNCT
# a DET
# medical ADJ
# emergency NOUN
# , PUNCT
# or CCONJ
# a DET
# college NOUN
# education NOUN
# . PUNCT
# I PRON
# propose VERB
# to PART
# match VERB
# their DET
# contributions NOUN
# , PUNCT
# however ADV
# small ADJ
# , PUNCT
# dollar NOUN
# for ADP
# dollar NOUN
# , PUNCT
# every DET
# year NOUN
# they PRON
# save VERB
# . PUNCT
# And CCONJ
# I PRON
# propose VERB
# to PART
# give VERB
# a DET
# major ADJ
# new ADJ
# tax NOUN
# credit NOUN
# to ADP
# any DET
# small ADJ
# business NOUN
# that DET
# will VERB
# provide VERB
# a DET
# meaningful ADJ
# pension NOUN
# to ADP
# its DET
# workers NOUN
# . PUNCT
# Those DET
# people NOUN
# ought VERB
# to PART
# have VERB
# retirement NOUN
# as ADV
# well ADV
# as ADP
# the DET
# rest NOUN
# of ADP
# us PRON
# . PUNCT
#   SPACE
# Nearly ADV
# one NUM
# in ADP
# three NUM
# American ADJ
# children NOUN
# grows VERB
# up PART
# without ADP
# a DET
# father NOUN
# . PUNCT
# These DET
# children NOUN
# are VERB
# five NUM
# times NOUN
# more ADV
# likely ADJ
# to PART
# live VERB
# in ADP
# poverty NOUN
# than ADP
# children NOUN
# with ADP
# both DET
# parents NOUN
# at ADP
# home NOUN
# . PUNCT
# Clearly ADV
# , PUNCT
# demanding VERB
# and CCONJ
# supporting VERB
# responsible ADJ
# fatherhood NOUN
# is VERB
# critical ADJ
# to ADP
# lifting VERB
# all DET
# our DET
# children NOUN
# out ADP
# of ADP
# poverty NOUN
# . PUNCT
# We PRON
# ’ve VERB
# doubled VERB
# child NOUN
# support NOUN
# collections NOUN
# since ADP
# 1992 NUM
# . PUNCT
# And CCONJ
# I PRON
# ’m VERB
# proposing VERB
# to ADP
# you PRON
# tough ADJ
# new ADJ
# measures NOUN
# to PART
# hold VERB
# still ADV
# more ADJ
# fathers NOUN
# responsible ADJ
# . PUNCT
#   SPACE
# But CCONJ
# we PRON
# should VERB
# recognize VERB
# that ADP
# a DET
# lot NOUN
# of ADP
# fathers NOUN
# want VERB
# to PART
# do VERB
# right NOUN
# by ADP
# their DET
# children NOUN
# but CCONJ
# need VERB
# help NOUN
# to PART
# do VERB
# it PRON
# . PUNCT
# Carlos PROPN
# Rosas PROPN
# of ADP
# St. PROPN
# Paul PROPN
# , PUNCT
# Minnesota PROPN
# , PUNCT
# wanted VERB
# to PART
# do VERB
# right NOUN
# by ADP
# his DET
# son NOUN
# , PUNCT
# and CCONJ
# he PRON
# got VERB
# the DET
# help NOUN
# to PART
# do VERB
# it PRON
# . PUNCT
# Now ADV
# he PRON
# ’s PROPN
# got VERB
# a DET
# good ADJ
# job NOUN
# , PUNCT
# and CCONJ
# he PRON
# supports VERB
# his DET
# little ADJ
# boy NOUN
# . PUNCT
# My DET
# budget NOUN
# will VERB
# help VERB
# 40,000 NUM
# more ADJ
# fathers NOUN
# make VERB
# the DET
# same ADJ
# choices NOUN
# Carlos PROPN
# Rosas PROPN
# did VERB
# . PUNCT
# I PRON
# thank VERB
# him PRON
# for ADP
# being VERB
# here ADV
# tonight NOUN
# . PUNCT
# Stand VERB
# up PART
# , PUNCT
# Carlos PROPN
# . PUNCT
# [ PUNCT
# Applause NOUN
# ] PUNCT
# Thank VERB
# you PRON
# . PUNCT
#   SPACE
# If ADP
# there ADV
# is VERB
# any DET
# single ADJ
# issue NOUN
# on ADP
# which DET
# we PRON
# should VERB
# be VERB
# able ADJ
# to PART
# reach VERB
# across ADP
# party NOUN
# lines NOUN
# , PUNCT
# it PRON
# is VERB
# in ADP
# our DET
# common ADJ
# commitment NOUN
# to PART
# reward VERB
# work NOUN
# and CCONJ
# strengthen VERB
# families NOUN
# . PUNCT
# Just ADV
# remember VERB
# what PRON
# we PRON
# did VERB
# last ADJ
# year NOUN
# . PUNCT
# We PRON
# came VERB
# together ADV
# to PART
# help VERB
# people NOUN
# with ADP
# disabilities NOUN
# keep VERB
# their DET
# health NOUN
# insurance NOUN
# when ADV
# they PRON
# go VERB
# to ADP
# work NOUN
# . PUNCT
# And CCONJ
# I PRON
# thank VERB
# you PRON
# for ADP
# that DET
# . PUNCT
# Thanks NOUN
# to ADP
# overwhelming ADJ
# bipartisan ADJ
# support NOUN
# from ADP
# this DET
# Congress PROPN
# , PUNCT
# we PRON
# have VERB
# improved VERB
# foster ADJ
# care NOUN
# . PUNCT
# We PRON
# ’ve VERB
# helped VERB
# those DET
# young ADJ
# people NOUN
# who PRON
# leave VERB
# it PRON
# when ADV
# they PRON
# turn VERB
# 18 NUM
# , PUNCT
# and CCONJ
# we PRON
# have VERB
# dramatically ADV
# increased VERB
# the DET
# number NOUN
# of ADP
# foster ADJ
# care NOUN
# children NOUN
# going VERB
# into ADP
# adoptive ADJ
# homes NOUN
# . PUNCT
# I PRON
# thank VERB
# all DET
# of ADP
# you PRON
# for ADP
# all DET
# of ADP
# that DET
# . PUNCT
#   SPACE
# Of ADV
# course ADV
# , PUNCT
# I PRON
# am VERB
# forever ADV
# grateful ADJ
# to ADP
# the DET
# person NOUN
# who PRON
# has VERB
# led VERB
# our DET
# efforts NOUN
# from ADP
# the DET
# beginning NOUN
# and CCONJ
# who PRON
# ’s PROPN
# worked VERB
# so ADV
# tirelessly ADV
# for ADP
# children NOUN
# and CCONJ
# families NOUN
# for ADP
# 30 NUM
# years NOUN
# now ADV
# , PUNCT
# my DET
# wife NOUN
# , PUNCT
# Hillary PROPN
# , PUNCT
# and CCONJ
# I PRON
# thank VERB
# her PRON
# . PUNCT
#   SPACE
# If ADP
# we PRON
# take VERB
# the DET
# steps NOUN
# just ADV
# discussed VERB
# , PUNCT
# we PRON
# can VERB
# go VERB
# a DET
# long ADJ
# , PUNCT
# long ADJ
# way NOUN
# toward ADP
# empowering VERB
# parents NOUN
# to PART
# succeed VERB
# at ADP
# home NOUN
# and CCONJ
# at ADP
# work NOUN
# and CCONJ
# ensuring VERB
# that ADP
# no DET
# child NOUN
# is VERB
# raised VERB
# in ADP
# poverty NOUN
# . PUNCT
# We PRON
# can VERB
# make VERB
# these DET
# vital ADJ
# investments NOUN
# in ADP
# health NOUN
# care NOUN
# , PUNCT
# education NOUN
# , PUNCT
# support NOUN
# for ADP
# working VERB
# families NOUN
# , PUNCT
# and CCONJ
# still ADV
# offer VERB
# tax NOUN
# cuts NOUN
# to PART
# help VERB
# pay VERB
# for ADP
# college NOUN
# , PUNCT
# for ADP
# retirement NOUN
# , PUNCT
# to PART
# care VERB
# for ADP
# aging VERB
# parents NOUN
# , PUNCT
# to PART
# reduce VERB
# the DET
# marriage NOUN
# penalty NOUN
# . PUNCT
# We PRON
# can VERB
# do VERB
# these DET
# things NOUN
# without ADP
# forsaking VERB
# the DET
# path NOUN
# of ADP
# fiscal ADJ
# discipline NOUN
# that DET
# got VERB
# us PRON
# to ADP
# this DET
# point NOUN
# here ADV
# tonight NOUN
# . PUNCT
# Indeed ADV
# , PUNCT
# we PRON
# must VERB
# make VERB
# these DET
# investments NOUN
# and CCONJ
# these DET
# tax NOUN
# cuts NOUN
# in ADP
# the DET
# context NOUN
# of ADP
# a DET
# balanced ADJ
# budget NOUN
# that DET
# strengthens VERB
# and CCONJ
# extends VERB
# the DET
# life NOUN
# of ADP
# Social PROPN
# Security PROPN
# and CCONJ
# Medicare PROPN
# and CCONJ
# pays VERB
# down PART
# the DET
# national ADJ
# debt NOUN
# . PUNCT
#   SPACE
# Crime PROPN
# in ADP
# America PROPN
# has VERB
# dropped VERB
# for ADP
# the DET
# past ADJ
# seven NUM
# years NOUN
# — X
# that ADP
# ’s PROPN
# the DET
# longest ADJ
# decline NOUN
# on ADP
# record— NUM
# thanks NOUN
# to ADP
# a DET
# national ADJ
# consensus NOUN
# we PRON
# helped VERB
# to PART
# forge VERB
# on ADP
# community NOUN
# police NOUN
# , PUNCT
# sensible ADJ
# gun NOUN
# safety NOUN
# laws NOUN
# , PUNCT
# and CCONJ
# effective ADJ
# prevention NOUN
# . PUNCT
# But CCONJ
# nobody NOUN
# , PUNCT
# nobody NOUN
# here ADV
# , PUNCT
# nobody NOUN
# in ADP
# America PROPN
# believes VERB
# we PRON
# ’re VERB
# safe ADJ
# enough ADV
# . PUNCT
# So ADV
# again ADV
# , PUNCT
# I PRON
# ask VERB
# you PRON
# to PART
# set VERB
# a DET
# higher ADJ
# goal NOUN
# . PUNCT
# Let VERB
# ’s PROPN
# make VERB
# this DET
# country NOUN
# the DET
# safest ADJ
# big ADJ
# country NOUN
# in ADP
# the DET
# world NOUN
# . PUNCT
#   SPACE
# Last ADJ
# fall NOUN
# , PUNCT
# Congress PROPN
# supported VERB
# my DET
# plan NOUN
# to PART
# hire VERB
# , PUNCT
# in ADP
# addition NOUN
# to ADP
# the DET
# 100,000 NUM
# community NOUN
# police NOUN
# we PRON
# ’ve VERB
# already ADV
# funded VERB
# , PUNCT
# 50,000 NUM
# more ADJ
# , PUNCT
# concentrated VERB
# in ADP
# high ADJ
# - PUNCT
# crime NOUN
# neighborhoods NOUN
# . PUNCT
# I PRON
# ask VERB
# your DET
# continued ADJ
# support NOUN
# for ADP
# that DET
# . PUNCT
#   SPACE
# Soon ADV
# after ADP
# the DET
# Columbine PROPN
# tragedy NOUN
# , PUNCT
# Congress PROPN
# considered VERB
# commonsense NOUN
# gun NOUN
# legislation NOUN
# , PUNCT
# to PART
# require VERB
# Brady PROPN
# background NOUN
# checks NOUN
# at ADP
# the DET
# gun NOUN
# shows NOUN
# , PUNCT
# child NOUN
# safety NOUN
# locks NOUN
# for ADP
# new ADJ
# handguns NOUN
# , PUNCT
# and CCONJ
# a DET
# ban NOUN
# on ADP
# the DET
# importation NOUN
# of ADP
# large ADJ
# capacity NOUN
# ammunition NOUN
# clips NOUN
# . PUNCT
# With ADP
# courage NOUN
# and CCONJ
# a DET
# tie NOUN
# - PUNCT
# breaking VERB
# vote NOUN
# by ADP
# the DET
# Vice PROPN
# President—[laughter PROPN
# ] PUNCT
# —the DET
# Senate PROPN
# faced VERB
# down PART
# the DET
# gun NOUN
# lobby NOUN
# , PUNCT
# stood VERB
# up PART
# for ADP
# the DET
# American ADJ
# people NOUN
# , PUNCT
# and CCONJ
# passed VERB
# this DET
# legislation NOUN
# . PUNCT
# But CCONJ
# the DET
# House PROPN
# failed VERB
# to PART
# follow VERB
# suit NOUN
# . PUNCT
#   SPACE
# Now ADV
# , PUNCT
# we PRON
# have VERB
# all ADV
# seen VERB
# what PRON
# happens VERB
# when ADV
# guns NOUN
# fall VERB
# into ADP
# the DET
# wrong ADJ
# hands NOUN
# . PUNCT
# Daniel PROPN
# Mauser PROPN
# was VERB
# only ADV
# 15 NUM
# years NOUN
# old ADJ
# when ADV
# he PRON
# was VERB
# gunned VERB
# down PART
# at ADP
# Columbine PROPN
# . PUNCT
# He PRON
# was VERB
# an DET
# amazing ADJ
# kid NOUN
# , PUNCT
# a DET
# straight ADJ
# - PUNCT
# A NOUN
# student NOUN
# , PUNCT
# a DET
# good ADJ
# skier NOUN
# . PUNCT
# Like ADP
# all DET
# parents NOUN
# who PRON
# lose VERB
# their DET
# children NOUN
# , PUNCT
# his DET
# father NOUN
# , PUNCT
# Tom PROPN
# , PUNCT
# has VERB
# borne VERB
# unimaginable ADJ
# grief NOUN
# . PUNCT
# Somehow ADV
# he PRON
# has VERB
# found VERB
# the DET
# strength NOUN
# to PART
# honor VERB
# his DET
# son NOUN
# by ADP
# transforming VERB
# his DET
# grief NOUN
# into ADP
# action NOUN
# . PUNCT
# Earlier ADV
# this DET
# month NOUN
# , PUNCT
# he PRON
# took VERB
# a DET
# leave NOUN
# of ADP
# absence NOUN
# from ADP
# his DET
# job NOUN
# to PART
# fight VERB
# for ADP
# tougher ADJ
# gun NOUN
# safety NOUN
# laws NOUN
# . PUNCT
# I PRON
# pray VERB
# that ADP
# his DET
# courage NOUN
# and CCONJ
# wisdom NOUN
# will VERB
# at ADP
# long ADV
# last ADJ
# move NOUN
# this DET
# Congress PROPN
# to PART
# make VERB
# commonsense NOUN
# gun NOUN
# legislation NOUN
# the DET
# very ADV
# next ADJ
# order NOUN
# of ADP
# business NOUN
# . PUNCT
# Tom PROPN
# Mauser PROPN
# , PUNCT
# stand VERB
# up PART
# . PUNCT
# We PRON
# thank VERB
# you PRON
# for ADP
# being VERB
# here ADV
# tonight NOUN
# . PUNCT
# Tom PROPN
# . PUNCT
# Thank VERB
# you PRON
# , PUNCT
# Tom PROPN
# . PUNCT
# [ PUNCT
# Applause NOUN
# ] PUNCT
#   SPACE
# We PRON
# must VERB
# strengthen VERB
# our DET
# gun NOUN
# laws NOUN
# and CCONJ
# enforce VERB
# those DET
# already ADV
# on ADP
# the DET
# books NOUN
# better ADV
# . PUNCT
# Federal ADJ
# gun NOUN
# crime NOUN
# prosecutions NOUN
# are VERB
# up ADV
# 16 NUM
# percent NOUN
# since ADP
# I PRON
# took VERB
# office NOUN
# . PUNCT
# But CCONJ
# we PRON
# must VERB
# do VERB
# more ADJ
# . PUNCT
# I PRON
# propose VERB
# to PART
# hire VERB
# more ADV
# federal ADJ
# and CCONJ
# local ADJ
# gun NOUN
# prosecutors NOUN
# and CCONJ
# more ADJ
# ATF PROPN
# agents NOUN
# to PART
# crack VERB
# down PART
# on ADP
# illegal ADJ
# gun NOUN
# traffickers NOUN
# and CCONJ
# bad ADJ
# - PUNCT
# apple NOUN
# dealers NOUN
# . PUNCT
# And CCONJ
# we PRON
# must VERB
# give VERB
# them PRON
# the DET
# enforcement NOUN
# tools NOUN
# that DET
# they PRON
# need VERB
# , PUNCT
# tools NOUN
# to PART
# trace VERB
# every DET
# gun NOUN
# and CCONJ
# every DET
# bullet NOUN
# used VERB
# in ADP
# every DET
# gun NOUN
# crime NOUN
# in ADP
# the DET
# United PROPN
# States PROPN
# . PUNCT
# I PRON
# ask VERB
# you PRON
# to PART
# help VERB
# us PRON
# do VERB
# that DET
# . PUNCT
#   SPACE
# Every DET
# State NOUN
# in ADP
# this DET
# country NOUN
# already ADV
# requires VERB
# hunters NOUN
# and CCONJ
# automobile NOUN
# drivers NOUN
# to PART
# have VERB
# a DET
# license NOUN
# . PUNCT
# I PRON
# think VERB
# they PRON
# ought VERB
# to PART
# do VERB
# the DET
# same ADJ
# thing NOUN
# for ADP
# handgun NOUN
# purchases NOUN
# . PUNCT
# Now ADV
# , PUNCT
# specifically ADV
# , PUNCT
# I PRON
# propose VERB
# a DET
# plan NOUN
# to PART
# ensure VERB
# that ADP
# all DET
# new ADJ
# handgun NOUN
# buyers NOUN
# must VERB
# first ADV
# have VERB
# a DET
# photo NOUN
# license NOUN
# from ADP
# their DET
# state NOUN
# showing VERB
# they PRON
# passed VERB
# the DET
# Brady PROPN
# background NOUN
# check NOUN
# and CCONJ
# a DET
# gun NOUN
# safety NOUN
# course NOUN
# , PUNCT
# before ADP
# they PRON
# get VERB
# the DET
# gun NOUN
# . PUNCT
# I PRON
# hope VERB
# you PRON
# ’ll AUX
# help VERB
# me PRON
# pass VERB
# that DET
# in ADP
# this DET
# Congress PROPN
# . PUNCT
#   SPACE
# Listen VERB
# to ADP
# this DET
# — PROPN
# listen VERB
# to ADP
# this DET
# . PUNCT
# The DET
# accidental ADJ
# gun NOUN
# rate NOUN
# — PUNCT
# the DET
# accidental ADJ
# gun NOUN
# death NOUN
# rate NOUN
# of ADP
# children NOUN
# under ADP
# 15 NUM
# in ADP
# the DET
# United PROPN
# States PROPN
# is VERB
# nine NUM
# times NOUN
# higher ADJ
# than ADP
# in ADP
# the DET
# other ADJ
# 25 NUM
# industrialized VERB
# countries NOUN
# combined VERB
# . PUNCT
# Now ADV
# , PUNCT
# technologies NOUN
# now ADV
# exist VERB
# that DET
# could VERB
# lead VERB
# to ADP
# guns NOUN
# that DET
# can VERB
# only ADV
# be VERB
# fired VERB
# by ADP
# the DET
# adults NOUN
# who PRON
# own VERB
# them PRON
# . PUNCT
# I PRON
# ask VERB
# Congress PROPN
# to PART
# fund VERB
# research NOUN
# into ADP
# smart ADJ
# gun NOUN
# technology NOUN
# to PART
# save VERB
# these DET
# children NOUN
# ’s PROPN
# lives NOUN
# . PUNCT
# I PRON
# ask VERB
# responsible ADJ
# leaders NOUN
# in ADP
# the DET
# gun NOUN
# industry NOUN
# to PART
# work VERB
# with ADP
# us PRON
# on ADP
# smart ADJ
# guns NOUN
# and CCONJ
# other ADJ
# steps NOUN
# to PART
# keep VERB
# guns NOUN
# out ADP
# of ADP
# the DET
# wrong ADJ
# hands NOUN
# , PUNCT
# to PART
# keep VERB
# our DET
# children NOUN
# safe ADJ
# . PUNCT
#   SPACE
# You PRON
# know VERB
# , PUNCT
# every DET
# parent NOUN
# I PRON
# know VERB
# worries NOUN
# about ADP
# the DET
# impact NOUN
# of ADP
# violence NOUN
# in ADP
# the DET
# media NOUN
# on ADP
# their DET
# children NOUN
# . PUNCT
# I PRON
# want VERB
# ...
# use VERB
# it PRON
# to PART
# prevent VERB
# the DET
# onset NOUN
# of ADP
# Alzheimer PROPN
# ’s PROPN
# . PUNCT
# Scientists NOUN
# are VERB
# also ADV
# working VERB
# on ADP
# an DET
# artificial ADJ
# retina NOUN
# to PART
# help VERB
# many ADJ
# blind ADJ
# people NOUN
# to PART
# see VERB
# and CCONJ
# — PUNCT
# listen VERB
# to ADP
# this DET
# — PROPN
# microchips NOUN
# that DET
# would VERB
# actually ADV
# directly ADV
# stimulate VERB
# damaged VERB
# spinal ADJ
# cords NOUN
# in ADP
# a DET
# way NOUN
# that DET
# could VERB
# allow VERB
# people NOUN
# now ADV
# paralyzed ADJ
# to PART
# stand VERB
# up PART
# and CCONJ
# walk VERB
# . PUNCT
#   SPACE
# These DET
# kinds NOUN
# of ADP
# innovations NOUN
# are VERB
# also ADV
# propelling VERB
# our DET
# remarkable ADJ
# prosperity NOUN
# . PUNCT
# Information NOUN
# technology NOUN
# only ADV
# includes VERB
# 8 NUM
# percent NOUN
# of ADP
# our DET
# employment NOUN
# but CCONJ
# now ADV
# accounts VERB
# for ADP
# a DET
# third NOUN
# of ADP
# our DET
# economic ADJ
# growth NOUN
# along ADP
# with ADP
# jobs NOUN
# that DET
# pay VERB
# , PUNCT
# by ADP
# the DET
# way NOUN
# , PUNCT
# about ADV
# 80 NUM
# percent NOUN
# above ADP
# the DET
# private ADJ
# sector NOUN
# average NOUN
# . PUNCT
# Again ADV
# , PUNCT
# we PRON
# ought VERB
# to PART
# keep VERB
# in ADP
# mind NOUN
# , PUNCT
# government NOUN
# - PUNCT
# funded VERB
# research NOUN
# brought VERB
# supercomputers NOUN
# , PUNCT
# the DET
# Internet NOUN
# , PUNCT
# and CCONJ
# communications NOUN
# satellites NOUN
# into ADP
# being NOUN
# . PUNCT
# Soon ADV
# researchers NOUN
# will VERB
# bring VERB
# us PRON
# devices NOUN
# that DET
# can VERB
# translate VERB
# foreign ADJ
# languages NOUN
# as ADV
# fast ADV
# as ADP
# you PRON
# can VERB
# talk VERB
# , PUNCT
# materials NOUN
# 10 NUM
# times NOUN
# stronger ADJ
# than ADP
# steel NOUN
# at ADP
# a DET
# fraction NOUN
# of ADP
# the DET
# weight NOUN
# , PUNCT
# and CCONJ
# — X
# this DET
# is VERB
# unbelievable ADJ
# to ADP
# me PRON
# — VERB
# molecular ADJ
# computers NOUN
# the DET
# size NOUN
# of ADP
# a DET
# teardrop NOUN
# with ADP
# the DET
# power NOUN
# of ADP
# today NOUN
# ’s PROPN
# fastest ADJ
# supercomputers NOUN
# . PUNCT
#   SPACE
# To PART
# accelerate VERB
# the DET
# march NOUN
# of ADP
# discovery NOUN
# across ADP
# all DET
# these DET
# disciplines NOUN
# in ADP
# science NOUN
# and CCONJ
# technology NOUN
# , PUNCT
# I PRON
# ask VERB
# you PRON
# to PART
# support VERB
# my DET
# recommendation NOUN
# of ADP
# an DET
# unprecedented ADJ
# $ SYM
# 3 NUM
# billion NUM
# in ADP
# the DET
# 21st ADJ
# century NOUN
# research NOUN
# fund NOUN
# , PUNCT
# the DET
# largest ADJ
# increase NOUN
# in ADP
# civilian ADJ
# research NOUN
# in ADP
# a DET
# generation NOUN
# . PUNCT
# We PRON
# owe VERB
# it PRON
# to ADP
# our DET
# future NOUN
# . PUNCT
#   SPACE
# Now ADV
# , PUNCT
# these DET
# new ADJ
# breakthroughs NOUN
# have VERB
# to PART
# be VERB
# used VERB
# in ADP
# ways NOUN
# that DET
# reflect VERB
# our DET
# values NOUN
# . PUNCT
# First ADV
# and CCONJ
# foremost ADV
# , PUNCT
# we PRON
# have VERB
# to PART
# safeguard VERB
# our DET
# citizens NOUN
# ’ PART
# privacy NOUN
# . PUNCT
# Last ADJ
# year NOUN
# we PRON
# proposed VERB
# to PART
# protect VERB
# every DET
# citizen NOUN
# ’s PROPN
# medical ADJ
# record NOUN
# . PUNCT
# This DET
# year NOUN
# we PRON
# will VERB
# finalize VERB
# those DET
# rules NOUN
# . PUNCT
# We PRON
# ’ve VERB
# also ADV
# taken VERB
# the DET
# first ADJ
# steps NOUN
# to PART
# protect VERB
# the DET
# privacy NOUN
# of ADP
# bank NOUN
# and CCONJ
# credit NOUN
# card NOUN
# records NOUN
# and CCONJ
# other ADJ
# financial ADJ
# statements NOUN
# . PUNCT
# Soon ADV
# I PRON
# will VERB
# send VERB
# legislation NOUN
# to ADP
# you PRON
# to PART
# finish VERB
# that DET
# job NOUN
# . PUNCT
# We PRON
# must VERB
# also ADV
# act VERB
# to PART
# prevent VERB
# any DET
# genetic ADJ
# discrimination NOUN
# whatever DET
# by ADP
# employers NOUN
# or CCONJ
# insurers NOUN
# . PUNCT
# I PRON
# hope VERB
# you PRON
# will VERB
# support VERB
# that DET
# . PUNCT
#   SPACE
# These DET
# steps NOUN
# will VERB
# allow VERB
# us PRON
# to PART
# lead VERB
# toward ADP
# the DET
# far ADJ
# frontiers NOUN
# of ADP
# science NOUN
# and CCONJ
# technology NOUN
# . PUNCT
# They PRON
# will VERB
# enhance VERB
# our DET
# health NOUN
# , PUNCT
# the DET
# environment NOUN
# , PUNCT
# the DET
# economy NOUN
# in ADP
# ways NOUN
# we PRON
# ca AUX
# n’t ADV
# even ADV
# imagine VERB
# today NOUN
# . PUNCT
# But CCONJ
# we PRON
# all DET
# know VERB
# that ADP
# at ADP
# a DET
# time NOUN
# when ADV
# science NOUN
# , PUNCT
# technology NOUN
# , PUNCT
# and CCONJ
# the DET
# forces NOUN
# of ADP
# globalization NOUN
# are VERB
# bringing VERB
# so ADV
# many ADJ
# changes NOUN
# into ADP
# all DET
# our DET
# lives NOUN
# , PUNCT
# it PRON
# ’s VERB
# more ADV
# important ADJ
# than ADP
# ever ADV
# that ADP
# we PRON
# strengthen VERB
# the DET
# bonds NOUN
# that DET
# root VERB
# us PRON
# in ADP
# our DET
# local ADJ
# communities NOUN
# and CCONJ
# in ADP
# our DET
# national ADJ
# community NOUN
# . PUNCT
#   SPACE
# No DET
# tie NOUN
# binds VERB
# different ADJ
# people NOUN
# together ADV
# like ADP
# citizen NOUN
# service NOUN
# . PUNCT
# There ADV
# ’s PROPN
# a DET
# new ADJ
# spirit NOUN
# of ADP
# service NOUN
# in ADP
# America PROPN
# , PUNCT
# a DET
# movement NOUN
# we PRON
# ’ve VERB
# tried VERB
# to PART
# support VERB
# with ADP
# AmeriCorps PROPN
# , PUNCT
# expanded VERB
# Peace PROPN
# Corps PROPN
# , PUNCT
# unprecedented ADJ
# new ADJ
# partnerships NOUN
# with ADP
# businesses NOUN
# , PUNCT
# foundations NOUN
# , PUNCT
# community NOUN
# groups NOUN
# ; PUNCT
# partnerships NOUN
# , PUNCT
# for ADP
# example NOUN
# , PUNCT
# like ADP
# the DET
# one NOUN
# that DET
# enlisted VERB
# 12,000 NUM
# companies NOUN
# which DET
# have VERB
# now ADV
# moved VERB
# 650,000 NUM
# of ADP
# our DET
# fellow ADJ
# citizens NOUN
# from ADP
# welfare NOUN
# to ADP
# work NOUN
# ; PUNCT
# partnerships NOUN
# to ADP
# battle NOUN
# drug NOUN
# abuse NOUN
# , PUNCT
# AIDS PROPN
# , PUNCT
# teach VERB
# young ADJ
# people NOUN
# to PART
# read VERB
# , PUNCT
# save VERB
# America PROPN
# ’s PROPN
# treasures NOUN
# , PUNCT
# strengthen VERB
# the DET
# arts NOUN
# , PUNCT
# fight VERB
# teen NOUN
# pregnancy NOUN
# , PUNCT
# prevent VERB
# violence NOUN
# among ADP
# young ADJ
# people NOUN
# , PUNCT
# promote VERB
# racial ADJ
# healing NOUN
# . PUNCT
# The DET
# American ADJ
# people NOUN
# are VERB
# working VERB
# together ADV
# . PUNCT
#   SPACE
# But CCONJ
# we PRON
# should VERB
# do VERB
# more ADJ
# to PART
# help VERB
# Americans PROPN
# help VERB
# each DET
# other ADJ
# . PUNCT
# First ADV
# , PUNCT
# we PRON
# should VERB
# help VERB
# faith NOUN
# - PUNCT
# based VERB
# organizations NOUN
# to PART
# do VERB
# more ADJ
# to PART
# fight VERB
# poverty NOUN
# and CCONJ
# drug NOUN
# abuse NOUN
# and CCONJ
# help VERB
# people NOUN
# get VERB
# back ADV
# on ADP
# the DET
# right ADJ
# track NOUN
# , PUNCT
# with ADP
# initiatives NOUN
# like ADP
# Second PROPN
# Chance PROPN
# Homes PROPN
# that DET
# do VERB
# so ADV
# much ADV
# to PART
# help VERB
# unwed ADJ
# teen NOUN
# mothers NOUN
# . PUNCT
# Second ADV
# , PUNCT
# we PRON
# should VERB
# support VERB
# Americans PROPN
# who PRON
# tithe VERB
# and CCONJ
# contribute VERB
# to ADP
# charities NOUN
# but CCONJ
# do VERB
# n’t ADV
# earn VERB
# enough ADJ
# to PART
# claim VERB
# a DET
# tax NOUN
# deduction NOUN
# for ADP
# it PRON
# . PUNCT
# Tonight NOUN
# I PRON
# propose VERB
# new ADJ
# tax NOUN
# incentives NOUN
# that DET
# would VERB
# allow VERB
# low ADJ
# and CCONJ
# middle ADJ
# income NOUN
# citizens NOUN
# who PRON
# do VERB
# n’t ADV
# itemize VERB
# to PART
# get VERB
# that DET
# deduction NOUN
# . PUNCT
# It PRON
# ’s VERB
# nothing NOUN
# but ADP
# fair ADJ
# , PUNCT
# and CCONJ
# it PRON
# will VERB
# get VERB
# more ADJ
# people NOUN
# to PART
# give VERB
# . PUNCT
#   SPACE
# We PRON
# should VERB
# do VERB
# more ADJ
# to PART
# help VERB
# new ADJ
# immigrants NOUN
# to PART
# fully ADV
# participate VERB
# in ADP
# our DET
# community NOUN
# . PUNCT
# That DET
# ’s PROPN
# why ADV
# I PRON
# recommend VERB
# spending VERB
# more ADJ
# to PART
# teach VERB
# them PRON
# civics NOUN
# and CCONJ
# English PROPN
# . PUNCT
# And CCONJ
# since ADP
# everybody NOUN
# in ADP
# our DET
# community NOUN
# counts NOUN
# , PUNCT
# we PRON
# ’ve VERB
# got VERB
# to PART
# make VERB
# sure ADJ
# everyone NOUN
# is VERB
# counted VERB
# in ADP
# this DET
# year NOUN
# ’s PROPN
# census NOUN
# . PUNCT
#   SPACE
# Within ADP
# 10 NUM
# years NOUN
# — PUNCT
# just ADV
# 10 NUM
# years NOUN
# — PUNCT
# there ADV
# will VERB
# be VERB
# no DET
# majority NOUN
# race NOUN
# in ADP
# our DET
# largest ADJ
# state NOUN
# of ADP
# California PROPN
# . PUNCT
# In ADP
# a DET
# little ADJ
# more ADJ
# than ADP
# 50 NUM
# years NOUN
# , PUNCT
# there ADV
# will VERB
# be VERB
# no DET
# majority NOUN
# race NOUN
# in ADP
# America PROPN
# . PUNCT
# In ADP
# a DET
# more ADV
# interconnected ADJ
# world NOUN
# , PUNCT
# this DET
# diversity NOUN
# can VERB
# be VERB
# our DET
# greatest ADJ
# strength NOUN
# . PUNCT
# Just ADV
# look VERB
# around ADP
# this DET
# chamber NOUN
# . PUNCT
# Look VERB
# around ADV
# . PUNCT
# We PRON
# have VERB
# members NOUN
# in ADP
# this DET
# Congress PROPN
# from ADP
# virtually ADV
# every DET
# racial ADJ
# , PUNCT
# ethnic ADJ
# , PUNCT
# and CCONJ
# religious ADJ
# background NOUN
# . PUNCT
# And CCONJ
# I PRON
# think VERB
# you PRON
# would VERB
# agree VERB
# that ADP
# America PROPN
# is VERB
# stronger ADJ
# because ADP
# of ADP
# it PRON
# . PUNCT
# [ PUNCT
# Applause NOUN
# ] PUNCT
#   SPACE
# You PRON
# also ADV
# have VERB
# to PART
# agree VERB
# that ADP
# all DET
# those DET
# differences NOUN
# you PRON
# just ADV
# clapped VERB
# for ADP
# all ADV
# too ADV
# often ADV
# spark VERB
# hatred NOUN
# and CCONJ
# division NOUN
# even ADV
# here ADV
# at ADP
# home NOUN
# . PUNCT
# Just ADV
# in ADP
# the DET
# last ADJ
# couple NOUN
# of ADP
# years NOUN
# , PUNCT
# we PRON
# ’ve VERB
# seen VERB
# a DET
# man NOUN
# dragged VERB
# to ADP
# death NOUN
# in ADP
# Texas PROPN
# just ADV
# because ADP
# he PRON
# was VERB
# black ADJ
# . PUNCT
# We PRON
# saw VERB
# a DET
# young ADJ
# man NOUN
# murdered VERB
# in ADP
# Wyoming PROPN
# just ADV
# because ADP
# he PRON
# was VERB
# gay ADJ
# . PUNCT
# Last ADJ
# year NOUN
# we PRON
# saw VERB
# the DET
# shootings NOUN
# of ADP
# African PROPN
# - PUNCT
# Americans PROPN
# , PUNCT
# Asian PROPN
# - PUNCT
# Americans PROPN
# , PUNCT
# and CCONJ
# Jewish ADJ
# children NOUN
# just ADV
# because ADP
# of ADP
# who PRON
# they PRON
# were VERB
# . PUNCT
# This DET
# is VERB
# not ADV
# the DET
# American ADJ
# way NOUN
# , PUNCT
# and CCONJ
# we PRON
# must VERB
# draw VERB
# the DET
# line NOUN
# . PUNCT
#   SPACE
# I PRON
# ask VERB
# you PRON
# to PART
# draw VERB
# that DET
# line NOUN
# by ADP
# passing VERB
# without ADP
# delay NOUN
# the DET
# " PUNCT
# Hate PROPN
# Crimes PROPN
# Prevention PROPN
# Act PROPN
# " PUNCT
# and CCONJ
# the DET
# " PUNCT
# Employment PROPN
# Non PROPN
# - PUNCT
# Discrimination PROPN
# Act PROPN
# . PUNCT
# " PUNCT
# And CCONJ
# I PRON
# ask VERB
# you PRON
# to PART
# reauthorize VERB
# the DET
# Violence NOUN
# Against ADP
# Women PROPN
# Act PROPN
# . PUNCT
#   SPACE
# Finally ADV
# tonight NOUN
# , PUNCT
# I PRON
# propose VERB
# the DET
# largest ADJ
# ever ADJ
# investment NOUN
# in ADP
# our DET
# civil ADJ
# rights NOUN
# laws NOUN
# for ADP
# enforcement NOUN
# , PUNCT
# because ADP
# no DET
# American PROPN
# should VERB
# be VERB
# subjected VERB
# to ADP
# discrimination NOUN
# in ADP
# finding VERB
# a DET
# home NOUN
# , PUNCT
# getting VERB
# a DET
# job NOUN
# , PUNCT
# going VERB
# to ADP
# school NOUN
# , PUNCT
# or CCONJ
# securing VERB
# a DET
# loan NOUN
# . PUNCT
# Protections NOUN
# in ADP
# law NOUN
# should VERB
# be VERB
# protections NOUN
# in ADP
# fact NOUN
# . PUNCT
#   SPACE
# Last ADJ
# February PROPN
# , PUNCT
# because ADP
# I PRON
# thought VERB
# this DET
# was VERB
# so ADV
# important ADJ
# , PUNCT
# I PRON
# created VERB
# the DET
# White PROPN
# House PROPN
# Office PROPN
# of ADP
# One PROPN
# America PROPN
# to PART
# promote VERB
# racial ADJ
# reconciliation NOUN
# . PUNCT
# That DET
# ’s PROPN
# what PRON
# one NUM
# of ADP
# my DET
# personal ADJ
# heroes NOUN
# , PUNCT
# Hank PROPN
# Aaron PROPN
# , PUNCT
# has VERB
# done VERB
# all DET
# his DET
# life NOUN
# . PUNCT
# From ADP
# his DET
# days NOUN
# as ADP
# our DET
# all DET
# - PUNCT
# time NOUN
# home NOUN
# run NOUN
# king NOUN
# to ADP
# his DET
# recent ADJ
# acts NOUN
# of ADP
# healing NOUN
# , PUNCT
# he PRON
# has VERB
# always ADV
# brought VERB
# people NOUN
# together ADV
# . PUNCT
# We PRON
# should VERB
# follow VERB
# his DET
# example NOUN
# , PUNCT
# and CCONJ
# we PRON
# ’re ADV
# honored VERB
# to PART
# have VERB
# him PRON
# with ADP
# us PRON
# tonight NOUN
# . PUNCT
# Stand VERB
# up PART
# , PUNCT
# Hank PROPN
# Aaron PROPN
# . PUNCT
# [ PUNCT
# Applause NOUN
# ] PUNCT
#   SPACE
# I PRON
# just ADV
# want VERB
# to PART
# say VERB
# one NUM
# more ADJ
# thing NOUN
# about ADP
# this DET
# , PUNCT
# and CCONJ
# I PRON
# want VERB
# every DET
# one NUM
# of ADP
# you PRON
# to PART
# think VERB
# about ADP
# this DET
# the DET
# next ADJ
# time NOUN
# you PRON
# get VERB
# mad ADJ
# at ADP
# one NUM
# of ADP
# your DET
# colleagues NOUN
# on ADP
# the DET
# other ADJ
# side NOUN
# of ADP
# the DET
# aisle NOUN
# . PUNCT
# This DET
# fall NOUN
# , PUNCT
# at ADP
# the DET
# White PROPN
# House PROPN
# , PUNCT
# Hillary PROPN
# had VERB
# one NUM
# of ADP
# her DET
# millennium NOUN
# dinners NOUN
# , PUNCT
# and CCONJ
# we PRON
# had VERB
# this DET
# very ADV
# distinguished ADJ
# scientist NOUN
# there ADV
# , PUNCT
# who PRON
# is VERB
# an DET
# expert NOUN
# in ADP
# this DET
# whole ADJ
# work NOUN
# in ADP
# the DET
# human ADJ
# genome NOUN
# . PUNCT
# And CCONJ
# he PRON
# said VERB
# that ADP
# we PRON
# are VERB
# all DET
# , PUNCT
# regardless ADV
# of ADP
# race NOUN
# , PUNCT
# genetically ADV
# 99.9 NUM
# percent NOUN
# the DET
# same ADJ
# . PUNCT
#   SPACE
# Now ADV
# , PUNCT
# you PRON
# may VERB
# find VERB
# that DET
# uncomfortable ADJ
# when ADV
# you PRON
# look VERB
# around ADV
# here ADV
# . PUNCT
# [ PUNCT
# Laughter NOUN
# ] PUNCT
# But CCONJ
# it PRON
# is VERB
# worth ADJ
# remembering VERB
# . PUNCT
# We PRON
# can VERB
# laugh VERB
# about ADP
# this DET
# , PUNCT
# but CCONJ
# you PRON
# think VERB
# about ADP
# it PRON
# . PUNCT
# Modern ADJ
# science NOUN
# has VERB
# confirmed VERB
# what PRON
# ancient ADJ
# faiths NOUN
# have VERB
# always ADV
# taught VERB
# : PUNCT
# the DET
# most ADV
# important ADJ
# fact NOUN
# of ADP
# life NOUN
# is VERB
# our DET
# common ADJ
# humanity NOUN
# . PUNCT
# Therefore ADV
# , PUNCT
# we PRON
# should VERB
# do VERB
# more ADJ
# than ADP
# just ADV
# tolerate VERB
# our DET
# diversity NOUN
# ; PUNCT
# we PRON
# should VERB
# honor VERB
# it PRON
# and CCONJ
# celebrate VERB
# it PRON
# . PUNCT
#   SPACE
# My DET
# fellow ADJ
# Americans PROPN
# , PUNCT
# every DET
# time NOUN
# I PRON
# prepare VERB
# for ADP
# the DET
# State PROPN
# of ADP
# the DET
# Union PROPN
# , PUNCT
# I PRON
# approach VERB
# it PRON
# with ADP
# hope NOUN
# and CCONJ
# expectation NOUN
# and CCONJ
# excitement NOUN
# for ADP
# our DET
# nation NOUN
# . PUNCT
# But CCONJ
# tonight NOUN
# is VERB
# very ADV
# special ADJ
# , PUNCT
# because ADP
# we PRON
# stand VERB
# on ADP
# the DET
# mountaintop NOUN
# of ADP
# a DET
# new ADJ
# millennium NOUN
# . PUNCT
# Behind ADP
# us PRON
# we PRON
# can VERB
# look VERB
# back ADV
# and CCONJ
# see VERB
# the DET
# great ADJ
# expanse NOUN
# of ADP
# American ADJ
# achievement NOUN
# , PUNCT
# and CCONJ
# before ADP
# us PRON
# we PRON
# can VERB
# see VERB
# even ADV
# greater ADJ
# , PUNCT
# grander NOUN
# frontiers NOUN
# of ADP
# possibility NOUN
# . PUNCT
# We PRON
# should VERB
# , PUNCT
# all DET
# of ADP
# us PRON
# , PUNCT
# be VERB
# filled VERB
# with ADP
# gratitude NOUN
# and CCONJ
# humility NOUN
# for ADP
# our DET
# present ADJ
# progress NOUN
# and CCONJ
# prosperity NOUN
# . PUNCT
# We PRON
# should VERB
# be VERB
# filled VERB
# with ADP
# awe NOUN
# and CCONJ
# joy NOUN
# at ADP
# what PRON
# lies VERB
# over ADP
# the DET
# horizon NOUN
# . PUNCT
# And CCONJ
# we PRON
# should VERB
# be VERB
# filled VERB
# with ADP
# absolute ADJ
# determination NOUN
# to PART
# make VERB
# the DET
# most ADJ
# of ADP
# it PRON
# . PUNCT
#   SPACE
# You PRON
# know VERB
# , PUNCT
# when ADV
# the DET
# Framers PROPN
# finished VERB
# crafting VERB
# our DET
# Constitution PROPN
# in ADP
# Philadelphia PROPN
# , PUNCT
# Benjamin PROPN
# Franklin PROPN
# stood VERB
# in ADP
# Independence PROPN
# Hall PROPN
# , PUNCT
# and CCONJ
# he PRON
# reflected VERB
# on ADP
# the DET
# carving NOUN
# of ADP
# the DET
# sun NOUN
# that DET
# was VERB
# on ADP
# the DET
# back NOUN
# of ADP
# a DET
# chair NOUN
# he PRON
# saw VERB
# . PUNCT
# The DET
# sun NOUN
# was VERB
# low ADJ
# on ADP
# the DET
# horizon NOUN
# . PUNCT
# So ADV
# he PRON
# said VERB
# this DET
# — X
# he PRON
# said VERB
# , PUNCT
# " PUNCT
# I PRON
# ’ve VERB
# often ADV
# wondered VERB
# whether ADP
# that DET
# sun NOUN
# was VERB
# rising VERB
# or CCONJ
# setting VERB
# . PUNCT
# Today NOUN
# , PUNCT
# " PUNCT
# Franklin PROPN
# said VERB
# , PUNCT
# " PUNCT
# I PRON
# have VERB
# the DET
# happiness NOUN
# to PART
# know VERB
# it PRON
# ’s PROPN
# a DET
# rising VERB
# sun NOUN
# . PUNCT
# " PUNCT
# Today NOUN
# , PUNCT
# because ADP
# each DET
# succeeding VERB
# generation NOUN
# of ADP
# Americans PROPN
# has VERB
# kept VERB
# the DET
# fire NOUN
# of ADP
# freedom NOUN
# burning VERB
# brightly ADV
# , PUNCT
# lighting VERB
# those DET
# frontiers NOUN
# of ADP
# possibility NOUN
# , PUNCT
# we PRON
# all DET
# still ADV
# bask VERB
# in ADP
# the DET
# glow NOUN
# and CCONJ
# the DET
# warmth NOUN
# of ADP
# Mr. PROPN
# Franklin PROPN
# ’s PROPN
# rising VERB
# sun NOUN
# . PUNCT
#   SPACE
# After ADP
# 224 NUM
# years NOUN
# , PUNCT
# the DET
# American ADJ
# revolution NOUN
# continues VERB
# . PUNCT
# We PRON
# remain VERB
# a DET
# new ADJ
# nation NOUN
# . PUNCT
# And CCONJ
# as ADV
# long ADV
# as ADP
# our DET
# dreams NOUN
# outweigh VERB
# our DET
# memories NOUN
# , PUNCT
# America PROPN
# will VERB
# be VERB
# forever ADV
# young ADJ
# . PUNCT
# That DET
# is VERB
# our DET
# destiny NOUN
# . PUNCT
# And CCONJ
# this DET
# is VERB
# our DET
# moment NOUN
# . PUNCT
#   SPACE
# Thank VERB
# you PRON
# , PUNCT
# God PROPN
# bless VERB
# you PRON
# , PUNCT
# and CCONJ
# God PROPN
# bless VERB
# America PROPN
# . PUNCT
#   SPACE
# Hide VERB
# Transcript PROPN

# %%
# detailed tag
# For what these tags mean, you might check out http://www.clips.ua.ac.be/pages/mbsp-tags
for token in doc:
    print(token.text, token.tag_)

# %%
# syntactic dependency
for token in doc:
    print(token.text, token.dep_)
# Out:
# Mr. compound
# Speaker ROOT
# , punct
# Mr. compound
# Vice compound
# President appos
# , punct
# members appos
# of prep
# Congress pobj
# , punct
# honored amod
# guests appos
# , punct
# my poss
# fellow amod
# Americans appos
# : punct
#
# We nsubj
# are ROOT
# fortunate acomp
# to aux
# be xcomp
# alive acomp
# at prep
# this det
# moment pobj
# in prep
# history pobj
# . punct
# Never neg
# before advmod
# has aux
# our poss
# nation nsubj
# enjoyed ROOT
# , punct
# at prep
# once pcomp
# , punct
# so advmod
# much amod
# prosperity pobj
# and cc
# social amod
# progress conj
# with prep
# so advmod
# little amod
# internal amod
# crisis pobj
# and cc
# so advmod
# few amod
# external amod
# threats conj
# . punct
# Never neg
# before advmod
# have aux
# we nsubj
# had ROOT
# such predet
# a det
# blessed amod
# opportunity dobj
# and cc
# , punct
# therefore advmod
# , punct
# such predet
# a det
# profound amod
# obligation appos
# to aux
# build acl
# the det
# more advmod
# perfect amod
# Union dobj
# of prep
# our poss
# Founders compound
# ’ compound
# dreams pobj
# . punct
#
# We nsubj
# begin ccomp
# the det
# new amod
# century dobj
# with prep
# over quantmod
# 20 compound
# million nummod
# new amod
# jobs pobj
# ; punct
# the det
# fastest amod
# economic amod
# growth nsubj
# in prep
# more amod
# than quantmod
# 30 nummod
# years pobj
# ; punct
# the det
# lowest amod
# unemployment compound
# rates nsubj
# in prep
# 30 nummod
# years pobj
# ; punct
# the det
# lowest amod
# poverty compound
# rates nsubj
# in prep
# 20 nummod
# years pobj
# ; punct
# the det
# lowest amod
# African amod
# - punct
# American amod
# and cc
# Hispanic conj
# unemployment compound
# rates appos
# on prep
# record pobj
# ; punct
# the det
# first amod
# back nmod
# - punct
# to prep
# - punct
# back pobj
# surpluses nsubj
# in prep
# 42 nummod
# years pobj
# ; punct
# and cc
# next amod
# month npadvmod
# , punct
# America nsubj
# will aux
# achieve ROOT
# the det
# longest amod
# period dobj
# of prep
# economic amod
# growth pobj
# in prep
# our poss
# entire amod
# history pobj
# . punct
# We nsubj
# have aux
# built ROOT
# a det
# new amod
# economy dobj
# . punct
#
# And cc
# our poss
# economic amod
# revolution nsubjpass
# has aux
# been auxpass
# matched ccomp
# by agent
# a det
# revival pobj
# of prep
# the det
# American amod
# spirit pobj
# : punct
# crime appos
# down prt
# by prep
# 20 nummod
# percent pobj
# , punct
# to prep
# its poss
# lowest amod
# level pobj
# in prep
# 25 nummod
# years pobj
# ; punct
# teen nsubj
# births ccomp
# down advmod
# seven nummod
# years npadvmod
# in prep
# a det
# row pobj
# ; punct
# adoptions dep
# up advmod
# by prep
# 30 nummod
# percent pobj
# ; punct
# welfare compound
# rolls nsubj
# cut ROOT
# in prep
# half pobj
# , punct
# to prep
# their poss
# lowest amod
# levels pobj
# in prep
# 30 nummod
# years pobj
# . punct
#
# My poss
# fellow amod
# Americans npadvmod
# , punct
# the det
# state nsubj
# of prep
# our poss
# Union pobj
# is ROOT
# the det
# strongest attr
# it nsubj
# has aux
# ever advmod
# been relcl
# . punct
#
# As prep
# always pcomp
# , punct
# the det
# real amod
# credit nsubj
# belongs ROOT
# to prep
# the det
# American amod
# people pobj
# . punct
# My poss
# gratitude nsubj
# also advmod
# goes ROOT
# to prep
# those pobj
# of prep
# you pobj
# in prep
# this det
# chamber pobj
# who nsubj
# have aux
# worked relcl
# with prep
# us pobj
# to aux
# put advcl
# progress dobj
# over prep
# partisanship pobj
# . punct
#
# Eight nummod
# years npadvmod
# ago advmod
# , punct
# it nsubj
# was ROOT
# not neg
# so advmod
# clear acomp
# to prep
# most amod
# Americans pobj
# there expl
# would aux
# be ccomp
# much attr
# to aux
# celebrate xcomp
# in prep
# the det
# year pobj
# 2000 nummod
# . punct
# Then advmod
# our poss
# nation nsubjpass
# was auxpass
# gripped ROOT
# by agent
# economic amod
# distress pobj
# , punct
# social amod
# decline conj
# , punct
# political amod
# gridlock conj
# . punct
# The det
# title nsubj
# of prep
# a det
# best advmod
# - punct
# selling amod
# book pobj
# asked ROOT
# : punct
# " punct
# America ccomp
# : punct
# What nsubj
# Went ROOT
# Wrong dobj
# ? punct
# " punct
#
# In prep
# the det
# best amod
# traditions pobj
# of prep
# our poss
# nation pobj
# , punct
# Americans nsubj
# determined ROOT
# to aux
# set xcomp
# things dobj
# right advmod
# . punct
# We nsubj
# restored ROOT
# the det
# vital amod
# center dobj
# , punct
# replacing advcl
# outmoded amod
# ideologies dobj
# with prep
# a det
# new amod
# vision pobj
# anchored acl
# in prep
# basic amod
# , punct
# enduring amod
# values pobj
# : punct
# opportunity ROOT
# for prep
# all pobj
# , punct
# responsibility appos
# from prep
# all pobj
# , punct
# a det
# community appos
# of prep
# all det
# Americans pobj
# . punct
# We nsubj
# reinvented ROOT
# government dobj
# , punct
# transforming advcl
# it dobj
# into prep
# a det
# catalyst pobj
# for prep
# new amod
# ideas pobj
# that nsubj
# stress relcl
# both det
# opportunity dobj
# and cc
# responsibility conj
# and cc
# give conj
# our poss
# people dative
# the det
# tools dobj
# they nsubj
# need relcl
# to aux
# solve xcomp
# their poss
# own amod
# problems dobj
# . punct
#
# With prep
# the det
# smallest amod
# federal amod
# work compound
# force pobj
# in prep
# 40 nummod
# years pobj
# , punct
# we nsubj
# turned ROOT
# record compound
# deficits dobj
# into prep
# record compound
# surpluses pobj
# and cc
# doubled conj
# our poss
# investment dobj
# in prep
# education pobj
# . punct
# We nsubj
# cut ROOT
# crime dobj
# with prep
# 100,000 nummod
# community compound
# police pobj
# and cc
# the det
# Brady compound
# law conj
# , punct
# which nsubj
# has aux
# kept relcl
# guns dobj
# out prep
# of prep
# the det
# hands pobj
# of prep
# half quantmod
# a quantmod
# million nummod
# criminals pobj
# . punct
#
# We nsubj
# ended ROOT
# welfare dobj
# as mark
# we nsubj
# knew advcl
# it dobj
# , punct
# requiring advcl
# work dobj
# while mark
# protecting advcl
# health compound
# care dobj
# and cc
# nutrition conj
# for prep
# children pobj
# and cc
# investing conj
# more dobj
# in prep
# child compound
# care pobj
# , punct
# transportation conj
# , punct
# and cc
# housing conj
# to aux
# help advcl
# their poss
# parents nsubj
# go ccomp
# to prep
# work pobj
# . punct
# We nsubj
# ’ve appos
# helped ROOT
# parents nsubj
# to aux
# succeed xcomp
# at prep
# home pobj
# and cc
# at conj
# work pobj
# with prep
# family compound
# leave pobj
# , punct
# which dobj
# 20 compound
# million nummod
# Americans nsubj
# have aux
# now advmod
# used relcl
# to aux
# care xcomp
# for prep
# a det
# newborn amod
# child pobj
# or cc
# a det
# sick amod
# loved ROOT
# one dobj
# . punct
# We nsubj
# ’ve appos
# engaged ROOT
# 150,000 nummod
# young amod
# Americans dobj
# in prep
# citizen compound
# service pobj
# through prep
# AmeriCorps pobj
# , punct
# while mark
# helping advcl
# them nsubj
# earn ccomp
# money dobj
# for prep
# college pobj
# . punct
#
# In prep
# 1992 pobj
# , punct
# we nsubj
# just advmod
# had ROOT
# a det
# roadmap dobj
# . punct
# Today npadvmod
# , punct
# we nsubj
# have ROOT
# results dobj
# . punct
#
# Even advmod
# more advmod
# important advcl
# , punct
# America nsubj
# again advmod
# has ROOT
# the det
# confidence dobj
# to aux
# dream acl
# big amod
# dreams dobj
# . punct
# But cc
# we nsubj
# must aux
# not neg
# let ROOT
# this det
# confidence nsubj
# drift ccomp
# into prep
# complacency pobj
# . punct
# For prep
# we pobj
# , punct
# all nsubjpass
# of prep
# us pobj
# , punct
# will aux
# be auxpass
# judged ROOT
# by agent
# the det
# dreams pobj
# and cc
# deeds conj
# we nsubj
# pass ROOT
# on prt
# to prep
# our poss
# children pobj
# . punct
# And cc
# on prep
# that det
# score pobj
# , punct
# we nsubjpass
# will aux
# be auxpass
# held ROOT
# to prep
# a det
# high amod
# standard pobj
# , punct
# indeed advmod
# , punct
# because mark
# our poss
# chance nsubj
# to aux
# do acl
# good dobj
# is advcl
# so advmod
# great acomp
# . punct
#
# My poss
# fellow amod
# Americans npadvmod
# , punct
# we nsubj
# have aux
# crossed ROOT
# the det
# bridge dobj
# we nsubj
# built relcl
# to prep
# the det
# 21st amod
# century pobj
# . punct
# Now advmod
# , punct
# we nsubj
# must aux
# shape ROOT
# a det
# 21st amod
# century nmod
# American amod
# revolution dobj
# of prep
# opportunity pobj
# , punct
# responsibility conj
# , punct
# and cc
# community conj
# . punct
# We nsubj
# must aux
# be ROOT
# now advmod
# , punct
# as mark
# we nsubj
# were advcl
# in prep
# the det
# beginning pobj
# , punct
# a det
# new amod
# nation npadvmod
# . punct
#
# At prep
# the det
# dawn pobj
# of prep
# the det
# last amod
# century pobj
# , punct
# Theodore compound
# Roosevelt nsubj
# said ROOT
# , punct
# " punct
# The det
# one nsubj
# characteristic amod
# more advmod
# essential amod
# than prep
# any det
# other pobj
# is ccomp
# foresight acomp
# . punct
# . punct
# . punct
# it nsubj
# should aux
# be ROOT
# the det
# growing amod
# nation attr
# with prep
# a det
# future pobj
# that nsubj
# takes relcl
# the det
# long amod
# look dobj
# ahead advmod
# . punct
# " ROOT
# So advmod
# tonight npadvmod
# let ROOT
# us nsubj
# take ccomp
# our poss
# long amod
# look dobj
# ahead advmod
# and cc
# set conj
# great amod
# goals dobj
# for dative
# our poss
# Nation pobj
# . punct
#
# To prep
# 21st amod
# century compound
# America pobj
# , punct
# let ccomp
# us nsubj
# pledge ccomp
# these det
# things dobj
# : punct
# Every det
# child nsubj
# will aux
# begin ROOT
# school dobj
# ready oprd
# to aux
# learn xcomp
# and cc
# graduate conj
# ready amod
# to aux
# succeed xcomp
# . punct
# Every det
# family nsubj
# will aux
# be ROOT
# able acomp
# to aux
# succeed xcomp
# at prep
# home pobj
# and cc
# at conj
# work pobj
# , punct
# and cc
# no det
# child nsubjpass
# will aux
# be auxpass
# raised conj
# in prep
# poverty pobj
# . punct
# We nsubj
# will aux
# meet ROOT
# the det
# challenge dobj
# of prep
# the det
# aging pobj
# of prep
# America pobj
# . punct
# We nsubj
# will aux
# assure ROOT
# quality dobj
# , punct
# affordable amod
# health compound
# care appos
# , punct
# at prep
# last pcomp
# , punct
# for conj
# all det
# Americans pobj
# . punct
# We nsubj
# will aux
# make ROOT
# America nsubj
# the det
# safest amod
# big amod
# country ccomp
# on prep
# Earth pobj
# . punct
# We nsubj
# will aux
# pay ROOT
# off prt
# our poss
# national amod
# debt dobj
# for prep
# the det
# first amod
# time pobj
# since prep
# 1835 pobj
# . punct
# * ROOT
# We nsubj
# will aux
# bring ROOT
# prosperity dobj
# to dative
# every det
# American amod
# community pobj
# . punct
# We nsubj
# will aux
# reverse ROOT
# the det
# course dobj
# of prep
# climate compound
# change pobj
# and cc
# leave conj
# a det
# safer amod
# , punct
# cleaner amod
# planet dobj
# . punct
# America nsubj
# will aux
# lead ROOT
# the det
# world dobj
# toward prep
# shared amod
# peace pobj
# and cc
# prosperity conj
# and cc
# the det
# far amod
# frontiers conj
# of prep
# science pobj
# and cc
# technology conj
# . punct
# And cc
# we nsubj
# will aux
# become ROOT
# at advmod
# last advmod
# what dobj
# our poss
# Founders nsubj
# pledged ccomp
# us dobj
# to aux
# be xcomp
# so advmod
# long advmod
# ago advmod
# : punct
#
# * punct
# White compound
# House compound
# correction ROOT
# . punct
#
# One nummod
# nation nsubj
# , punct
# under prep
# God pobj
# , punct
# indivisible ROOT
# , punct
# with prep
# liberty pobj
# and cc
# justice conj
# for prep
# all pobj
# . punct
#
# These nsubj
# are ROOT
# great amod
# goals attr
# , punct
# worthy amod
# of prep
# a det
# great amod
# nation pobj
# . punct
# We nsubj
# will aux
# not neg
# reach ROOT
# them dobj
# all predet
# this det
# year npadvmod
# , punct
# not neg
# even advmod
# in prep
# this det
# decade pobj
# . punct
# But cc
# we nsubj
# will aux
# reach ROOT
# them dobj
# . punct
# Let advcl
# us nsubj
# remember ccomp
# that mark
# the det
# first amod
# American compound
# Revolution nsubjpass
# was auxpass
# not neg
# won ccomp
# with prep
# a det
# single amod
# shot pobj
# ; punct
# the det
# continent nsubjpass
# was auxpass
# not neg
# settled ROOT
# in prep
# a det
# single amod
# year pobj
# . punct
# The det
# lesson nsubj
# of prep
# our poss
# history pobj
# and cc
# the det
# lesson conj
# of prep
# the det
# last amod
# seven nummod
# years pobj
# is ROOT
# that mark
# great amod
# goals nsubjpass
# are auxpass
# reached ccomp
# step npadvmod
# by prep
# step pobj
# , punct
# always advmod
# building advcl
# on prep
# our poss
# progress pobj
# , punct
# always advmod
# gaining conj
# ground dobj
# . punct
#
# Of advmod
# course advmod
# , punct
# you nsubj
# ca ROOT
# n’t punct
# gain dobj
# ground dobj
# if mark
# you nsubj
# ’re advmod
# standing advcl
# still advmod
# . punct
# And cc
# for prep
# too advmod
# long amod
# this dobj
# Congress nsubj
# has aux
# been aux
# standing ROOT
# still advmod
# on prep
# some pobj
# of prep
# our poss
# most advmod
# pressing amod
# national amod
# priorities pobj
# . punct
# So advmod
# let ROOT
# ’s nsubj
# begin ccomp
# tonight npadvmod
# with prep
# them pobj
# . punct
#
# Again advmod
# , punct
# I nsubj
# ask ROOT
# you dobj
# to aux
# pass xcomp
# a det
# real amod
# Patients compound
# ’ compound
# Bill dobj
# of prep
# Rights pobj
# . punct
# I nsubj
# ask ROOT
# you dobj
# to aux
# pass xcomp
# common amod
# - punct
# sense compound
# gun compound
# safety compound
# legislation dobj
# . punct
# I nsubj
# ask ROOT
# you dobj
# to aux
# pass xcomp
# campaign compound
# finance compound
# reform dobj
# . punct
# I nsubj
# ask ROOT
# you dobj
# to aux
# vote xcomp
# up prt
# or cc
# down conj
# on prep
# judicial amod
# nominations pobj
# and cc
# other amod
# important amod
# appointees conj
# . punct
# And cc
# again advmod
# , punct
# I nsubj
# ask ROOT
# you dobj
# — ROOT
# I nsubj
# implore ROOT
# you dobj
# to aux
# raise xcomp
# the det
# minimum amod
# wage dobj
# . punct
#
# Now advmod
# , punct
# two nummod
# years npadvmod
# ago advmod
# — nsubj
# let ccomp
# me nsubj
# try ccomp
# to aux
# balance xcomp
# the det
# seesaw dobj
# here—[laughter]—two compound
# years npadvmod
# ago advmod
# , punct
# as mark
# we nsubj
# reached advcl
# across prep
# party compound
# lines pobj
# to aux
# reach xcomp
# our poss
# first amod
# balanced amod
# budget dobj
# , punct
# I nsubj
# asked ROOT
# that mark
# we nsubj
# meet ccomp
# our poss
# responsibility dobj
# to prep
# the det
# next amod
# generation pobj
# by prep
# maintaining pcomp
# our poss
# fiscal amod
# discipline dobj
# . punct
# Because mark
# we nsubj
# refused advcl
# to aux
# stray xcomp
# from prep
# that det
# path pobj
# , punct
# we nsubj
# are aux
# doing ROOT
# something dobj
# that nsubj
# would aux
# have aux
# seemed relcl
# unimaginable oprd
# seven nummod
# years npadvmod
# ago advmod
# . punct
# We nsubj
# are aux
# actually advmod
# paying ROOT
# down prt
# the det
# national amod
# debt dobj
# . punct
# Now advmod
# , punct
# if mark
# we nsubj
# stay advcl
# on prep
# this det
# path pobj
# , punct
# we nsubj
# can aux
# pay ROOT
# down prt
# the det
# debt dobj
# entirely advmod
# in prep
# just advmod
# 13 nummod
# years pobj
# now advmod
# and cc
# make conj
# America nsubj
# debt npadvmod
# - punct
# free ccomp
# for prep
# the det
# first amod
# time pobj
# since mark
# Andrew compound
# Jackson nsubj
# was advcl
# President attr
# in prep
# 1835 pobj
# . punct
#
# In prep
# 1993 pobj
# we nsubj
# began ROOT
# to aux
# put xcomp
# our poss
# fiscal amod
# house dobj
# in prep
# order pobj
# with prep
# the det
# Deficit compound
# Reduction compound
# Act pobj
# , punct
# which nsubj
# you nsubj
# ’ll nsubj
# all appos
# remember relcl
# won ccomp
# passages dobj
# in prep
# both det
# Houses pobj
# by prep
# just advmod
# a det
# single amod
# vote pobj
# . punct
# Your poss
# former amod
# colleague nsubj
# , punct
# my poss
# first amod
# Secretary appos
# of prep
# the det
# Treasury pobj
# , punct
# led ROOT
# that det
# effort dobj
# and cc
# sparked conj
# our poss
# long amod
# boom dobj
# . punct
# He nsubj
# ’s ROOT
# here advmod
# with prep
# us pobj
# tonight npadvmod
# . punct
# Lloyd compound
# Bentsen npadvmod
# , punct
# you nsubj
# have aux
# served ROOT
# America dobj
# well advmod
# , punct
# and cc
# we nsubj
# thank conj
# you dobj
# . punct
#
# Beyond prep
# paying pcomp
# off prt
# the det
# debt dobj
# , punct
# we nsubj
# must aux
# ensure ROOT
# that mark
# the det
# benefits nsubj
# of prep
# debt compound
# reduction pobj
# go ccomp
# to prep
# preserving pcomp
# two dobj
# of prep
# the det
# most advmod
# important amod
# guarantees pobj
# we nsubj
# make relcl
# to prep
# every det
# American pobj
# , punct
# Social compound
# Security conj
# and cc
# Medicare conj
# . punct
# Tonight npadvmod
# I nsubj
# ask ROOT
# you dobj
# to aux
# work xcomp
# with prep
# me pobj
# to aux
# make advcl
# a det
# bipartisan amod
# downpayment dobj
# on prep
# Social compound
# Security compound
# reform pobj
# by prep
# crediting pcomp
# the det
# interest compound
# savings dobj
# from prep
# debt compound
# reduction pobj
# to prep
# the det
# Social compound
# Security compound
# Trust nmod
#
# Fund pobj
# so mark
# that mark
# it nsubj
# will aux
# be advcl
# strong acomp
# and cc
# sound conj
# for prep
# the det
# next amod
# 50 nummod
# years pobj
# . punct
#
# But cc
# this nsubj
# is ROOT
# just advmod
# the det
# start attr
# of prep
# our poss
# journey pobj
# . punct
# We nsubj
# must aux
# also advmod
# take ROOT
# the det
# right amod
# steps dobj
# toward prep
# reaching pcomp
# our poss
# great amod
# goals dobj
# . punct
# First advmod
# and cc
# foremost conj
# , punct
# we nsubj
# need ROOT
# a det
# 21st amod
# century compound
# revolution dobj
# in prep
# education pobj
# , punct
# guided acl
# by agent
# our poss
# faith pobj
# that mark
# every det
# single amod
# child nsubj
# can aux
# learn ccomp
# . punct
# Because mark
# education nsubj
# is ROOT
# more advmod
# important acomp
# than prep
# ever pcomp
# , punct
# more acomp
# than prep
# ever advmod
# the det
# key pobj
# to prep
# our poss
# children pobj
# ’s nummod
# future npadvmod
# , punct
# we nsubj
# must aux
# make ROOT
# sure ccomp
# all det
# our poss
# children nsubj
# have ccomp
# that det
# key dobj
# . punct
# That nsubj
# means ROOT
# quality compound
# preschool dobj
# and cc
# after conj
# - punct
# school pobj
# , punct
# the det
# best advmod
# trained amod
# teachers appos
# in prep
# the det
# classroom pobj
# , punct
# and cc
# college compound
# opportunities conj
# for prep
# all predet
# our poss
# children pobj
# . punct
#
# For prep
# seven nummod
# years pobj
# now advmod
# , punct
# we nsubj
# ’ve appos
# worked ROOT
# hard advmod
# to aux
# improve advcl
# our poss
# schools dobj
# , punct
# with prep
# opportunity pobj
# and cc
# responsibility conj
# , punct
# investing advcl
# more advmod
# but cc
# demanding conj
# more advmod
# in prep
# turn pobj
# . punct
# Reading advcl
# , punct
# math conj
# , punct
# college compound
# entrance compound
# scores nsubj
# are ROOT
# up advmod
# . punct
# Some nsubj
# of prep
# the det
# most advmod
# impressive amod
# gains pobj
# are ROOT
# in prep
# schools pobj
# in prep
# very advmod
# poor amod
# neighborhoods pobj
# . punct
#
# But cc
# all det
# successful amod
# schools nsubj
# have aux
# followed ROOT
# the det
# same amod
# proven amod
# formula dobj
# : punct
# higher amod
# standards appos
# , punct
# more amod
# accountability conj
# , punct
# and cc
# extra amod
# help conj
# so advmod
# children nsubj
# who nsubj
# need relcl
# it dobj
# can aux
# get ROOT
# it nsubj
# to aux
# reach ccomp
# those det
# standards dobj
# . punct
# I nsubj
# have aux
# sent ROOT
# Congress dative
# a det
# reform compound
# plan dobj
# based acl
# on prep
# that det
# formula pobj
# . punct
# It nsubj
# holds ROOT
# states nsubj
# and cc
# school compound
# districts conj
# accountable ccomp
# for prep
# progress pobj
# and cc
# rewards conj
# them dobj
# for prep
# results pobj
# . punct
# Each det
# year npadvmod
# , punct
# our poss
# national amod
# government nsubj
# invests ROOT
# more amod
# than quantmod
# $ quantmod
# 15 compound
# billion dobj
# in prep
# our poss
# schools pobj
# . punct
# It nsubj
# is ROOT
# time attr
# to aux
# support relcl
# what nsubj
# works ccomp
# and cc
# stop conj
# supporting xcomp
# what nsubj
# does ccomp
# n’t punct
# . punct
#
# Now advmod
# , punct
# as mark
# we nsubj
# demand advcl
# more dobj
# from prep
# our poss
# schools pobj
# , punct
# we nsubj
# should aux
# also advmod
# invest ROOT
# more dobj
# in prep
# our poss
# schools pobj
# . punct
# Let ROOT
# ’s nsubj
# double ccomp
# our poss
# investment dobj
# to aux
# help advcl
# states nsubj
# and cc
# districts conj
# turn ccomp
# around prt
# their poss
# worst amod
# performing compound
# schools dobj
# or cc
# shut conj
# them dobj
# down prt
# . punct
# Let ROOT
# ’s nsubj
# double ccomp
# our poss
# investments dobj
# in prep
# after nmod
# - punct
# school pobj
# and cc
# summer conj
# school compound
# programs pobj
# , punct
# which nsubj
# boost relcl
# achievement dobj
# and cc
# keep conj
# people dobj
# off prep
# the det
# streets pobj
# and cc
# out conj
# of prep
# trouble pobj
# . punct
# If mark
# we nsubj
# do advcl
# this dobj
# , punct
# we nsubj
# can aux
# give ROOT
# every det
# single amod
# child dobj
# in prep
# every det
# failing amod
# school pobj
# in prep
# America pobj
# — aux
# everyone nsubj
# — ROOT
# the det
# chance dobj
# to aux
# meet acl
# high amod
# standards dobj
# . punct
#
# Since prep
# 1993 pobj
# , punct
# we nsubj
# ’ve appos
# nearly advmod
# doubled ROOT
# our poss
# investment dobj
# in prep
# Head compound
# Start pobj
# and cc
# improved conj
# its poss
# quality dobj
# . punct
# Tonight npadvmod
# I nsubj
# ask ROOT
# you dobj
# for prep
# another det
# $ quantmod
# 1 compound
# billion pobj
# for prep
# Head compound
# Start pobj
# , punct
# the det
# largest amod
# increase appos
# in prep
# the det
# history pobj
# of prep
# the det
# program pobj
# . punct
#
# We nsubj
# know ROOT
# that mark
# children nsubj
# learn ccomp
# best advmod
# in prep
# smaller amod
# classes pobj
# with prep
# good amod
# teachers pobj
# . punct
# For prep
# two nummod
# years pobj
# in prep
# a det
# row pobj
# , punct
# Congress nsubj
# has aux
# supported ROOT
# my poss
# plan dobj
# to aux
# hire acl
# 100,000 nummod
# new amod
# qualified amod
# teachers dobj
# to aux
# lower advcl
# class compound
# size dobj
# in prep
# the det
# early amod
# grades pobj
# . punct
# I nsubj
# thank ROOT
# you dobj
# for prep
# that pobj
# , punct
# and cc
# I nsubj
# ask conj
# you dobj
# to aux
# make xcomp
# it nsubj
# three ccomp
# in prep
# a det
# row pobj
# . punct
# And cc
# to aux
# make advcl
# sure ccomp
# all det
# teachers nsubj
# know ccomp
# the det
# subjects dobj
# they nsubj
# teach relcl
# , punct
# tonight npadvmod
# I nsubj
# propose ROOT
# a det
# new amod
# teacher compound
# quality compound
# initiative dobj
# , punct
# to aux
# recruit xcomp
# more advmod
# talented amod
# people dobj
# into prep
# the det
# classroom pobj
# , punct
# reward conj
# good amod
# teachers dobj
# for prep
# staying pcomp
# there advmod
# , punct
# and cc
# give conj
# all det
# teachers dative
# the det
# training dobj
# they nsubj
# need relcl
# . punct
#
# We nsubj
# know ROOT
# charter compound
# schools nsubj
# provide ccomp
# real amod
# public amod
# school compound
# choice dobj
# . punct
# When advmod
# I nsubj
# became advcl
# President attr
# , punct
# there expl
# was ROOT
# just advmod
# one nummod
# independent amod
# public amod
# charter compound
# school attr
# in prep
# all det
# America pobj
# . punct
# Today npadvmod
# , punct
# thanks npadvmod
# to prep
# you pobj
# , punct
# there expl
# are ROOT
# 1,700 attr
# . punct
# I nsubj
# ask ROOT
# you dobj
# now advmod
# to aux
# help xcomp
# us nsubj
# meet ccomp
# our poss
# goal dobj
# of prep
# 3,000 nummod
# charter compound
# schools pobj
# by prep
# next amod
# year pobj
# . punct
#
# We nsubj
# know parataxis
# we nsubj
# must aux
# connect ROOT
# all predet
# our poss
# classrooms dobj
# to prep
# the det
# Internet pobj
# , punct
# and cc
# we nsubj
# ’re advmod
# getting conj
# there advmod
# . punct
# In prep
# 1994 pobj
# , punct
# only advmod
# 3 nummod
# percent nsubjpass
# of prep
# our poss
# classrooms pobj
# were auxpass
# connected ROOT
# . punct
# Today npadvmod
# , punct
# with prep
# the det
# help pobj
# of prep
# the det
# Vice compound
# President compound
# ’s nmod
# E compound
# - punct
# rate compound
# program pobj
# , punct
# more amod
# than quantmod
# half nsubj
# of prep
# them pobj
# are ROOT
# , punct
# and cc
# 90 nummod
# percent nsubj
# of prep
# our poss
# schools pobj
# have conj
# at advmod
# least advmod
# one nummod
# Internet compound
# connection dobj
# . punct
# But cc
# we nsubj
# can aux
# not neg
# finish ROOT
# the det
# job dobj
# when advmod
# a det
# third nsubj
# of prep
# all det
# our poss
# schools pobj
# are advcl
# in prep
# serious amod
# disrepair pobj
# . punct
# Many nsubj
# of prep
# them pobj
# have ROOT
# walls dobj
# and cc
# wires conj
# so advmod
# old ROOT
# , punct
# they ROOT
# ’re advmod
# too advmod
# old amod
# for prep
# the det
# Internet pobj
# . punct
# So advmod
# tonight npadvmod
# I nsubj
# propose ROOT
# to aux
# help xcomp
# 5,000 nummod
# schools dobj
# a det
# year npadvmod
# make xcomp
# immediate amod
# and cc
# urgent conj
# repairs dobj
# and cc
# , punct
# again advmod
# , punct
# to aux
# help aux
# build xcomp
# or cc
# modernize conj
# 6,000 dobj
# more amod
# , punct
# to aux
# get xcomp
# students dobj
# out prep
# of prep
# trailers pobj
# and cc
# into conj
# high amod
# - punct
# tech compound
# classrooms pobj
# . punct
#
# I nsubj
# ask ROOT
# all dobj
# of prep
# you pobj
# to aux
# help xcomp
# me dobj
# double ccomp
# our poss
# bipartisan amod
# GEAR compound
# UP compound
# program dobj
# , punct
# which nsubj
# provides relcl
# mentors dobj
# for prep
# disadvantaged amod
# young amod
# people pobj
# . punct
# If mark
# we nsubj
# double advcl
# it dobj
# , punct
# we nsubj
# can aux
# provide ROOT
# mentors dobj
# for prep
# 1.4 compound
# million pobj
# of prep
# them pobj
# . punct
# Let ROOT
# ’s nsubj
# also advmod
# offer ccomp
# these det
# kids dobj
# from prep
# disadvantaged amod
# backgrounds pobj
# the det
# same amod
# chance dobj
# to aux
# take acl
# the det
# same amod
# college nmod
# test npadvmod
# - punct
# prep amod
# courses dobj
# wealthier amod
# students nsubj
# use relcl
# to aux
# boost xcomp
# their poss
# test compound
# scores dobj
# . punct
#
# To aux
# make advcl
# the det
# American amod
# dream nsubj
# achievable ccomp
# for prep
# all pobj
# , punct
# we nsubj
# must aux
# make ROOT
# college nsubj
# affordable ccomp
# for prep
# all pobj
# . punct
# For prep
# seven nummod
# years pobj
# , punct
# on prep
# a det
# bipartisan amod
# basis pobj
# , punct
# we nsubj
# have aux
# taken ROOT
# action dobj
# toward prep
# that det
# goal pobj
# : punct
# larger amod
# Pell compound
# Grants appos
# , punct
# more advmod
# affordable amod
# student compound
# loans appos
# , punct
# education compound
# IRAs conj
# , punct
# and cc
# our poss
# HOPE compound
# scholarships conj
# , punct
# which nsubj
# have aux
# already advmod
# benefited relcl
# five compound
# million nummod
# young amod
# people dobj
# . punct
#
# Now advmod
# , punct
# 67 nummod
# percent nsubj
# of prep
# high amod
# school compound
# graduates pobj
# are aux
# going ROOT
# on prt
# to prep
# college pobj
# . punct
# That nsubj
# ’s ROOT
# up prt
# 10 nummod
# percent npadvmod
# since prep
# 1993 pobj
# . punct
# Yet cc
# millions nsubj
# of prep
# families pobj
# still advmod
# strain ROOT
# to aux
# pay xcomp
# college compound
# tuition dobj
# . punct
# They nsubj
# need ROOT
# help dobj
# . punct
# So advmod
# I nsubj
# propose ROOT
# a det
# landmark pobj
# $ quantmod
# 30 compound
# billion nummod
# college compound
# opportunity compound
# tax compound
# cut dobj
# , punct
# a det
# middle amod
# class compound
# tax compound
# deduction appos
# for prep
# up quantmod
# to quantmod
# $ quantmod
# 10,000 pobj
# in prep
# college compound
# tuition compound
# costs pobj
# . punct
# The det
# previous amod
# actions nsubj
# of prep
# this det
# Congress pobj
# have aux
# already advmod
# made ROOT
# two nummod
# years nsubj
# of prep
# college pobj
# affordable ccomp
# for prep
# all pobj
# . punct
# It nsubj
# ’s compound
# time npadvmod
# make ROOT
# four nummod
# years nsubj
# of prep
# college pobj
# affordable ccomp
# for prep
# all pobj
# . punct
# If mark
# we nsubj
# take advcl
# all predet
# these det
# steps dobj
# , punct
# we nsubj
# ’ll nsubj
# move ROOT
# a det
# long amod
# way dobj
# toward prep
# making pcomp
# sure acomp
# every det
# child nsubj
# starts ccomp
# school dobj
# ready amod
# to aux
# learn xcomp
# and cc
# graduates conj
# ready amod
# to aux
# succeed xcomp
# . punct
#
# We nsubj
# also advmod
# need ROOT
# a det
# 21st amod
# century compound
# revolution dobj
# to aux
# reward relcl
# work dobj
# and cc
# strengthen conj
# families dobj
# by prep
# giving pcomp
# every det
# parent dative
# the det
# tools dobj
# to aux
# succeed relcl
# at prep
# work pobj
# and cc
# at conj
# the det
# most advmod
# important amod
# work pobj
# of prep
# all pobj
# , punct
# raising advcl
# children dobj
# . punct
# That nsubj
# means ROOT
# making xcomp
# sure acomp
# every det
# family nsubj
# has ccomp
# health compound
# care dobj
# and cc
# the det
# support conj
# to aux
# care relcl
# for prep
# aging amod
# parents pobj
# , punct
# the det
# tools conj
# to aux
# bring relcl
# their poss
# children dobj
# up prt
# right advmod
# , punct
# and cc
# that mark
# no det
# child nsubj
# grows conj
# up prt
# in prep
# poverty pobj
# . punct
#
# From prep
# my poss
# first amod
# days pobj
# as prep
# President pobj
# , punct
# we nsubj
# ’ve appos
# worked ROOT
# to aux
# give advcl
# families dative
# better amod
# access dobj
# to prep
# better amod
# health compound
# care pobj
# . punct
# In prep
# 1997 pobj
# , punct
# we nsubj
# passed ROOT
# the det
# Children compound
# ’s compound
# Health compound
# Insurance compound
# Program dobj
# — compound
# CHIP compound
# — appos
# so mark
# that mark
# workers nsubj
# who nsubj
# do relcl
# n’t dobj
# have advcl
# coverage dobj
# through prep
# their poss
# employers pobj
# at advmod
# least advmod
# can aux
# get advcl
# it dobj
# for prep
# their poss
# children pobj
# . punct
# So advmod
# far advmod
# , punct
# we nsubj
# ’ve appos
# enrolled ROOT
# two compound
# million nummod
# children dobj
# . punct
# We ROOT
# ’re advmod
# well advmod
# on prep
# our poss
# way pobj
# to prep
# our poss
# goal pobj
# of prep
# five compound
# million pobj
# . punct
#
# But cc
# there expl
# are ROOT
# still advmod
# more amod
# than quantmod
# 40 compound
# million attr
# of prep
# our poss
# fellow amod
# Americans pobj
# without prep
# health compound
# insurance pobj
# , punct
# more acomp
# than mark
# there expl
# were advcl
# in prep
# 1993 pobj
# . punct
# Tonight npadvmod
# I nsubj
# propose ROOT
# that mark
# we nsubj
# follow ccomp
# Vice compound
# President compound
# Gore compound
# ’s compound
# suggestion dobj
# to aux
# make advcl
# low amod
# income compound
# parents nsubj
# eligible ccomp
# for prep
# the det
# insurance pobj
# that nsubj
# covers relcl
# their poss
# children dobj
# . punct
# Together advmod
# with ROOT
# our poss
# children pobj
# ’s compound
# initiative compound
# — nsubj
# think ROOT
# of prep
# this det
# — pobj
# together advmod
# with prep
# our poss
# children poss
# ’s appos
# initiative pobj
# , punct
# this det
# action nsubj
# would aux
# enable ccomp
# us dobj
# to aux
# cover xcomp
# nearly advmod
# a nummod
# quarter dobj
# of prep
# all predet
# the det
# uninsured amod
# people pobj
# in prep
# America pobj
# . punct
#
# Again advmod
# , punct
# I nsubj
# want ROOT
# to aux
# ask xcomp
# you dobj
# to aux
# let xcomp
# people dobj
# between prep
# the det
# ages pobj
# of prep
# 55 pobj
# and cc
# 65 conj
# , punct
# the det
# fastest amod
# growing amod
# group appos
# of prep
# uninsured pobj
# , punct
# buy conj
# into prep
# Medicare pobj
# . punct
# And cc
# this det
# year npadvmod
# I nsubj
# propose ROOT
# to aux
# give xcomp
# them dative
# a det
# tax compound
# credit dobj
# to aux
# make relcl
# that det
# choice nsubj
# an det
# affordable amod
# one ccomp
# . punct
# I nsubj
# hope ROOT
# you nsubj
# will aux
# support ccomp
# that dobj
# , punct
# as advmod
# well advmod
# . punct
#
# When advmod
# the det
# baby compound
# boomers nsubj
# retire advcl
# , punct
# Medicare nsubjpass
# will aux
# be auxpass
# faced ccomp
# with prep
# caring pcomp
# for prep
# twice advmod
# as quantmod
# many pobj
# of prep
# our poss
# citizens pobj
# ; punct
# yet advmod
# , punct
# it nsubj
# is ROOT
# far advmod
# from prep
# ready amod
# to aux
# do xcomp
# so advmod
# . punct
# My poss
# generation nsubj
# must aux
# not neg
# ask ROOT
# our poss
# children dobj
# ’s nummod
# generation dobj
# to aux
# shoulder xcomp
# our poss
# burden dobj
# . punct
# We nsubj
# simply advmod
# must aux
# act ROOT
# now advmod
# to aux
# strengthen advcl
# and cc
# modernize conj
# Medicare dobj
# . punct
#
# My poss
# budget nsubj
# includes ROOT
# a det
# comprehensive amod
# plan dobj
# to aux
# reform acl
# Medicare dobj
# , punct
# to aux
# make acl
# it nsubj
# more advmod
# efficient ccomp
# and cc
# more advmod
# competitive conj
# . punct
# And cc
# it nsubj
# dedicates ROOT
# nearly advmod
# $ quantmod
# 400 compound
# billion dobj
# of prep
# our poss
# budget compound
# surplus pobj
# to aux
# keep advcl
# Medicare dobj
# solvent oprd
# past prep
# 2025 pobj
# . punct
# And cc
# at advmod
# long advmod
# last advmod
# , punct
# it nsubj
# also advmod
# provides ROOT
# funds dobj
# to aux
# give xcomp
# every det
# senior amod
# a det
# voluntary amod
# choice dobj
# of prep
# affordable amod
# coverage pobj
# for prep
# prescription compound
# drugs pobj
# . punct
#
# Lifesaving csubj
# drugs dobj
# are ROOT
# an det
# indispensable amod
# part attr
# of prep
# modern amod
# medicine pobj
# . punct
# No det
# one nsubj
# creating acl
# a det
# Medicare compound
# program dobj
# today npadvmod
# would aux
# even advmod
# think ROOT
# of prep
# excluding pcomp
# coverage dobj
# for prep
# prescription compound
# drugs pobj
# . punct
# Yet advmod
# more amod
# than quantmod
# three nsubj
# in prep
# five pobj
# of prep
# our poss
# seniors pobj
# now advmod
# lack ROOT
# dependable amod
# drug compound
# coverage dobj
# which nsubj
# can aux
# lengthen relcl
# and cc
# enrich conj
# their poss
# lives dobj
# . punct
# Millions nsubj
# of prep
# older amod
# Americans pobj
# , punct
# who nsubj
# need relcl
# prescription compound
# drugs dobj
# the det
# most advmod
# , punct
# pay ROOT
# the det
# highest amod
# prices dobj
# for prep
# them pobj
# . punct
# In prep
# good amod
# conscience pobj
# , punct
# we nsubj
# can aux
# not neg
# let ROOT
# another det
# year nsubj
# pass ccomp
# without prep
# extending pcomp
# to prep
# all det
# our poss
# seniors pobj
# this det
# lifeline dobj
# of prep
# affordable amod
# prescription compound
# drugs pobj
# . punct
#
# Record compound
# numbers nsubj
# of prep
# Americans pobj
# are aux
# providing ROOT
# for prep
# aging amod
# or cc
# ailing conj
# loved amod
# ones pobj
# at prep
# home pobj
# . punct
# It nsubj
# ’s ROOT
# a det
# loving dobj
# but cc
# a det
# difficult amod
# and cc
# often advmod
# very advmod
# expensive conj
# choice conj
# . punct
# Last amod
# year npadvmod
# , punct
# I nsubj
# proposed ROOT
# a det
# $ nmod
# 1,000 nummod
# tax compound
# credit dobj
# for prep
# long amod
# - punct
# term compound
# care pobj
# . punct
# Frankly advmod
# , punct
# it nsubj
# was ROOT
# n’t attr
# enough acomp
# . punct
# This det
# year npadvmod
# , punct
# let ROOT
# ’s nsubj
# triple ccomp
# it dobj
# to prep
# $ nmod
# 3,000 pobj
# . punct
# But cc
# this det
# year npadvmod
# , punct
# let ROOT
# ’s nsubj
# pass ccomp
# it dobj
# . punct
#
# We nsubj
# also advmod
# have ROOT
# to aux
# make xcomp
# needed amod
# investments nsubj
# to aux
# expand ccomp
# access dobj
# to prep
# mental amod
# health compound
# care pobj
# . punct
# I nsubj
# want ROOT
# to aux
# take xcomp
# a det
# moment dobj
# to aux
# thank advcl
# the det
# person dobj
# who nsubj
# led relcl
# our poss
# first amod
# White compound
# House compound
# Conference dobj
# on prep
# Mental compound
# Health pobj
# last amod
# year npadvmod
# and cc
# who nsubj
# for prep
# seven nummod
# years pobj
# has aux
# led conj
# all predet
# our poss
# efforts dobj
# to aux
# break acl
# down prt
# the det
# barriers dobj
# to aux
# decent advcl
# treatment dobj
# of prep
# people pobj
# with prep
# mental amod
# illness pobj
# . punct
# Thank ROOT
# you dobj
# , punct
# Tipper compound
# Gore npadvmod
# . punct
#
# Taken advcl
# together advmod
# , punct
# these det
# proposals nsubj
# would aux
# mark ROOT
# the det
# largest amod
# investment dobj
# in prep
# health compound
# care pobj
# in prep
# the det
# 35 nummod
# years pobj
# since mark
# Medicare nsubjpass
# was auxpass
# created advcl
# — ROOT
# the det
# largest amod
# investment dobj
# in prep
# 35 nummod
# years pobj
# . punct
# That nsubj
# would aux
# be ROOT
# a det
# big amod
# step attr
# toward prep
# assuring pcomp
# quality compound
# health compound
# care dobj
# for prep
# all det
# Americans pobj
# , punct
# young amod
# and cc
# old conj
# . punct
# And cc
# I nsubj
# ask ROOT
# you dobj
# to aux
# embrace xcomp
# them dobj
# and cc
# pass conj
# them dobj
# . punct
#
# We nsubj
# must aux
# also advmod
# make ROOT
# investments dobj
# that nsubj
# reward relcl
# work nmod
# and cc
# support conj
# families dobj
# . punct
# Nothing nsubj
# does ROOT
# that dobj
# better advmod
# than prep
# the det
# earned amod
# - punct
# income compound
# tax compound
# credit pobj
# , punct
# the det
# EITC appos
# . punct
# The det
# " punct
# E nsubj
# " punct
# in prep
# the det
# EITC pobj
# is ROOT
# about prep
# earning pcomp
# , punct
# working conj
# , punct
# taking conj
# responsibility dobj
# , punct
# and cc
# being auxpass
# rewarded conj
# for prep
# it pobj
# . punct
# In prep
# my poss
# very advmod
# first amod
# address pobj
# to prep
# you pobj
# , punct
# I nsubj
# asked ROOT
# Congress dobj
# to aux
# greatly advmod
# expand xcomp
# this det
# credit dobj
# , punct
# and cc
# you nsubj
# did conj
# . punct
# As prep
# a det
# result pobj
# , punct
# in prep
# 1998 pobj
# alone advmod
# , punct
# the det
# EITC nsubj
# helped ROOT
# more amod
# than quantmod
# 4.3 compound
# million nummod
# Americans nsubj
# work ccomp
# their poss
# way dobj
# out prep
# of prep
# poverty pobj
# toward prep
# the det
# middle amod
# class pobj
# . punct
# That det
# ’s nsubj
# double advmod
# the det
# number ROOT
# in prep
# 1993 pobj
# . punct
#
# Tonight npadvmod
# I nsubj
# propose ROOT
# another det
# major amod
# expansion dobj
# of prep
# the det
# EITC pobj
# : punct
# to aux
# reduce xcomp
# the det
# marriage compound
# penalty dobj
# , punct
# to aux
# make advcl
# sure ccomp
# it nsubj
# rewards ccomp
# marriage dobj
# as mark
# it nsubj
# rewards advcl
# work dobj
# , punct
# and cc
# also advmod
# to aux
# expand conj
# the det
# tax compound
# credit dobj
# for prep
# families pobj
# that nsubj
# have relcl
# more amod
# than quantmod
# two nummod
# children dobj
# . punct
# It nsubj
# punishes ROOT
# people dobj
# with prep
# more amod
# than quantmod
# two nummod
# children pobj
# today npadvmod
# . punct
# Our poss
# proposal nsubj
# would aux
# allow ROOT
# families dobj
# with prep
# three nummod
# or cc
# more conj
# children pobj
# to aux
# get ccomp
# up quantmod
# to quantmod
# $ quantmod
# 1,100 npadvmod
# more dobj
# in prep
# tax compound
# relief pobj
# . punct
# These nsubj
# are ccomp
# working amod
# families attr
# ; punct
# their poss
# children nsubj
# should aux
# not neg
# be ROOT
# in prep
# poverty pobj
# . punct
#
# We nsubj
# also advmod
# ca ROOT
# n’t punct
# reward compound
# work dobj
# and cc
# family conj
# unless mark
# men nsubj
# and cc
# women conj
# get advcl
# equal amod
# pay dobj
# for prep
# equal amod
# work pobj
# . punct
# Today npadvmod
# the det
# female amod
# unemployment compound
# rate nsubj
# is ROOT
# the det
# lowest attr
# it nsubj
# has aux
# been relcl
# in prep
# 46 nummod
# years pobj
# . punct
# Yet advmod
# , punct
# women nsubj
# still advmod
# only advmod
# earn ROOT
# about advmod
# 75 nummod
# cents dobj
# for prep
# every det
# dollar compound
# men nsubj
# earn ccomp
# . punct
# We nsubj
# must aux
# do ROOT
# better advmod
# , punct
# by prep
# providing pcomp
# the det
# resources dobj
# to aux
# enforce xcomp
# present amod
# equal amod
# pay compound
# laws dobj
# , punct
# training advcl
# more amod
# women dobj
# for prep
# high advmod
# - punct
# paying amod
# , punct
# high amod
# - punct
# tech compound
# jobs pobj
# , punct
# and cc
# passing conj
# the det
# " punct
# Paycheck compound
# Fairness compound
# Act dobj
# . punct
# " punct
#
# Many amod
# working amod
# parents nsubj
# spend ROOT
# up prt
# to prep
# a det
# quarter compound
# — pobj
# a det
# quarter compound
# — ROOT
# of prep
# their poss
# income pobj
# on prep
# child compound
# care pobj
# . punct
# Last amod
# year npadvmod
# , punct
# we nsubj
# helped ROOT
# parents nsubj
# provide ccomp
# child compound
# care dobj
# for prep
# about advmod
# two compound
# million nummod
# children pobj
# . punct
# My poss
# child compound
# care compound
# initiative nsubj
# before prep
# you pobj
# now advmod
# , punct
# along prep
# with prep
# funds pobj
# already advmod
# secured acl
# in prep
# welfare compound
# reform pobj
# , punct
# would aux
# make ROOT
# child nsubj
# care ccomp
# better advmod
# , punct
# safer conj
# , punct
# and cc
# more advmod
# affordable conj
# for prep
# another det
# 400,000 nummod
# children pobj
# . punct
# I nsubj
# ask ROOT
# you dobj
# to aux
# pass xcomp
# that dobj
# . punct
# They nsubj
# need ROOT
# it dobj
# out advmod
# there advmod
# . punct
#
# For prep
# hard advmod
# - punct
# pressed amod
# middle amod
# income compound
# families pobj
# , punct
# we nsubj
# should aux
# also advmod
# expand ROOT
# the det
# child compound
# care compound
# tax compound
# credit dobj
# . punct
# And cc
# I nsubj
# believe ROOT
# strongly advmod
# we nsubj
# should aux
# take ccomp
# the det
# next amod
# big amod
# step dobj
# and cc
# make conj
# that mark
# tax compound
# credit nsubj
# refundable ccomp
# for prep
# low amod
# income compound
# families pobj
# . punct
# For prep
# people pobj
# making acl
# under prep
# $ nmod
# 30,000 pobj
# a det
# year npadvmod
# , punct
# that nsubj
# could aux
# mean ROOT
# up quantmod
# to quantmod
# $ quantmod
# 2,400 dobj
# for prep
# child compound
# care compound
# costs pobj
# . punct
# You nsubj
# know parataxis
# , punct
# we nsubj
# all appos
# say ROOT
# we nsubj
# ’re advmod
# pro subtok
# - subtok
# work ccomp
# and cc
# pro subtok
# - subtok
# family punct
# . punct
# Passing csubj
# this det
# proposal dobj
# would aux
# prove ROOT
# it dobj
# . punct
#
# Ten nsubj
# of prep
# millions pobj
# of prep
# Americans pobj
# live ROOT
# from prep
# paycheck pobj
# to prep
# paycheck pobj
# . punct
# As advmod
# hard advcl
# as mark
# they nsubj
# work advcl
# , punct
# they nsubj
# still advmod
# do aux
# n’t punct
# have ROOT
# the det
# opportunity dobj
# to aux
# save acl
# . punct
# Too advmod
# few nsubj
# can aux
# make ROOT
# use dobj
# of prep
# IRAs pobj
# and cc
# 401k nummod
# plans conj
# . punct
# We nsubj
# should aux
# do ROOT
# more dobj
# to aux
# help advcl
# all det
# working amod
# families nsubj
# save ccomp
# and cc
# accumulate conj
# wealth dobj
# . punct
# That nsubj
# ’s ROOT
# the det
# idea dobj
# behind prep
# the det
# Individual compound
# Development compound
# Accounts pobj
# , punct
# the det
# IDAs appos
# . punct
# I nsubj
# ask ROOT
# you dobj
# to aux
# take xcomp
# that det
# idea dobj
# to prep
# a det
# new amod
# level pobj
# , punct
# with prep
# new amod
# retirement compound
# savings compound
# accounts pobj
# that nsubj
# enable relcl
# every det
# low amod
# and cc
# moderate conj
# income compound
# family dobj
# in prep
# America pobj
# to aux
# save relcl
# for prep
# retirement pobj
# , punct
# a det
# first amod
# home appos
# , punct
# a det
# medical amod
# emergency conj
# , punct
# or cc
# a det
# college compound
# education conj
# . punct
# I nsubj
# propose ROOT
# to aux
# match xcomp
# their poss
# contributions dobj
# , punct
# however advmod
# small amod
# , punct
# dollar dep
# for prep
# dollar pobj
# , punct
# every det
# year npadvmod
# they nsubj
# save relcl
# . punct
# And cc
# I nsubj
# propose ROOT
# to aux
# give xcomp
# a det
# major amod
# new amod
# tax compound
# credit dobj
# to dative
# any det
# small amod
# business pobj
# that nsubj
# will aux
# provide relcl
# a det
# meaningful amod
# pension dobj
# to prep
# its poss
# workers pobj
# . punct
# Those det
# people nsubj
# ought ROOT
# to aux
# have xcomp
# retirement dobj
# as advmod
# well advmod
# as cc
# the det
# rest conj
# of prep
# us pobj
# . punct
#
# Nearly advmod
# one quantmod
# in quantmod
# three nummod
# American amod
# children nsubj
# grows ROOT
# up prt
# without prep
# a det
# father pobj
# . punct
# These det
# children nsubj
# are ROOT
# five npadvmod
# times quantmod
# more advmod
# likely acomp
# to aux
# live xcomp
# in prep
# poverty pobj
# than prep
# children pobj
# with prep
# both det
# parents pobj
# at prep
# home pobj
# . punct
# Clearly advmod
# , punct
# demanding csubj
# and cc
# supporting conj
# responsible amod
# fatherhood dobj
# is ROOT
# critical acomp
# to prep
# lifting pcomp
# all predet
# our poss
# children dobj
# out prep
# of prep
# poverty pobj
# . punct
# We nsubj
# ’ve appos
# doubled ROOT
# child compound
# support compound
# collections dobj
# since prep
# 1992 pobj
# . punct
# And cc
# I nsubj
# ’m ROOT
# proposing acl
# to prep
# you pobj
# tough amod
# new amod
# measures dobj
# to aux
# hold relcl
# still advmod
# more amod
# fathers dobj
# responsible amod
# . punct
#
# But cc
# we nsubj
# should aux
# recognize ROOT
# that mark
# a det
# lot nsubj
# of prep
# fathers pobj
# want ccomp
# to aux
# do xcomp
# right dobj
# by prep
# their poss
# children pobj
# but cc
# need conj
# help dobj
# to aux
# do xcomp
# it dobj
# . punct
# Carlos compound
# Rosas nsubj
# of prep
# St. compound
# Paul pobj
# , punct
# Minnesota appos
# , punct
# wanted ROOT
# to aux
# do xcomp
# right advmod
# by prep
# his poss
# son pobj
# , punct
# and cc
# he nsubj
# got conj
# the det
# help dobj
# to aux
# do acl
# it dobj
# . punct
# Now advmod
# he nsubj
# ’s appos
# got ROOT
# a det
# good amod
# job dobj
# , punct
# and cc
# he nsubj
# supports conj
# his poss
# little amod
# boy dobj
# . punct
# My poss
# budget nsubj
# will aux
# help ROOT
# 40,000 nummod
# more amod
# fathers nsubj
# make ccomp
# the det
# same amod
# choices dobj
# Carlos compound
# Rosas nsubj
# did relcl
# . punct
# I nsubj
# thank ROOT
# him dobj
# for prep
# being pcomp
# here advmod
# tonight npadvmod
# . punct
# Stand ROOT
# up prt
# , punct
# Carlos npadvmod
# . punct
# [ punct
# Applause ROOT
# ] punct
# Thank ROOT
# you dobj
# . punct
#
# If mark
# there expl
# is advcl
# any det
# single amod
# issue attr
# on prep
# which pobj
# we nsubj
# should aux
# be relcl
# able acomp
# to aux
# reach xcomp
# across prep
# party compound
# lines pobj
# , punct
# it nsubj
# is ROOT
# in prep
# our poss
# common amod
# commitment pobj
# to aux
# reward acl
# work dobj
# and cc
# strengthen conj
# families dobj
# . punct
# Just advmod
# remember ROOT
# what dobj
# we nsubj
# did ccomp
# last amod
# year npadvmod
# . punct
# We nsubj
# came ROOT
# together advmod
# to aux
# help advcl
# people dobj
# with prep
# disabilities pobj
# keep xcomp
# their poss
# health compound
# insurance dobj
# when advmod
# they nsubj
# go advcl
# to prep
# work pobj
# . punct
# And cc
# I nsubj
# thank ROOT
# you dobj
# for prep
# that pobj
# . punct
# Thanks npadvmod
# to prep
# overwhelming amod
# bipartisan amod
# support pobj
# from prep
# this det
# Congress pobj
# , punct
# we nsubj
# have aux
# improved ROOT
# foster amod
# care dobj
# . punct
# We nsubj
# ’ve appos
# helped ROOT
# those det
# young amod
# people dobj
# who nsubj
# leave relcl
# it dobj
# when advmod
# they nsubj
# turn advcl
# 18 dobj
# , punct
# and cc
# we nsubj
# have aux
# dramatically advmod
# increased conj
# the det
# number dobj
# of prep
# foster amod
# care compound
# children pobj
# going acl
# into prep
# adoptive amod
# homes pobj
# . punct
# I nsubj
# thank ROOT
# all dobj
# of prep
# you pobj
# for prep
# all pobj
# of prep
# that pobj
# . punct
#
# Of advmod
# course advmod
# , punct
# I nsubj
# am ROOT
# forever advmod
# grateful acomp
# to prep
# the det
# person pobj
# who nsubj
# has aux
# led relcl
# our poss
# efforts dobj
# from prep
# the det
# beginning pobj
# and cc
# who dobj
# ’s nsubj
# worked conj
# so advmod
# tirelessly advmod
# for prep
# children pobj
# and cc
# families conj
# for prep
# 30 nummod
# years pobj
# now advmod
# , punct
# my poss
# wife dep
# , punct
# Hillary appos
# , punct
# and cc
# I nsubj
# thank conj
# her dobj
# . punct
#
# If mark
# we nsubj
# take advcl
# the det
# steps dobj
# just advmod
# discussed acl
# , punct
# we nsubj
# can aux
# go ROOT
# a det
# long amod
# , punct
# long amod
# way npadvmod
# toward prep
# empowering pcomp
# parents nsubj
# to aux
# succeed ccomp
# at prep
# home pobj
# and cc
# at conj
# work pobj
# and cc
# ensuring advcl
# that mark
# no det
# child nsubjpass
# is auxpass
# raised ccomp
# in prep
# poverty pobj
# . punct
# We nsubj
# can aux
# make ROOT
# these det
# vital amod
# investments dobj
# in prep
# health compound
# care pobj
# , punct
# education conj
# , punct
# support conj
# for prep
# working amod
# families pobj
# , punct
# and cc
# still advmod
# offer conj
# tax compound
# cuts dobj
# to aux
# help advcl
# pay xcomp
# for prep
# college pobj
# , punct
# for prep
# retirement pobj
# , punct
# to aux
# care xcomp
# for prep
# aging amod
# parents pobj
# , punct
# to aux
# reduce advcl
# the det
# marriage compound
# penalty dobj
# . punct
# We nsubj
# can aux
# do ROOT
# these det
# things dobj
# without prep
# forsaking pcomp
# the det
# path dobj
# of prep
# fiscal amod
# discipline pobj
# that nsubj
# got relcl
# us dobj
# to prep
# this det
# point pobj
# here advmod
# tonight npadvmod
# . punct
# Indeed advmod
# , punct
# we nsubj
# must aux
# make ROOT
# these det
# investments dobj
# and cc
# these det
# tax compound
# cuts conj
# in prep
# the det
# context pobj
# of prep
# a det
# balanced amod
# budget pobj
# that nsubj
# strengthens relcl
# and cc
# extends conj
# the det
# life dobj
# of prep
# Social compound
# Security pobj
# and cc
# Medicare conj
# and cc
# pays conj
# down prt
# the det
# national amod
# debt dobj
# . punct
#
# Crime nsubj
# in prep
# America pobj
# has aux
# dropped ROOT
# for prep
# the det
# past amod
# seven nummod
# years pobj
# — advcl
# that nsubj
# ’s ccomp
# the det
# longest amod
# decline dobj
# on prep
# record— pobj
# thanks npadvmod
# to prep
# a det
# national amod
# consensus pobj
# we nsubj
# helped relcl
# to aux
# forge xcomp
# on prep
# community compound
# police pobj
# , punct
# sensible amod
# gun compound
# safety compound
# laws conj
# , punct
# and cc
# effective amod
# prevention conj
# . punct
# But cc
# nobody nsubj
# , punct
# nobody appos
# here advmod
# , punct
# nobody nsubj
# in prep
# America pobj
# believes ROOT
# we nsubj
# ’re ccomp
# safe ccomp
# enough advmod
# . punct
# So advmod
# again advmod
# , punct
# I nsubj
# ask ROOT
# you dobj
# to aux
# set xcomp
# a det
# higher amod
# goal dobj
# . punct
# Let ROOT
# ’s nsubj
# make ccomp
# this det
# country nsubj
# the det
# safest amod
# big amod
# country ccomp
# in prep
# the det
# world pobj
# . punct
#
# Last amod
# fall npadvmod
# , punct
# Congress nsubj
# supported ROOT
# my poss
# plan dobj
# to aux
# hire acl
# , punct
# in prep
# addition pobj
# to prep
# the det
# 100,000 nummod
# community compound
# police pobj
# we nsubj
# ’ve appos
# already advmod
# funded relcl
# , punct
# 50,000 appos
# more amod
# , punct
# concentrated acl
# in prep
# high amod
# - punct
# crime compound
# neighborhoods pobj
# . punct
# I nsubj
# ask ROOT
# your poss
# continued amod
# support dobj
# for prep
# that pobj
# . punct
#
# Soon advmod
# after prep
# the det
# Columbine compound
# tragedy pobj
# , punct
# Congress nsubj
# considered ROOT
# commonsense compound
# gun compound
# legislation dobj
# , punct
# to aux
# require advcl
# Brady compound
# background compound
# checks dobj
# at prep
# the det
# gun compound
# shows pobj
# , punct
# child compound
# safety compound
# locks dobj
# for prep
# new amod
# handguns pobj
# , punct
# and cc
# a det
# ban conj
# on prep
# the det
# importation pobj
# of prep
# large amod
# capacity compound
# ammunition compound
# clips pobj
# . punct
# With prep
# courage pobj
# and cc
# a det
# tie npadvmod
# - punct
# breaking amod
# vote conj
# by prep
# the det
# Vice compound
# President—[laughter pobj
# ] punct
# —the amod
# Senate nsubj
# faced ROOT
# down prt
# the det
# gun compound
# lobby dobj
# , punct
# stood conj
# up prt
# for prep
# the det
# American amod
# people pobj
# , punct
# and cc
# passed conj
# this det
# legislation dobj
# . punct
# But cc
# the det
# House nsubj
# failed ROOT
# to aux
# follow xcomp
# suit dobj
# . punct
#
# Now advmod
# , punct
# we nsubj
# have aux
# all dep
# seen ROOT
# what nsubj
# happens ccomp
# when advmod
# guns nsubj
# fall advcl
# into prep
# the det
# wrong amod
# hands pobj
# . punct
# Daniel compound
# Mauser nsubj
# was ROOT
# only advmod
# 15 nummod
# years npadvmod
# old acomp
# when advmod
# he nsubjpass
# was auxpass
# gunned advcl
# down prt
# at prep
# Columbine pobj
# . punct
# He nsubj
# was ROOT
# an det
# amazing amod
# kid attr
# , punct
# a det
# straight amod
# - punct
# A compound
# student appos
# , punct
# a det
# good amod
# skier appos
# . punct
# Like prep
# all det
# parents pobj
# who nsubj
# lose relcl
# their poss
# children dobj
# , punct
# his poss
# father appos
# , punct
# Tom appos
# , punct
# has aux
# borne ROOT
# unimaginable amod
# grief dobj
# . punct
# Somehow advmod
# he nsubj
# has aux
# found ROOT
# the det
# strength dobj
# to aux
# honor acl
# his poss
# son dobj
# by prep
# transforming pcomp
# his poss
# grief dobj
# into prep
# action pobj
# . punct
# Earlier advmod
# this det
# month npadvmod
# , punct
# he nsubj
# took ROOT
# a det
# leave dobj
# of prep
# absence pobj
# from prep
# his poss
# job pobj
# to aux
# fight advcl
# for prep
# tougher amod
# gun compound
# safety compound
# laws pobj
# . punct
# I nsubj
# pray ROOT
# that mark
# his poss
# courage nsubj
# and cc
# wisdom conj
# will aux
# at advmod
# long advmod
# last amod
# move ccomp
# this det
# Congress dobj
# to aux
# make advcl
# commonsense compound
# gun compound
# legislation dobj
# the det
# very advmod
# next amod
# order ccomp
# of prep
# business pobj
# . punct
# Tom compound
# Mauser nsubj
# , punct
# stand ROOT
# up prt
# . punct
# We nsubj
# thank ROOT
# you dobj
# for prep
# being pcomp
# here advmod
# tonight npadvmod
# . punct
# Tom ROOT
# . punct
# Thank ROOT
# you dobj
# , punct
# Tom npadvmod
# . punct
# [ punct
# Applause ROOT
# ] punct
#
# We nsubj
# must aux
# strengthen ROOT
# our poss
# gun compound
# laws dobj
# and cc
# enforce conj
# those dobj
# already advmod
# on prep
# the det
# books pobj
# better advmod
# . punct
# Federal amod
# gun compound
# crime compound
# prosecutions nsubj
# are ROOT
# up advmod
# 16 nummod
# percent npadvmod
# since mark
# I nsubj
# took advcl
# office dobj
# . punct
# But cc
# we nsubj
# must aux
# do ROOT
# more dobj
# . punct
# I nsubj
# ...
# employment pobj
# but cc
# now advmod
# accounts conj
# for prep
# a det
# third pobj
# of prep
# our poss
# economic amod
# growth pobj
# along prep
# with prep
# jobs pobj
# that nsubj
# pay relcl
# , punct
# by prep
# the det
# way pobj
# , punct
# about advmod
# 80 nummod
# percent npadvmod
# above prep
# the det
# private amod
# sector compound
# average pobj
# . punct
# Again advmod
# , punct
# we nsubj
# ought ROOT
# to aux
# keep xcomp
# in prt
# mind pobj
# , punct
# government npadvmod
# - punct
# funded amod
# research nsubj
# brought conj
# supercomputers dobj
# , punct
# the det
# Internet conj
# , punct
# and cc
# communications compound
# satellites conj
# into prep
# being pcomp
# . punct
# Soon advmod
# researchers nsubj
# will aux
# bring ROOT
# us dative
# devices dobj
# that nsubj
# can aux
# translate relcl
# foreign amod
# languages dobj
# as advmod
# fast advmod
# as mark
# you nsubj
# can aux
# talk advcl
# , punct
# materials conj
# 10 nummod
# times npadvmod
# stronger amod
# than prep
# steel pobj
# at prep
# a det
# fraction pobj
# of prep
# the det
# weight pobj
# , punct
# and cc
# — conj
# this nsubj
# is conj
# unbelievable acomp
# to prep
# me pobj
# — nmod
# molecular amod
# computers ROOT
# the det
# size dobj
# of prep
# a det
# teardrop pobj
# with prep
# the det
# power pobj
# of prep
# today poss
# ’s nummod
# fastest amod
# supercomputers pobj
# . punct
#
# To aux
# accelerate advcl
# the det
# march dobj
# of prep
# discovery pobj
# across prep
# all predet
# these det
# disciplines pobj
# in prep
# science pobj
# and cc
# technology conj
# , punct
# I nsubj
# ask ROOT
# you dobj
# to aux
# support xcomp
# my poss
# recommendation dobj
# of prep
# an det
# unprecedented amod
# $ quantmod
# 3 compound
# billion pobj
# in prep
# the det
# 21st amod
# century compound
# research compound
# fund pobj
# , punct
# the det
# largest amod
# increase appos
# in prep
# civilian amod
# research pobj
# in prep
# a det
# generation pobj
# . punct
# We nsubj
# owe ROOT
# it dobj
# to prep
# our poss
# future pobj
# . punct
#
# Now advmod
# , punct
# these det
# new amod
# breakthroughs nsubj
# have ROOT
# to aux
# be auxpass
# used xcomp
# in prep
# ways pobj
# that nsubj
# reflect relcl
# our poss
# values dobj
# . punct
# First advmod
# and cc
# foremost conj
# , punct
# we nsubj
# have ROOT
# to aux
# safeguard xcomp
# our poss
# citizens dobj
# ’ compound
# privacy dobj
# . punct
# Last amod
# year npadvmod
# we nsubj
# proposed ROOT
# to aux
# protect xcomp
# every det
# citizen nmod
# ’s case
# medical amod
# record dobj
# . punct
# This det
# year npadvmod
# we nsubj
# will aux
# finalize ROOT
# those det
# rules dobj
# . punct
# We nsubj
# ’ve appos
# also advmod
# taken ROOT
# the det
# first amod
# steps dobj
# to aux
# protect relcl
# the det
# privacy dobj
# of prep
# bank nmod
# and cc
# credit compound
# card conj
# records pobj
# and cc
# other amod
# financial amod
# statements conj
# . punct
# Soon advmod
# I nsubj
# will aux
# send ROOT
# legislation dobj
# to dative
# you pobj
# to aux
# finish advcl
# that det
# job dobj
# . punct
# We nsubj
# must aux
# also advmod
# act ROOT
# to aux
# prevent xcomp
# any det
# genetic amod
# discrimination dobj
# whatever ccomp
# by agent
# employers pobj
# or cc
# insurers conj
# . punct
# I nsubj
# hope ROOT
# you nsubj
# will aux
# support ccomp
# that dobj
# . punct
#
# These det
# steps nsubj
# will aux
# allow ROOT
# us nsubj
# to aux
# lead ccomp
# toward prep
# the det
# far amod
# frontiers pobj
# of prep
# science pobj
# and cc
# technology conj
# . punct
# They nsubj
# will aux
# enhance ccomp
# our poss
# health dobj
# , punct
# the det
# environment conj
# , punct
# the det
# economy nsubj
# in prep
# ways pobj
# we nsubj
# ca relcl
# n’t punct
# even advmod
# imagine ROOT
# today npadvmod
# . punct
# But cc
# we nsubj
# all appos
# know ROOT
# that mark
# at prep
# a det
# time pobj
# when advmod
# science nsubj
# , punct
# technology conj
# , punct
# and cc
# the det
# forces conj
# of prep
# globalization pobj
# are aux
# bringing relcl
# so advmod
# many amod
# changes dobj
# into prep
# all predet
# our poss
# lives pobj
# , punct
# it nsubj
# ’s ccomp
# more advmod
# important acomp
# than prep
# ever pcomp
# that mark
# we nsubj
# strengthen ccomp
# the det
# bonds dobj
# that nsubj
# root relcl
# us dobj
# in prep
# our poss
# local amod
# communities pobj
# and cc
# in conj
# our poss
# national amod
# community pobj
# . punct
#
# No det
# tie compound
# binds ROOT
# different amod
# people dobj
# together advmod
# like prep
# citizen compound
# service pobj
# . punct
# There expl
# ’s ROOT
# a det
# new amod
# spirit attr
# of prep
# service pobj
# in prep
# America pobj
# , punct
# a det
# movement appos
# we nsubj
# ’ve appos
# tried relcl
# to aux
# support xcomp
# with prep
# AmeriCorps pobj
# , punct
# expanded dep
# Peace compound
# Corps dobj
# , punct
# unprecedented amod
# new amod
# partnerships appos
# with prep
# businesses pobj
# , punct
# foundations conj
# , punct
# community compound
# groups conj
# ; punct
# partnerships conj
# , punct
# for prep
# example pobj
# , punct
# like prep
# the det
# one pobj
# that nsubj
# enlisted relcl
# 12,000 nummod
# companies dobj
# which nsubj
# have aux
# now advmod
# moved relcl
# 650,000 dobj
# of prep
# our poss
# fellow amod
# citizens pobj
# from prep
# welfare pobj
# to prep
# work pobj
# ; punct
# partnerships nsubj
# to prep
# battle compound
# drug compound
# abuse pobj
# , punct
# AIDS appos
# , punct
# teach conj
# young amod
# people dobj
# to aux
# read xcomp
# , punct
# save conj
# America compound
# ’s compound
# treasures dobj
# , punct
# strengthen conj
# the det
# arts dobj
# , punct
# fight conj
# teen compound
# pregnancy dobj
# , punct
# prevent conj
# violence dobj
# among prep
# young amod
# people pobj
# , punct
# promote conj
# racial amod
# healing dobj
# . punct
# The det
# American amod
# people nsubj
# are aux
# working ROOT
# together advmod
# . punct
#
# But cc
# we nsubj
# should aux
# do ROOT
# more dobj
# to aux
# help advcl
# Americans nsubj
# help ccomp
# each det
# other dobj
# . punct
# First advmod
# , punct
# we nsubj
# should aux
# help ROOT
# faith npadvmod
# - punct
# based amod
# organizations dobj
# to aux
# do xcomp
# more dobj
# to aux
# fight advcl
# poverty nmod
# and cc
# drug conj
# abuse dobj
# and cc
# help conj
# people nsubj
# get ccomp
# back advmod
# on prep
# the det
# right amod
# track pobj
# , punct
# with prep
# initiatives pobj
# like prep
# Second compound
# Chance compound
# Homes pobj
# that nsubj
# do relcl
# so advmod
# much dobj
# to aux
# help xcomp
# unwed xcomp
# teen compound
# mothers dobj
# . punct
# Second advmod
# , punct
# we nsubj
# should aux
# support ROOT
# Americans dobj
# who nsubj
# tithe relcl
# and cc
# contribute conj
# to prep
# charities pobj
# but cc
# do aux
# n’t punct
# earn conj
# enough dobj
# to aux
# claim acl
# a det
# tax compound
# deduction dobj
# for prep
# it pobj
# . punct
# Tonight npadvmod
# I nsubj
# propose ROOT
# new amod
# tax compound
# incentives dobj
# that nsubj
# would aux
# allow relcl
# low amod
# and cc
# middle conj
# income compound
# citizens nsubj
# who nsubj
# do aux
# n’t dobj
# itemize ccomp
# to aux
# get xcomp
# that det
# deduction dobj
# . punct
# It nsubj
# ’s ROOT
# nothing dobj
# but prep
# fair pobj
# , punct
# and cc
# it nsubj
# will aux
# get conj
# more amod
# people nsubj
# to aux
# give ccomp
# . punct
#
# We nsubj
# should aux
# do ROOT
# more dobj
# to aux
# help advcl
# new amod
# immigrants dobj
# to aux
# fully advmod
# participate acl
# in prep
# our poss
# community pobj
# . punct
# That nsubj
# ’s ROOT
# why advmod
# I nsubj
# recommend ccomp
# spending xcomp
# more dobj
# to aux
# teach advcl
# them dative
# civics dobj
# and cc
# English conj
# . punct
# And cc
# since prep
# everybody pobj
# in prep
# our poss
# community compound
# counts pobj
# , punct
# we nsubj
# ’ve appos
# got ROOT
# to aux
# make xcomp
# sure ccomp
# everyone nsubjpass
# is auxpass
# counted ccomp
# in prep
# this det
# year pobj
# ’s compound
# census pobj
# . punct
#
# Within prep
# 10 nummod
# years pobj
# — ROOT
# just advmod
# 10 nummod
# years npadvmod
# — ROOT
# there expl
# will aux
# be ccomp
# no det
# majority compound
# race attr
# in prep
# our poss
# largest amod
# state pobj
# of prep
# California pobj
# . punct
# In prep
# a quantmod
# little quantmod
# more amod
# than quantmod
# 50 nummod
# years pobj
# , punct
# there expl
# will aux
# be ROOT
# no det
# majority compound
# race attr
# in prep
# America pobj
# . punct
# In prep
# a det
# more advmod
# interconnected amod
# world pobj
# , punct
# this det
# diversity nsubj
# can aux
# be ROOT
# our poss
# greatest amod
# strength attr
# . punct
# Just advmod
# look ROOT
# around prep
# this det
# chamber pobj
# . punct
# Look ROOT
# around advmod
# . punct
# We nsubj
# have ROOT
# members dobj
# in prep
# this det
# Congress pobj
# from prep
# virtually advmod
# every nummod
# racial amod
# , punct
# ethnic amod
# , punct
# and cc
# religious conj
# background pobj
# . punct
# And cc
# I nsubj
# think ROOT
# you nsubj
# would aux
# agree ccomp
# that mark
# America nsubj
# is ccomp
# stronger acomp
# because prep
# of pcomp
# it pobj
# . punct
# [ punct
# Applause ROOT
# ] punct
#
# You nsubj
# also advmod
# have ROOT
# to aux
# agree xcomp
# that mark
# all predet
# those det
# differences nsubj
# you nsubj
# just advmod
# clapped relcl
# for prep
# all det
# too advmod
# often advmod
# spark ccomp
# hatred dobj
# and cc
# division conj
# even advmod
# here advmod
# at prep
# home pobj
# . punct
# Just advmod
# in prep
# the det
# last amod
# couple pobj
# of prep
# years pobj
# , punct
# we nsubj
# ’ve appos
# seen ROOT
# a det
# man nsubj
# dragged ccomp
# to prep
# death pobj
# in prep
# Texas pobj
# just advmod
# because mark
# he nsubj
# was advcl
# black acomp
# . punct
# We nsubj
# saw ROOT
# a det
# young amod
# man dobj
# murdered acl
# in prep
# Wyoming pobj
# just advmod
# because mark
# he nsubj
# was advcl
# gay acomp
# . punct
# Last amod
# year npadvmod
# we nsubj
# saw ROOT
# the det
# shootings dobj
# of prep
# African compound
# - punct
# Americans pobj
# , punct
# Asian compound
# - punct
# Americans conj
# , punct
# and cc
# Jewish amod
# children conj
# just advmod
# because prep
# of pcomp
# who attr
# they nsubj
# were pcomp
# . punct
# This nsubj
# is ROOT
# not neg
# the det
# American amod
# way attr
# , punct
# and cc
# we nsubj
# must aux
# draw conj
# the det
# line dobj
# . punct
#
# I nsubj
# ask ROOT
# you dobj
# to aux
# draw xcomp
# that det
# line dobj
# by prep
# passing pcomp
# without prep
# delay pcomp
# the det
# " punct
# Hate compound
# Crimes compound
# Prevention compound
# Act dobj
# " punct
# and cc
# the det
# " punct
# Employment compound
# Non subtok
# - subtok
# Discrimination compound
# Act conj
# . punct
# " ROOT
# And cc
# I nsubj
# ask ROOT
# you dobj
# to aux
# reauthorize xcomp
# the det
# Violence nmod
# Against prep
# Women pobj
# Act dobj
# . punct
#
# Finally advmod
# tonight npadvmod
# , punct
# I nsubj
# propose ROOT
# the det
# largest amod
# ever amod
# investment dobj
# in prep
# our poss
# civil amod
# rights compound
# laws pobj
# for prep
# enforcement pobj
# , punct
# because mark
# no det
# American nsubjpass
# should aux
# be auxpass
# subjected advcl
# to prep
# discrimination pobj
# in prep
# finding pcomp
# a det
# home dobj
# , punct
# getting conj
# a det
# job dobj
# , punct
# going conj
# to prep
# school pobj
# , punct
# or cc
# securing conj
# a det
# loan dobj
# . punct
# Protections nsubj
# in prep
# law pobj
# should aux
# be ROOT
# protections attr
# in prep
# fact pobj
# . punct
#
# Last amod
# February npadvmod
# , punct
# because mark
# I nsubj
# thought advcl
# this nsubj
# was ccomp
# so advmod
# important acomp
# , punct
# I nsubj
# created ROOT
# the det
# White compound
# House compound
# Office dobj
# of prep
# One nummod
# America pobj
# to aux
# promote advcl
# racial amod
# reconciliation dobj
# . punct
# That nsubj
# ’s ROOT
# what det
# one nsubj
# of prep
# my poss
# personal amod
# heroes pobj
# , punct
# Hank compound
# Aaron appos
# , punct
# has aux
# done ccomp
# all predet
# his poss
# life dobj
# . punct
# From prep
# his poss
# days pobj
# as prep
# our poss
# all det
# - punct
# time nmod
# home compound
# run compound
# king pobj
# to prep
# his poss
# recent amod
# acts pobj
# of prep
# healing pobj
# , punct
# he nsubj
# has aux
# always advmod
# brought ROOT
# people dobj
# together advmod
# . punct
# We nsubj
# should aux
# follow ROOT
# his poss
# example dobj
# , punct
# and cc
# we nsubj
# ’re appos
# honored conj
# to aux
# have xcomp
# him dobj
# with prep
# us pobj
# tonight npadvmod
# . punct
# Stand ROOT
# up prt
# , punct
# Hank compound
# Aaron npadvmod
# . punct
# [ punct
# Applause ROOT
# ] punct
#
# I nsubj
# just advmod
# want ROOT
# to aux
# say xcomp
# one nummod
# more amod
# thing dobj
# about prep
# this pobj
# , punct
# and cc
# I nsubj
# want conj
# every det
# one nsubj
# of prep
# you pobj
# to aux
# think ccomp
# about prep
# this pobj
# the det
# next amod
# time npadvmod
# you nsubj
# get relcl
# mad acomp
# at prep
# one pobj
# of prep
# your poss
# colleagues pobj
# on prep
# the det
# other amod
# side pobj
# of prep
# the det
# aisle pobj
# . punct
# This det
# fall npadvmod
# , punct
# at prep
# the det
# White compound
# House pobj
# , punct
# Hillary nsubj
# had ROOT
# one dobj
# of prep
# her poss
# millennium compound
# dinners pobj
# , punct
# and cc
# we nsubj
# had conj
# this det
# very advmod
# distinguished amod
# scientist dobj
# there advmod
# , punct
# who nsubj
# is relcl
# an det
# expert attr
# in prep
# this det
# whole amod
# work pobj
# in prep
# the det
# human amod
# genome pobj
# . punct
# And cc
# he nsubj
# said ROOT
# that mark
# we nsubj
# are ccomp
# all advmod
# , punct
# regardless advmod
# of prep
# race pobj
# , punct
# genetically advmod
# 99.9 nummod
# percent appos
# the det
# same npadvmod
# . punct
#
# Now advmod
# , punct
# you nsubj
# may aux
# find ROOT
# that advmod
# uncomfortable ccomp
# when advmod
# you nsubj
# look advcl
# around advmod
# here advmod
# . punct
# [ punct
# Laughter ROOT
# ] punct
# But cc
# it nsubj
# is ROOT
# worth acomp
# remembering xcomp
# . punct
# We nsubj
# can aux
# laugh ROOT
# about prep
# this pobj
# , punct
# but cc
# you nsubj
# think conj
# about prep
# it pobj
# . punct
# Modern amod
# science nsubj
# has aux
# confirmed ccomp
# what det
# ancient amod
# faiths nsubj
# have aux
# always advmod
# taught ccomp
# : punct
# the det
# most advmod
# important amod
# fact nsubj
# of prep
# life pobj
# is ROOT
# our poss
# common amod
# humanity attr
# . punct
# Therefore advmod
# , punct
# we nsubj
# should aux
# do ccomp
# more dobj
# than mark
# just advmod
# tolerate advcl
# our poss
# diversity dobj
# ; punct
# we nsubj
# should aux
# honor ROOT
# it dobj
# and cc
# celebrate conj
# it dobj
# . punct
#
# My poss
# fellow amod
# Americans npadvmod
# , punct
# every det
# time npadvmod
# I nsubj
# prepare relcl
# for prep
# the det
# State pobj
# of prep
# the det
# Union pobj
# , punct
# I nsubj
# approach ROOT
# it dobj
# with prep
# hope pobj
# and cc
# expectation conj
# and cc
# excitement conj
# for prep
# our poss
# nation pobj
# . punct
# But cc
# tonight nsubj
# is ROOT
# very advmod
# special acomp
# , punct
# because mark
# we nsubj
# stand advcl
# on prep
# the det
# mountaintop pobj
# of prep
# a det
# new amod
# millennium pobj
# . punct
# Behind prep
# us pobj
# we nsubj
# can aux
# look ROOT
# back advmod
# and cc
# see conj
# the det
# great amod
# expanse dobj
# of prep
# American amod
# achievement pobj
# , punct
# and cc
# before prep
# us pobj
# we nsubj
# can aux
# see conj
# even advmod
# greater acomp
# , punct
# grander amod
# frontiers dobj
# of prep
# possibility pobj
# . punct
# We nsubj
# should ccomp
# , punct
# all nsubjpass
# of prep
# us pobj
# , punct
# be auxpass
# filled ROOT
# with prep
# gratitude pobj
# and cc
# humility conj
# for prep
# our poss
# present amod
# progress pobj
# and cc
# prosperity conj
# . punct
# We nsubjpass
# should aux
# be auxpass
# filled ROOT
# with prep
# awe pobj
# and cc
# joy conj
# at prep
# what nsubj
# lies pcomp
# over prep
# the det
# horizon pobj
# . punct
# And cc
# we nsubjpass
# should aux
# be auxpass
# filled ROOT
# with prep
# absolute amod
# determination pobj
# to aux
# make advcl
# the det
# most dobj
# of prep
# it pobj
# . punct
#
# You nsubj
# know parataxis
# , punct
# when advmod
# the det
# Framers nsubj
# finished advcl
# crafting xcomp
# our poss
# Constitution dobj
# in prep
# Philadelphia pobj
# , punct
# Benjamin compound
# Franklin nsubj
# stood ROOT
# in prep
# Independence compound
# Hall pobj
# , punct
# and cc
# he nsubj
# reflected conj
# on prep
# the det
# carving pobj
# of prep
# the det
# sun pobj
# that nsubj
# was relcl
# on prep
# the det
# back pobj
# of prep
# a det
# chair pobj
# he nsubj
# saw relcl
# . punct
# The det
# sun nsubj
# was ROOT
# low acomp
# on prep
# the det
# horizon pobj
# . punct
# So advmod
# he nsubj
# said ROOT
# this det
# — dobj
# he nsubj
# said ROOT
# , punct
# " punct
# I nsubj
# ’ve pobj
# often advmod
# wondered ccomp
# whether mark
# that det
# sun nsubj
# was aux
# rising ccomp
# or cc
# setting conj
# . punct
# Today npadvmod
# , punct
# " punct
# Franklin nsubj
# said ROOT
# , punct
# " punct
# I nsubj
# have ccomp
# the det
# happiness dobj
# to aux
# know relcl
# it dobj
# ’s ccomp
# a det
# rising amod
# sun dobj
# . punct
# " punct
# Today npadvmod
# , punct
# because mark
# each det
# succeeding amod
# generation nsubj
# of prep
# Americans pobj
# has aux
# kept advcl
# the det
# fire dobj
# of prep
# freedom pobj
# burning acl
# brightly advmod
# , punct
# lighting advcl
# those det
# frontiers dobj
# of prep
# possibility pobj
# , punct
# we nsubj
# all appos
# still advmod
# bask ROOT
# in prep
# the det
# glow pobj
# and cc
# the det
# warmth conj
# of prep
# Mr. compound
# Franklin nmod
# ’s pobj
# rising amod
# sun pobj
# . punct
#
# After prep
# 224 nummod
# years pobj
# , punct
# the det
# American amod
# revolution nsubj
# continues ROOT
# . punct
# We nsubj
# remain ROOT
# a det
# new amod
# nation attr
# . punct
# And cc
# as advmod
# long advmod
# as mark
# our poss
# dreams nsubj
# outweigh advcl
# our poss
# memories dobj
# , punct
# America nsubj
# will aux
# be ROOT
# forever advmod
# young acomp
# . punct
# That nsubj
# is ROOT
# our poss
# destiny attr
# . punct
# And cc
# this nsubj
# is ROOT
# our poss
# moment attr
# . punct
#
# Thank advcl
# you dobj
# , punct
# God nsubj
# bless ROOT
# you dobj
# , punct
# and cc
# God nsubj
# bless conj
# America dobj
# . punct
#
# Hide ROOT
# Transcript dobj

# %%
# visualizing the sentence
from spacy import displacy

# %%
first_sent = list(doc.sents)[0]
first_sent
# Out:
# Mr. Speaker, Mr. Vice President, members of Congress, honored guests, my fellow Americans:

# %%
single_doc = nlp(str(first_sent))
options = {"compact": True, 'bg': '#09a3d5',
           'color': 'white', 'font': 'Source Sans Pro'}
displacy.render(single_doc, style="dep", jupyter=True, options=options)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a7adf84ee11648cdad8c4ee5662f119b-0" class="displacy" width="2150" height="512.0" direction="ltr" style="max-width: none; height: 512.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Mr.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">Speaker,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">Mr.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">Vice</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">President,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">members</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Congress,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">honored</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">guests,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">my</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">fellow</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">Americans:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">SPACE</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a7adf84ee11648cdad8c4ee5662f119b-0-0" stroke-width="2px" d="M62,377.0 62,352.0 188.0,352.0 188.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a7adf84ee11648cdad8c4ee5662f119b-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,379.0 L58,371.0 66,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a7adf84ee11648cdad8c4ee5662f119b-0-1" stroke-width="2px" d="M362,377.0 362,327.0 641.0,327.0 641.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a7adf84ee11648cdad8c4ee5662f119b-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M362,379.0 L358,371.0 366,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a7adf84ee11648cdad8c4ee5662f119b-0-2" stroke-width="2px" d="M512,377.0 512,352.0 638.0,352.0 638.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a7adf84ee11648cdad8c4ee5662f119b-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M512,379.0 L508,371.0 516,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a7adf84ee11648cdad8c4ee5662f119b-0-3" stroke-width="2px" d="M212,377.0 212,302.0 644.0,302.0 644.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a7adf84ee11648cdad8c4ee5662f119b-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M644.0,379.0 L648.0,371.0 640.0,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a7adf84ee11648cdad8c4ee5662f119b-0-4" stroke-width="2px" d="M662,377.0 662,352.0 788.0,352.0 788.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a7adf84ee11648cdad8c4ee5662f119b-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M788.0,379.0 L792.0,371.0 784.0,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a7adf84ee11648cdad8c4ee5662f119b-0-5" stroke-width="2px" d="M812,377.0 812,352.0 938.0,352.0 938.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a7adf84ee11648cdad8c4ee5662f119b-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M938.0,379.0 L942.0,371.0 934.0,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a7adf84ee11648cdad8c4ee5662f119b-0-6" stroke-width="2px" d="M962,377.0 962,352.0 1088.0,352.0 1088.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a7adf84ee11648cdad8c4ee5662f119b-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1088.0,379.0 L1092.0,371.0 1084.0,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a7adf84ee11648cdad8c4ee5662f119b-0-7" stroke-width

# %% [markdown]
# <div style="font-size: 1em; margin: 1em 0 1em 0; border: 1px solid #86989B; background-color: #f7f7f7; padding: 0;">
# <p style="margin: 0; padding: 0.1em 0 0.1em 0.5em; color: white; border-bottom: 1px solid #86989B; font-weight: bold; background-color: #AFC1C4;">
# Activity
# </p>
# <p style="margin: 0.5em 1em 0.5em 1em; padding: 0;">
# Write a function `count_chars(text)` that receives `text` and returns the total number of characters ignoring spaces and punctuation marks. For example, `count_chars("Well, I am not 30 years old.")` should return `20`.
# <br/>
# * **Hint**: You could count the characters in the words.*
# </p>
# </div>

# %%
# Solution using two functions, one to get just words without punct, one to get chars
def return_words(doc):
    return [token.text for token in doc if token.pos_ is not 'PUNCT']

def count_chars(words):
    return sum(len(w) for w in words)

# count_chars("Well, I am not 30 years old.")
words = return_words(nlp("Well, I am not 30 years old."))
count_chars(words)

# %% [markdown]
# ## Named Entity Recognition

# %%
# https://spacy.io/api/annotation#named-entities
# trained on OntoNotes corpus
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Speaker PERSON
# Congress ORG
# Americans NORP
# Union of our Founders ORG
# the new century DATE
# over 20 million CARDINAL
# more than 30 years DATE
# 30 years DATE
# 20 years DATE
# African-American NORP
# Hispanic NORP
# first ORDINAL
# 42 years DATE
# next month DATE
# America GPE
# American NORP
# 20 percent PERCENT
# 25 years DATE
# seven years in a row DATE
# 30 percent PERCENT
# half CARDINAL
# 30 years DATE
# Americans NORP
# Union ORG
# American NORP
# Eight years ago DATE
# Americans NORP
# the year 2000 DATE
# America GPE
# Americans NORP
# Americans NORP
# 40 years DATE
# 100,000 CARDINAL
# Brady PERSON
# half a million CARDINAL
# 20 million CARDINAL
# Americans NORP
# 150,000 CARDINAL
# Americans NORP
# AmeriCorps ORG
# 1992 DATE
# Today DATE
# America GPE
# Americans NORP
# the 21st century DATE
# a 21st century DATE
# American NORP
# the last century DATE
# Theodore Roosevelt PERSON
# one CARDINAL
# tonight TIME
# America GPE
# America GPE
# Americans NORP
# America GPE
# Earth LOC
# first ORDINAL
# 1835 DATE
# American NORP
# America GPE
# White House ORG
# One CARDINAL
# this year DATE
# this decade DATE
# first ORDINAL
# American Revolution EVENT
# a single year DATE
# the last seven years DATE
# Congress ORG
# tonight TIME
# Patients’ Bill of Rights LAW
# two years ago DATE
# first ORDINAL
# seven years ago DATE
# just 13 years DATE
# America GPE
# first ORDINAL
# Andrew Jackson PERSON
# 1835 DATE
# 1993 DATE
# the Deficit Reduction Act LAW
# Houses ORG
# Treasury ORG
# tonight TIME
# Lloyd Bentsen PERSON
# America GPE
# two CARDINAL
# American NORP
# Social Security ORG
# Medicare ORG
# Tonight TIME
# Social Security ORG
# Social Security Trust  Fund ORG
# the next 50 years DATE
# First ORDINAL
# a 21st century DATE
# seven years DATE
# Congress ORG
# Each year DATE
# more than $15 billion MONEY
# America GPE
# 1993 DATE
# Start PERSON
# Tonight TIME
# $1 billion MONEY
# two years in a row DATE
# Congress ORG
# 100,000 CARDINAL
# three CARDINAL
# tonight TIME
# one CARDINAL
# America GPE
# Today DATE
# 1,700 CARDINAL
# 3,000 CARDINAL
# next year DATE
# 1994 DATE
# only 3 percent PERCENT
# Today DATE
# more than half CARDINAL
# 90 percent PERCENT
# at least one CARDINAL
# a third CARDINAL
# tonight TIME
# 5,000 CARDINAL
# 6,000 CARDINAL
# 1.4 million CARDINAL
# American NORP
# seven years DATE
# Pell Grants PERSON
# five million CARDINAL
# 67 percent PERCENT
# 10 percent PERCENT
# 1993 DATE
# millions CARDINAL
# $30 billion MONEY
# up to $10,000 MONEY
# Congress ORG
# two years DATE
# four years DATE
# a 21st century DATE
# 1997 DATE
# the Children’s Health Insurance Program—CHIP ORG
# two million CARDINAL
# five million CARDINAL
# more than 40 million CARDINAL
# Americans NORP
# 1993 DATE
# Tonight TIME
# Gore PERSON
# nearly a quarter DATE
# America GPE
# between the ages of 55 and 65 DATE
# Medicare ORG
# this year DATE
# Medicare ORG
# Medicare ORG
# Medicare ORG
# nearly $400 billion MONEY
# Medicare ORG
# past 2025 DATE
# Medicare ORG
# today DATE
# more than three CARDINAL
# five CARDINAL
# Millions CARDINAL
# Americans NORP
# Americans NORP
# Last year DATE
# 1,000 MONEY
# This year DATE
# ’s ORG
# 3,000 MONEY
# this year DATE
# first ORDINAL
# White House Conference on Mental Health EVENT
# last year DATE
# seven years DATE
# Tipper Gore PERSON
# the 35 years DATE
# Medicare ORG
# 35 years DATE
# Americans NORP
# EITC ORG
# EITC ORG
# first ORDINAL
# Congress ORG
# 1998 DATE
# EITC ORG
# more than 4.3 million CARDINAL
# Americans NORP
# 1993 DATE
# Tonight TIME
# EITC ORG
# more than two CARDINAL
# more than two CARDINAL
# today DATE
# three CARDINAL
# up to $1,100 MONEY
# 46 years DATE
# about 75 cents MONEY
# Paycheck Fairness Act LAW
# Last year DATE
# about two million CARDINAL
# 400,000 CARDINAL
# 30,000 MONEY
# 2,400 MONEY
# Ten of millions CARDINAL
# Americans NORP
# 401k PRODUCT
# America GPE
# first ORDINAL
# every year DATE
# Nearly one CARDINAL
# three CARDINAL
# American NORP
# five CARDINAL
# 1992 DATE
# ’m PERSON
# Carlos Rosas PERSON
# St. Paul GPE
# Minnesota GPE
# 40,000 CARDINAL
# Carlos Rosas PERSON
# tonight TIME
# Carlos PERSON
# last year DATE
# Congress ORG
# 18 DATE
# 30 years DATE
# Hillary PERSON
# tonight TIME
# Social Security ORG
# Medicare ORG
# America GPE
# the past seven years DATE
# ’s ORG
# America GPE
# Last fall DATE
# Congress ORG
# 100,000 CARDINAL
# 50,000 CARDINAL
# Columbine ORG
# Congress ORG
# Brady PERSON
# Senate ORG
# American NORP
# House ORG
# Daniel Mauser PERSON
# only 15 years old DATE
# Columbine ORG
# Tom PERSON
# Earlier this month DATE
# Congress ORG
# Tom Mauser PERSON
# tonight TIME
# Tom PERSON
# Tom PERSON
# 16 percent PERCENT
# ATF ORG
# the United States GPE
# first ORDINAL
# Brady PERSON
# Congress ORG
# under 15 DATE
# the United States GPE
# nine CARDINAL
# 25 CARDINAL
# Congress ORG
# ’s ORG
# tonight TIME
# America GPE
# a 21st century DATE
# America GPE
# Native American NORP
# the last six months DATE
# Appalachia GPE
# the Mississippi Delta LOC
# Watts GPE
# the Pine Ridge Reservation ORG
# Tonight TIME
# America GPE
# Congress ORG
# America GPE
# Tonight TIME
# $22 billion MONEY
# five years DATE
# Democratic NORP
# Republican NORP
# American NORP
# Speaker PERSON
# last November DATE
# Jesse Jackson PERSON
# Illinois GPE
# Speaker PERSON
# Native American NORP
# the Mississippi Delta LOC
# $110 million MONEY
# Delta LOC
# a billion dollars MONEY
# Native American NORP
# this new century DATE
# first ORDINAL
# Americans NORP
# tonight TIME
# ’ve PERSON
# American NORP
# tonight TIME
# 1996 DATE
# today DATE
# 21st century DATE
# 1,000 CARDINAL
# This spring DATE
# first ORDINAL
# tonight TIME
# first ORDINAL
# America GPE
# America GPE
# African NORP
# Caribbean Basin LOC
# America GPE
# the 21st century DATE
# First ORDINAL
# Russia GPE
# China GPE
# today DATE
# Russia GPE
# Chechnya GPE
# China GPE
# the past decade DATE
# 5,000 CARDINAL
# Soviet NORP
# Russian NORP
# Balkans LOC
# Russian NORP
# first ORDINAL
# 1,000 years DATE
# China GPE
# tonight TIME
# Russians NORP
# Russia GPE
# Congress ORG
# China GPE
# WTO ORG
# China GPE
# this year DATE
# two CARDINAL
# First ORDINAL
# China GPE
# China GPE
# second ORDINAL
# Asia LOC
# China GPE
# China GPE
# second ORDINAL
# the Middle East LOC
# Northern Ireland GPE
# East Timor GPE
# Africa LOC
# Greece GPE
# Turkey GPE
# Cyprus GPE
# India GPE
# Pakistan GPE
# Armed Forces ORG
# Kosovo GPE
# million CARDINAL
# Slobodan Milosevic PERSON
# Kosovo GPE
# John Cherrey PERSON
# American NORP
# Serbia GPE
# Armed Forces’ ORG
# Kosovo GPE
# American NORP
# Captain Cherrey PERSON
# Captain Cherrey PERSON
# third ORDINAL
# North Korea GPE
# Iran GPE
# Iraq GPE
# ABM LAW
# Russia GPE
# the next 10 to 20 years DATE
# Pentagon ORG
# this year DATE
# the Comprehensive Nuclear-Test-Ban Treaty FAC
# Nigeria GPE
# Indonesia GPE
# 1999 DATE
# 1989 DATE
# the Berlin Wall FAC
# tonight TIME
# Colombia GPE
# two-year DATE
# Colombia GPE
# Houses ORG
# Colombia GPE
# Latin America LOC
# ’m PERSON
# billion CARDINAL
# last year DATE
# Congress ORG
# America GPE
# America GPE
# Last year DATE
# Africa LOC
# 10 CARDINAL
# $150 million MONEY
# today DATE
# TB ORG
# millions CARDINAL
# 21st century DATE
# U.N. ORG
# tonight TIME
# American NORP
# Republicans NORP
# Democrats NORP
# two CARDINAL
# First ORDINAL
# Defense ORG
# Bill Cohen PERSON
# Janet PERSON
# American NORP
# Janet Cohen PERSON
# one CARDINAL
# ’m PERSON
# more than 500 CARDINAL
# millions CARDINAL
# the past three months DATE
# 40 million acres QUANTITY
# three CARDINAL
# Tonight TIME
# California GPE
# Florida GPE
# House ORG
# year DATE
# last year DATE
# Lott PERSON
# —to PERSON
# Tonight TIME
# American NORP
# three CARDINAL
# the new century DATE
# the 1990s DATE
# the hottest decade DATE
# the entire millennium DATE
# the United States GPE
# last week DATE
# 70 to 80 miles QUANTITY
# hundreds of miles QUANTITY
# Congress ORG
# the United States of America GPE
# the new century DATE
# Later this year DATE
# first ORDINAL
# Americans NORP
# 8 percent PERCENT
# a third CARDINAL
# about 80 percent PERCENT
# 10 CARDINAL
# today DATE
# ’s ORG
# an unprecedented $3 billion MONEY
# the 21st century DATE
# First ORDINAL
# Last year DATE
# This year DATE
# first ORDINAL
# today DATE
# America GPE
# AmeriCorps ORG
# Peace Corps ORG
# 12,000 CARDINAL
# 650,000 CARDINAL
# America GPE
# American NORP
# Americans NORP
# First ORDINAL
# Second ORDINAL
# Second ORDINAL
# Americans NORP
# Tonight TIME
# English LANGUAGE
# year DATE
# 10 years DATE
# California GPE
# a little more than 50 years TIME
# America GPE
# Congress ORG
# America GPE
# the last couple of years DATE
# Texas GPE
# Wyoming GPE
# Last year DATE
# African-Americans NORP
# Asian-Americans NORP
# Jewish NORP
# American NORP
# the "Hate Crimes Prevention Act ORG
# Non-Discrimination Act LAW
# the Violence Against Women Act LOC
# tonight TIME
# American NORP
# the White House Office of One America ORG
# Hank Aaron PERSON
# his days DATE
# tonight TIME
# Hank Aaron PERSON
# one CARDINAL
# one CARDINAL
# This fall DATE
# the White House FAC
# Hillary PERSON
# one CARDINAL
# 99.9 percent PERCENT
# Americans NORP
# the State of the Union ORG
# tonight TIME
# American NORP
# Framers PERSON
# Constitution LAW
# Philadelphia GPE
# Benjamin Franklin PERSON
# Independence Hall FAC
# Today DATE
# Franklin ORG
# Today DATE
# Americans NORP
# Franklin PERSON
# 224 years DATE
# American NORP
# America GPE
# God PERSON
# America GPE

# %%
# If you're working on tokens, you can still access entity type
# Notice, though that the phrase entities are broken up here because we're iterating over tokens
# https://spacy.io/api/annotation#named-entities
for token in doc:
    if token.ent_type_ is not '':
        print(token.text, token.ent_type_, "----------", spacy.explain(token.ent_type_))

# %%
# spacy comes with built in entity visualization
displacy.render(single_doc, style="ent", jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Speaker
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Mr. Vice President, members of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Congress
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , honored guests, my fellow
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Americans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# :  </div>

# %%
next_sent = list(doc.sents)[3]
next_doc = nlp(str(next_sent))
displacy.render(next_doc, style="ent", jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">Never before have we had such a blessed opportunity and, therefore, such a profound obligation to build the more perfect
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Union of our Founders
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’ dreams.  </div>

# %% [markdown]
# It is possible to train your own entity recognition model, and to train other types of models in spaCy, but you need sufficient labeled data to make it work well.

# %% [markdown]
# ## Word transformations

# %%
# lemmas
for token in doc:
    print(token.text, token.lemma_)

# %%
doc1 = nlp('here are octopi')
for token in doc1:
    print(token.lemma_)

# %%
doc1 = nlp('There have been many mice and geese surrounding the pond.')
for token in doc1:
    print(token, token.lemma_)

# %%
# say we just want to lematize verbs
for token in doc:
    if token.tag_ == "VBP":
        print(token.text, token.lemma_)

# %%
# If you're using the simple part of speech instead of the tags
for token in doc:
    if token.pos_ == "VERB":
        print(token.text, token.lemma_)

# %%
# lowercasing
for token in doc:
    print(token.text, token.lower_)

# %% [markdown]
# ## Counting

# %%
from collections import Counter

# %%
sample_sents = "One fish, two fish, red fish, blue fish. One is less than two."

# %%
# Create a spacy doc
new_doc = nlp(sample_sents)

# Create a list of the words without the punctuation
words = [token.text for token in new_doc if token.pos_ is not 'PUNCT']
words

# %%
counter = Counter(words)

# %%
counter.most_common(10)

# %%
counter["fish"]

# %% [markdown]
# ## Sentiment Analysis
#
# Right now, spacy doesn't include a model for sentiment analysis. From comments on the spacy github repo, the developers of spacy, Explosion are going to offer sentiment models as part of their commercial offerings.
#
# They have put out examples for how to do sentiment analysis:
# - https://github.com/explosion/spaCy/blob/master/examples/deep_learning_keras.py
# - https://github.com/explosion/spaCy/blob/master/examples/training/train_textcat.py
#
# Both of these use some sort of deep learning/neural networks

# %% [markdown]
# <div style="font-size: 1em; margin: 1em 0 1em 0; border: 1px solid #86989B; background-color: #f7f7f7; padding: 0;">
# <p style="margin: 0; padding: 0.1em 0 0.1em 0.5em; color: white; border-bottom: 1px solid #86989B; font-weight: bold; background-color: #AFC1C4;">
# Activity
# </p>
# <p style="margin: 0.5em 1em 0.5em 1em; padding: 0;">
# Let's define the lexicon of a person as the number of different words she uses to speak. Write a function `get_lexicon(text, n)` that receives `text` and `n` and returns the lemmas of nouns, verbs, and adjectives that are used at least `n` times.
# <br/>
# </p>
# </div>

# %%
def get_lexicon(text, n):
    doc = nlp(text)
    
    # return a list of words that have the correct part of speech    
    words = [token.lemma_ for token in doc if token.pos_ in ["NOUN", "ADJ", "VERB"]]
    # count the words     
    counter = Counter(words)
    # filter by number
    filtered_words = [word for word in counter if counter[word] > n]
    return sorted(filtered_words)
    
get_lexicon(clinton_speech, 30)

# %% [markdown]
# ## Readability indices
#
# Readability indices are ways of assessing how easy or complex it is to read a particular text based on the words and sentences it has. They usually output scores that correlate with grade levels.
#
# A couple of indices that are presumably easy to calculate are the Auto Readability Index (ARI) and the Coleman-Liau Index:
#
# $$
# ARI = 4.71\frac{chars}{words}+0.5\frac{words}{sentences}-21.43
# $$
# $$ CL = 0.0588\frac{letters}{100 words} - 0.296\frac{sentences}{100words} - 15.8 $$
#
#
# https://en.wikipedia.org/wiki/Coleman%E2%80%93Liau_index
#
# https://en.wikipedia.org/wiki/Automated_readability_index

# %%
# problem: the tokens in spacy include punctuation. to get this right, we should remove punct
# we then have to make sure our functions handle lists of words rather than spacy doc objects

def coleman_liau_index(doc, words):
    return (0.0588 * letters_per_100(doc)) - (0.296 * sentences_per_100(doc, words)) - 15.8

def count_chars(words):
    return sum(len(w) for w in words)

def sentences_per_100(doc, words):
    return (len(list(doc.sents)) / len(words)) * 100

def letters_per_100(words):
    return (count_chars(words) / len(words)) * 100

# %%
# To get just the words, without punctuation tokens
def return_words(doc):
    return [token.text for token in doc if token.pos_ is not 'PUNCT']

# %%
fancy_doc = nlp("Regional ontology, clearly defined by Heidegger, equals, if not surpasses, the earlier work of Heidegger's own mentor, Husserl")
fancy_words = return_words(fancy_doc)
fancy_words

# %%
coleman_liau_index(fancy_doc, fancy_words)

# %%
doc = nlp(clinton_speech)
clinton_speech_words = return_words(doc)
coleman_liau_index(doc, clinton_speech_words)

# %% [markdown]
# <div style="font-size: 1em; margin: 1em 0 1em 0; border: 1px solid #86989B; background-color: #f7f7f7; padding: 0;">
# <p style="margin: 0; padding: 0.1em 0 0.1em 0.5em; color: white; border-bottom: 1px solid #86989B; font-weight: bold; background-color: #AFC1C4;">
# Activity
# </p>
# <p style="margin: 0.5em 1em 0.5em 1em; padding: 0;">
# Write a function `auto_readability_index(doc)` that receives a spacy `Doc` and returns the Auto Readability Index (ARI) score as defined above.
# <br/>
# * **Hint**: Feel free to use functions we've defined before.*
#
# </p>
# </div>

# %%
def auto_readability_index(doc):
    words = return_words(doc)
    chars = count_chars(words)
    words = len(words)
    sentences = len(list(doc.sents))
    return (4.71 * (chars / words)) + (0.5 * (words / sentences)) - 21.43

# %%
auto_readability_index(fancy_doc)

# %%
auto_readability_index(doc)

# %%
clinton_url = "https://raw.githubusercontent.com/sul-cidr/python_workshops/master/data/clinton2000.txt"
bush_url = "https://raw.githubusercontent.com/sul-cidr/python_workshops/master/data/bush2008.txt"
obama_url = "https://raw.githubusercontent.com/sul-cidr/python_workshops/master/data/obama2016.txt"
trump_url = "https://raw.githubusercontent.com/sul-cidr/python_workshops/master/data/trump.txt"

# %%
clinton_speech = get_speech(clinton_url)
bush_speech = get_speech(bush_url)
obama_speech = get_speech(obama_url)
trump_speech = get_speech(trump_url)

# %%
speeches = {
    "clinton": nlp(clinton_speech),
    "bush": nlp(bush_speech),
    "obama": nlp(obama_speech),
    "trump": nlp(trump_speech),
}

# %%
print("Name", "Chars", "Words", "Unique", "Sentences", sep="\t")
for speaker, speech in speeches.items():
    words = return_words(speech)
    print(speaker, count_chars(words), len(words), len(set(words)), len(list(speech.sents)), sep="\t")

# %% [markdown]
# <div style="font-size: 1em; margin: 1em 0 1em 0; border: 1px solid #86989B; background-color: #f7f7f7; padding: 0;">
# <p style="margin: 0; padding: 0.1em 0 0.1em 0.5em; color: white; border-bottom: 1px solid #86989B; font-weight: bold; background-color: #AFC1C4;">
# Activity
# </p>
# <p style="margin: 0.5em 1em 0.5em 1em; padding: 0;">
# Write a function `avg_sentence_length(blob)` that receives a spaCy `doc` and returns the average number of words in a sentence for the doc. You might need to use our `return_words` function.
# </p>
# </div>

# %%
# average sentence length
def avg_sentence_length(doc):
    return sum(len(return_words(s)) for s in doc.sents) / len(list(doc.sents))

# %%
for speaker, speech in speeches.items():
    print(speaker, avg_sentence_length(speech))

# %% [markdown]
# We might stop to ask why Obama's speech seems to have shorter sentences. Is it deliberate rhetorical choice? Or could it be an issue with the data itself?
#
# In this case, if we look closely at the txt file, we can see that the transcription of the speech included the world 'applause' as a one word sentence throughout the text. Let's see what happens if we filter that out.

# %%
obama_clean_speech = obama_speech.replace("(Applause.)", "")

# %%
# Let's compare lengths of the texts. We should see a difference.

len(obama_speech), len(obama_clean_speech)

# %%
# Now let's recheck the average sentence length of Obama's speech.
avg_sentence_length(nlp(obama_clean_speech))

# %%
speeches = {
    "clinton": nlp(clinton_speech),
    "bush": nlp(bush_speech),
    "obama": nlp(obama_clean_speech),
    "trump": nlp(trump_speech),
}

# %% [markdown]
# Let's write a quick function to get the most common words used by each person

# %%
def most_common_words(doc, n):
    words = return_words(doc)
    c = Counter(words)
    return c.most_common(n)

# %%
for speaker, speech in speeches.items():
    print(speaker, most_common_words(speech, 10))

# %% [markdown]
# You can see quickly that we need to remove some of these most common words. To do this, we'll use common lists of stopwords.

# %%
from spacy.lang.en.stop_words import STOP_WORDS
print(STOP_WORDS)

# %%
# to make sure we've got all the punctuation out and to remove some contractions, we'll have a custom stoplist
custom_stopwords = [',', '-', '.', '’s', '-', ' ', '(', ')', '--', '---', 'n’t', ';', "'s", "'ve", "  ", "’ve"]

# %%
def most_common_words(doc, n):
    words = [token.text for token in doc if token.pos_ is not 'PUNCT' 
             and token.lower_ not in STOP_WORDS and token.text not in custom_stopwords]
    c = Counter(words)
    return c.most_common(n)

# %%
for speaker, speech in speeches.items():
    print(speaker, ": ", most_common_words(speech, 10), "\n")

# %% [markdown]
# This sort of exploratory work is often the first step in figuring out how to clean a text for text analysis.

# %% [markdown]
# Let's assess the lexical richness, defined as the ratio of number of unique words by the number of total words.

# %%
def lexical_richness(doc):
    words = return_words(doc)
    return len(set(words)) / len(words)

# %%
for speaker, speech in speeches.items():
    print(speaker, lexical_richness(speech))

# %% [markdown]
# Let's look at the readbility scores for all four speeches now
#
# For the Automated Readability Index, you can get the appropriate grade level here: https://en.wikipedia.org/wiki/Automated_readability_index

# %%
for speaker, speech in speeches.items():
    words = return_words(speech)
    print(speaker, "ARI:", auto_readability_index(speech), "CL:", coleman_liau_index(speech, words))

# %% [markdown]
# To get some comparison, let's also look at some stats calculated through Textacy. We'll see the ARI and CL scores, which use the same formulas we used. However, you might notice that the scores are different. To understand why, you have to dig into the source code for Textacy, where you'll find that it filters out punctuation in creating the word list, which affects the number of characters. It also lowercases the punctuation-filtered words before creating the set of unique words, decreasing that number as well compared to how we calculated it here. These changes affect both the ARI and CL scores.

# %%
# !pip install textacy

# %%
import textacy

# %%
# https://en.wikipedia.org/wiki/Coleman%E2%80%93Liau_index
# https://en.wikipedia.org/wiki/Automated_readability_index
txt_speeches = [clinton_speech, bush_speech, obama_clean_speech, trump_speech]
corpus = textacy.Corpus('en', txt_speeches)
for doc in corpus:
    stats = textacy.text_stats.TextStats(doc)
    print({
        "ARI": stats.automated_readability_index,
        "CL": stats.coleman_liau_index,
        "stats": stats.basic_counts
    })

# %% [markdown]
# Why do we have such a significant difference in the CL scores? Let's look quickly at the textacy implementation: https://github.com/chartbeat-labs/textacy/blob/5927d539dd989c090f8a0b0c06ba40bb204fce82/textacy/text_stats.py#L277

# %%
print("Name", "Chars", "Words", "Unique", "Sentences", sep="\t")
for speaker, speech in speeches.items():
    words = return_words(speech)
    print(speaker, count_chars(words), len(words), len(set(words)), len(list(speech.sents)), sep="\t")

# %%
# clinton, bush, obama, trump
for doc in corpus:
    stats = textacy.text_stats.TextStats(doc)
    print({
        "stats": stats.basic_counts
    })

# %% [markdown]
# Post-workshop eval:
#
# https://stanforduniversity.qualtrics.com/jfe/form/SV_aaZ76OCnWDqQbuR
